# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from requests import get

# %%
baseURL = 'https://www.armslist.com/classifieds/search?location=new-york&category=all&page=1&posttype=7&ships=False'

# %%
response = get(baseURL)

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="utf-8" />
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <title>
#     ARMSLIST    -
# New York
# All Categories
# Classifieds
# </title>
#         <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
#         <link rel="stylesheet" href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css">
#         <link rel="stylesheet" href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css">
#         <link href='//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700' rel='stylesheet' type='text/css'>
#         <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
#         <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
# ...

# %%
print(response.content)
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n<html>\r\n    <head>\r\n        <meta charset="utf-8" />\r\n        <meta name="viewport" content="width=device-width, initial-scale=1">\r\n        <title>\r\n    ARMSLIST    -\r\nNew York     \r\nAll Categories     \r\nClassifieds\r\n</title>\r\n        <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>\r\n        <link rel="stylesheet" href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css">\r\n        <link rel="stylesheet" href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css">\r\n        <link href=\'//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700\' rel=\'stylesheet\' type=\'text/css\'>\r\n        <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">\r\n        <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>\r\n        <scrip
# ...

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
#     ARMSLIST    -
# New York
# All Categories
# Classifieds
# </title>
# <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
# <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css" rel="stylesheet"/>
# <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css" rel="stylesheet"/>
# <link href="//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    ARMSLIST    -
# New York
# All Categories
# Classifieds
#   </title>
#   <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
#   <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css" rel="stylesheet"/>
#   <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css" rel="stylesheet"/>
#   <link href="//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700" rel="stylesheet" type="text/css"/>
#   <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js">
#   </script>
#   <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js">
#   </script>
# ...

# %%
list(soup.children)
# Out:
# ['\n', 'html', '\n', <html>
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <title>
#      ARMSLIST    -
#  New York
#  All Categories
#  Classifieds
#  </title>
#  <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
#  <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css" rel="stylesheet"/>
#  <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css" rel="stylesheet"/>
#  <link href="//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700" rel="stylesheet" type="text/css"/>
#  <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
#  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
#  <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[3]

# %%
type(html)
# Out:
# bs4.element.Tag

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <title>
#      ARMSLIST    -
#  New York
#  All Categories
#  Classifieds
#  </title>
#  <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
#  <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css" rel="stylesheet"/>
#  <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css" rel="stylesheet"/>
#  <link href="//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700" rel="stylesheet" type="text/css"/>
#  <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
#  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
#  <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
# ...

# %%
list(html.children)[3]
# Out:
# <body style="-webkit-overflow-scrolling: touch;">
# <div class="modal fade" id="termsModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">TERMS OF USE</h4>
# </div>
# <div class="modal-body">
# <div id="termsModalContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" onclick="acceptTerms()" type="button">Accept</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="promotionModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">PROMOTIONAL LINK</h4>
# </div>
# <div class="modal-body">
# <div id="promotionModalContainer"></div>
# </div>
# <div class="modal-footer">
# ...

# %%
body = list(html.children)[3]

# %%
body.find_all('p')
# Out:
# [<p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Rochester</small></p>,
#  <p style="font-size: 80%;"><small>Friday, 6/7 2:30 AM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Albany</small></p>,
#  <p style="font-size: 80%;"><small>Friday, 6/7 1:17 AM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Albany</small></p>,
#  <p style="font-size: 80%;"><small>Friday, 6/7 1:17 AM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Albany</small></p>,
#  <p style="font-size: 80%;"><small>Friday, 6/7 1:16 AM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Albany</small></p>,
# ...

# %%
columns = body.find_all(class_='col-md-7')

# %%
for text in body.select('.col-md-7 h4 a'):
    print(text.get_text())
# Out:
# Unfired, compliant Steyr AUG A3
# Uzi Folding Stock - steel - NEW
# Integrated Red Laser Dot Sight - NEW
# Mini -14 Disassembly/Reassembly video
# Side Saddle 6 Shotshell Carrier
# NEW - Glock 17/19/22/23 4-position black leather holster
# Gun Magnet - Quick Draw
# Mossberg 590A1, 9 round, 12ga shotgun, XS Ghost ring sights, Heavy Wall Barrel, nearly new
# Browning Citori 525 Golden Clays
# 1942 Model 94 winchester
# 7mm MAUSER TRACER AMMO "F N 46" 12 Rounds
# MAUSER 1895 Chilean Model 95 LOEWE BERLIN GERMANY 7x57mm
# REMINGTON 1100 SKEET 12 ga SHOTGUN VERY GOOD COND
# WWI FRENCH BERTHIER 1916 M16 BOLT ACTION RIFLE
# Ruger Scout Rifle

# %%
for text in body.select('.col-md-7 h4'):
    print(text.get_text())
# Out:
# Unfired, compliant Steyr AUG A3
# FREE
# Uzi Folding Stock - steel - NEW
#
#                     $ 30
#
# Integrated Red Laser Dot Sight - NEW
#
#                     $ 50
#
# Mini -14 Disassembly/Reassembly video
#
#                     $ 15
#
# Side Saddle 6 Shotshell Carrier
#
#                     $ 14
#
# NEW - Glock 17/19/22/23 4-position black leather holster
#
#                     $ 22
#
# Gun Magnet - Quick Draw
#
#                     $ 12
#
# Mossberg 590A1, 9 round, 12ga shotgun, XS Ghost ring sights, Heavy Wall Barrel, nearly new
#
#                     $ 415
#
# Browning Citori 525 Golden Clays
#
#                     $ 2,800
#
# 1942 Model 94 winchester
#
#                     $ 750
#
# 7mm MAUSER TRACER AMMO "F N 46" 12 Rounds
#
#                     $ 25
#
# MAUSER 1895 Chilean Model 95 LOEWE BERLIN GERMANY 7x57mm
#
#                     $ 750
#
# REMINGTON 1100 SKEET 12 ga SHOTGUN VERY GOOD COND
#
#                     $ 425
#
# ...
