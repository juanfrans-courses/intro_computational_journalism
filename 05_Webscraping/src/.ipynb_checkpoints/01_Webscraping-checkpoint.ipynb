# %% [markdown]
# # Webscraping

# %% [markdown]
# This notebook shows how to scrape a website using the `BeautifulSoup` and `Requests` libraries. The example we are using here is scraping arms classifieds from the [Armslist](https://www.armslist.com/classifieds) website.

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from requests import get

# %% [markdown]
# **Set URL**

# %%
baseURL = 'https://www.armslist.com/classifieds/search?location=new-york&category=all&page=1&posttype=7&ships=False'

# %% [markdown]
# **Query the website and explore the response**

# %%
response = get(baseURL)

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html>\r\n    <head>\r\n        <meta charset="utf-8" />\r\n        <meta name="viewport" content="width=device-width, initial-scale=1">\r\n        <title>\r\n    ARMSLIST    -\r\nNew York     \r\nAll Categories     \r\nClassifieds\r\n</title>\r\n        <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>\r\n        <link rel="stylesheet" href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css">\r\n        <link rel="stylesheet" href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css">\r\n        <link href=\'//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700\' rel=\'stylesheet\' type=\'text/css\'>\r\n        <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">\r\n        <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>\r\n        <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>\r\n        <script type="text/javascript" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/js/jquery.main.js"></script>\r\n\r\n        \r\n        <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.5/js/bootstrap.min.js"></script>\r\n\r\n        \r\n        <script type="text/javascript" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/lib/jquery-cookie.js"></script>\r\n\r\n        <script type="text/javascript" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/listmill-app.js"></script>\r\n        <script type="text/javascript" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/jquery-listmill.js"></script>\r\n        \r\n\r\n\r\n        <script type="text/javascript">\r\n            var appOptions = {\r\n                showTermsOnLoad: "true" == "true" ? true : false,\r\n                showTermsOnLoadTimeout: 0};\r\n\r\n            $(function () {\r\n                if(appOptions.showTermsOnLoad) {\r\n                    checkTerms();\r\n                }\r\n            });\r\n\r\n            function checkTerms() {\r\n                if ((document.cookie.length == 0 || document.cookie.indexOf("terms=agreed") == -1)\r\n                    && window.location.href.indexOf("/info/terms") == -1\r\n                    && document.cookie.indexOf("listmill_auth") == -1) {\r\n                    showTerms();\r\n                } else\r\n                    acceptTerms();\r\n            }\r\n\r\n            function acceptTerms() {\r\n                var dateStr = "";\r\n                if (appOptions.showTermsOnLoadTimeout > 0) {\r\n                    date = new Date();\r\n                    date.setHours(date.getHours() + appOptions.showTermsOnLoadTimeout);\r\n                    dateStr = "; expires=" + date.toUTCString();\r\n                };\r\n                document.cookie = "terms=agreed" + dateStr + "; path=/";\r\n\r\n                $(\'#termsModal\').modal(\'hide\');\r\n\r\n                //show dropin after terms are agreed\r\n                //showDropin();\r\n            }\r\n\r\n            function showTerms() {\r\n                //termsModalContainer\r\n                $.ajax({\r\n                    url: "/info/termsagreement",\r\n                    dataType: "html",\r\n                    success: function (data) {\r\n                        $("#termsModalContainer").html(data);\r\n                        \r\n                        $(\'#termsModal\').modal({\r\n                            backdrop: \'static\',\r\n                            keyboard: false\r\n                        });\r\n\r\n                        $(\'#termsModal\').modal(\'show\');\r\n                    }});\r\n            }\r\n\r\n            function showDropin() {\r\n                if(document.cookie.indexOf("dropin=true") == -1) {\r\n                    $.ajax({\ ...

# %% [markdown]
# **Use `beautifulsoup` to parse the `html` and `prettify` the response**

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
#     ARMSLIST    -
# New York
# All Categories
# Classifieds
# </title>
# <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
# <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css" rel="stylesheet"/>
# <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css" rel="stylesheet"/>
# <link href="//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
# <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/js/jquery.main.js" type="text/javascript"></script>
# <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.5/js/bootstrap.min.js"></script>
# <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/lib/jquery-cookie.js" type="text/javascript"></script>
# <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/listmill-app.js" type="text/javascript"></script>
# <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/jquery-listmill.js" type="text/javascript"></script>
# <script type="text/javascript">
#             var appOptions = {
#                 showTermsOnLoad: "true" == "true" ? true : false,
#                 showTermsOnLoadTimeout: 0};
#
#             $(function () {
#                 if(appOptions.showTermsOnLoad) {
#                     checkTerms();
#                 }
#             });
#
#             function checkTerms() {
#                 if ((document.cookie.length == 0 || document.cookie.indexOf("terms=agreed") == -1)
#                     && window.location.href.indexOf("/info/terms") == -1
#                     && document.cookie.indexOf("listmill_auth") == -1) {
#                     showTerms();
#                 } else
#                     acceptTerms();
#             }
#
#             function acceptTerms() {
#                 var dateStr = "";
#                 if (appOptions.showTermsOnLoadTimeout > 0) {
#                     date = new Date();
#                     date.setHours(date.getHours() + appOptions.showTermsOnLoadTimeout);
#                     dateStr = "; expires=" + date.toUTCString();
#                 };
#                 document.cookie = "terms=agreed" + dateStr + "; path=/";
#
#                 $('#termsModal').modal('hide');
#
#                 //show dropin after terms are agreed
#                 //showDropin();
#             }
#
#             function showTerms() {
#                 //termsModalContainer
#                 $.ajax({
#                     url: "/info/termsagreement",
#                     dataType: "html",
#                     success: function (data) {
#                         $("#termsModalContainer").html(data);
#
#                         $('#termsModal').modal({
#                             backdrop: 'static',
#                             keyboard: false
#                         });
#
#                         $('#termsModal').modal('show');
#                     }});
#             }
#
#             function showDropin() {
#                 if(document.cookie.indexOf("dropin=true") == -1) {
#                     $.ajax({
#                         url: "/info/dropin",
#                         dataType: "html",
#                         success: function (data) {
#                             $("#dropinModalContainer").html(data);
#
#                             $('#dropinModal').modal({
#                                 backdrop: 'static',
#                                 keyboard: true
#                             });
#
#                             $('#dropinModal').modal('show');
#                         }});
#                 }
#             }
#
#             function saveDropin() {
#                 $.post( "/info/dropin", "email=" +$('#dropinModalTextBox').val() );
#                 setDropinCookie();
#             }
#
#             function noThanksDropin() {
#                 setDropinCookie();
#             }
#
#             function setDropinCookie() {
#                 var dateStr = "";
#                 date = new Date();
#                 // 2190 = 3 months, cookie expires in 3 months
#                 date.setHours(date.getHours() + 2190);
#                 dateStr = "; expires=" + date.toUTCString();
#                 document.cookie = "dropin=true" + dateStr + "; path=/";
#
#                 $('#dropinModal').modal('hide');
#             }
#
#         </script>
# <meta content="Classifieds listings of All Categories in New York" name="description">
# <meta content="New York, All Categories, classifieds" name="keywords"/>
# <style type="text/css">
#         .youtube_container {
#         position: relative;
#         width: 100%;
#         height: 0;
#         padding-bottom: 56.25%;
#         clear: both;
#     }
#     .youtube_video {
#         position: absolute;
#         top: 0;
#         left: 0;
#         width: 100%;
#         height: 100%;
#     }
#     .blink_me {
#         animation: blinker 1s linear infinite;
#     }
#
#     @keyframes blinker {
#       50% {
#         opacity: 0;
#       }
#     }
#     </style>
# <!-- -->
# <!--                <style type="text/css">
#         .footer-social {  width: 100px;  margin-right: 0px !important;}
#         </style>
# -->
# <style type="text/css">
#             #h3Overrides h3 {
#                 margin-top: 0px;
#                 color: #000000;
#             }
#         </style>
# <!-- Javascript tag: -->
# <!-- begin ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
# <script language="JavaScript">
# var zflag_nid="305"; var zflag_cid="56890/56889/1"; var zflag_sid="5734"; var zflag_width="1"; var zflag_height="1"; var zflag_sz="15"; var zflag_click="[INSERT_CLICK_TRACKER_MACRO]"; var zflag_page="[INSERT_PAGE_URL]";
# </script>
# <script language="JavaScript" src="http://c5.zedo.com/jsc/c5/fo.js"></script>
# <!-- end ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
# <!--ALC script-->
# <script>
#     var _alcTag = _alcTag || [];
#     (function () {
#         var atag = document.createElement('script');
#         atag.async = 1;
#         atag.src = '//al-p.alcmpn.com/wt/388/webtag.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(atag, node);
#     })();
#
#         </script>
# <!--End ALC script-->
# <!-- OneTag Container: armslist-->
# </meta></head>
# <body style="-webkit-overflow-scrolling: touch;">
# <div class="modal fade" id="termsModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">TERMS OF USE</h4>
# </div>
# <div class="modal-body">
# <div id="termsModalContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" onclick="acceptTerms()" type="button">Accept</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="promotionModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">PROMOTIONAL LINK</h4>
# </div>
# <div class="modal-body">
# <div id="promotionModalContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="filterByModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 style="color: #655d5b">Filter By</h4>
# </div>
# <div class="modal-body">
# <div id="filterByContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="dropinModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">Armslist</h4>
# </div>
# <div class="modal-body">
# <div id="dropinModalContainer"></div>
# <input id="dropinModalTextBox" type="text"/>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" onclick="noThanksDropin()" style="float: left;" type="button">Close</button>
# <button class="btn btn-primary" onclick="saveDropin()" type="button">Submit</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="contactSellerEmailModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 style="color: #655d5b">Contact Seller</h4>
# </div>
# <div class="modal-body">
# <div id="messageSellerContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="pull-left btn btn-default" id="contactFormSubmitBtn" onclick="doMessageSend()" type="button">Send</button>
# <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="searchAlertModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 style="color: #655d5b">Search Alert</h4>
# </div>
# <div class="modal-body">
# <div id="searchAlertContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="pull-left btn btn-default" id="searchAlertFormSubmitBtn" onclick="createSearchAlert()" type="button">Create</button>
# <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
# </div>
# </div>
# </div>
# </div>
# <div id="wrapper">
# <header class="navbar-default text-uppercase" id="header" role="navigation">
# <div class="top-holder">
# <div class="container-fluid">
# <button class="navbar-toggle text-uppercase pull-left" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" id="popoverMobileViewMainMenu" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="text">Menu</span>
# </button>
# <div id="popovercontentMobileViewMainMenu" style="display: none;">
# <div class="container-fluid">
# <div class="row" id="h3Overrides">
# <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#                         $(document).ready(function () {
#
#                             $("#popoverMobileViewMainMenu").popover({
#                                 html: true,
#                                 container: 'body',
#                                 content: function () {
#                                     return $('#popovercontentMobileViewMainMenu').html();
#                                 }
#                             });
#
#                             $('html').on('click', function (e) {
#                                 if (typeof $(e.target).data('original-title') == 'undefined' &&
#                                     !$(e.target).parents().is('.popover.in') &&
#                                     $(e.target).parent().attr("id") !== "popoverMobileViewMainMenu") {
#                                     $('[data-original-title]').popover('hide');
#                                 }
#                             });
#                         });
#
#                     </script>
# <div class="pull-right align-right">
# <form action="/classifieds/search" class="search-form navbar-form hidden-xs" method="get" role="search"> <fieldset>
# <div class="form-group">
# <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
# <input name="location" type="hidden" value="new-york">
# <input name="category" type="hidden" value="all"/>
# <input name="posttype" type="hidden" value="7"/>
# <input name="ships" type="hidden"/>
# </input></div>
# <button class="btn btn-default icon-search" type="submit"></button>
# </fieldset>
# </form>
# <a class="btn btn-warning create-btn text-uppercase" href="/posts/new"><span class="hidden-sm hidden-xs">CREATE A LISTING</span> <i class="icon-pencil"></i> <span class="visible-sm visible-xs">list</span></a>
# <ul class="users-list hidden-xs">
# <li><a href="/account/new">CREATE AN ACCOUNT</a></li>
# <li><a href="/accountlogin">LOGIN</a></li>
# </ul>
# <button class="btn btn-warning create-btn text-uppercase visible-xs" onclick="showHideSearchMobile()" type="button"><i class="icon-search"></i> <span class="visible-xs">search</span></button>
# <script type="text/javascript">
#                             function showHideSearchMobile() {
#                                 $("#searchMobileView").fadeToggle();
#                             }
#                         </script>
# </div>
# <div class="pull-left" id="logo">
# <a href="/" title="ARMSLIST - Firearms Classifieds">
# <picture>
# <!--[if IE 9]><video style="display: none;"><![endif]-->
# <source media="(max-width: 767px)" srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile@2x.png 2x"/>
# <source srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop@2x.png 2x"/>
# <!--[if IE 9]></video><![endif]-->
# <img alt="armslist firearms marketplace" height="66" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png" width="260"/>
# </picture>
# </a>
# </div>
# </div>
# </div>
# <div class="hidden-xs"><br/><br/></div>
# <div class="alert " id="mainMessageContainer" style="display: none; margin-bottom: 0px;">
# <div id="mainMessageContainer_Message" style="text-align: center;"></div>
# </div>
# <div class="hidden-sm hidden-md hidden-lg" id="searchMobileView" style="padding: 20px 10px 10px 20px; text-align: center; display: none;">
# <form action="/classifieds/search" class="search-form" method="get" role="search" style="width: 75% !important;"> <fieldset>
# <div class="form-group">
# <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
# <input name="location" type="hidden" value="new-york">
# <input name="category" type="hidden" value="all"/>
# <input name="posttype" type="hidden" value="7"/>
# <input name="ships" type="hidden"/>
# </input></div>
# <button class="btn btn-default icon-search" type="submit"></button>
# </fieldset>
# </form> <br/>
# <div class="carousel slide" data-ride="carousel" id="myCarousel" style="padding-top: 20px;">
# <!-- Wrapper for slides -->
# <div class="carousel-inner" role="listbox">
# <div class="item active">
# <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
# <a href="/classifieds/search?category=handguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">HANDGUNS <br/><i class="icon-handguns"></i></a>
# <a href="/classifieds/search?category=shotguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">SHOTGUNS <br/><i class="icon-shotguns"></i></a>
# <a href="/classifieds/search?category=rifles&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">RIFLES <br/><i class="icon-rifles"></i></a>
# </div>
# </div>
# <div class="item">
# <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
# <a href="/classifieds/search?category=firearm-accessories&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">ACCESSORIES <br/><i class="icon-scope"></i></a>
# <a href="/classifieds/search?category=outdoors&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">GEAR + MORE <br/><i class="icon-gear"></i></a>
# </div>
# </div>
# </div>
# <!-- Left and right controls -->
# <a class="left carousel-control" data-slide="prev" href="#myCarousel" role="button">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-left"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="right carousel-control" data-slide="next" href="#myCarousel" role="button">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-right"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# <style type="text/css">
#                     .carousel-control.left, .carousel-control.right {
#                         background-image: none;
#                     }
#                 </style>
# </div>
# </header>
# <main id="main">
# <div class="container-fluid" style="color: #655D5B;">
# <div id="bootstrap-overrides">
# <div class="col-xs-12 col-md-4" style="padding-top: 15px;">
# <h3>1 - 15 of 1118 results in All Categories</h3>
# </div>
# <div class="col-xs-12 col-md-8">
# <div class="col-xs-3 col-md-3" style="padding: 15px 0px 0px 0px; margin: 0px;">
# <a class="hidden-md hidden-lg" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Alert</a>
# <a class="hidden-xs hidden-sm" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Set a Search Alert</a>
# <script type="text/javascript">
#                 function newInitRecaptcha() {
#                     $.getScript("https://www.google.com/recaptcha/api/js/recaptcha_ajax.js", function () {
#                         Recaptcha.create(
#                             RecaptchaOptions.publicKey,     // public key, declared in Recaptcha view
#                             "recaptchaControls",            // id
#                             RecaptchaOptions                // options, declared in Recaptcha view
#                         );
#                     });
#                 }
#
#                 function doCreateSearchAlert(obj) {
#                     //var $dialog = $("#searchAlertDialog");
#                     //if ($dialog.length == 0) {
#                     //    $dialog = $('<div id="searchAlertDialog"></div>');
#                     //    $("body").append($dialog);
#                     //}
#                     //$dialog.html("");
#                     $.ajax({
#                         url: "/searchalerts/new",
#                         cache: false,
#                         success: function (data) {
#                             $("#searchAlertContainer").html(data);
#                             newInitRecaptcha();
#                             //$dialog.html(data);
#                             //listmill.app.initRecaptcha();
#                             //$dialog.dialog({
#                             //    title: "New Search Alert",
#                             //    modal: true,
#                             //    width: 460,
#                             //    buttons: [
#                             //        { text: "Create", click: createSearchAlert },
#                             //        { text: "Cancel", click: function () { $(this).dialog("close"); } },
#                             //    ]
#                             //});
#                             //$("#name").focus();
#                         }
#                     });
#                     return false;
#                 }
#
#                 function createSearchAlert() {
#                     var $dialog = $("#searchAlertContainer");
#                     var $form = $dialog.find("form");
#                     $.ajax({
#                         url: $form.attr("action"),
#                         type: "POST",
#                         data: $form.serialize(),
#                         success: createSearchAlertCallback,
#                         error: function () {
#                             $('#searchAlertModal').modal('hide');
#                             alert("There was a problem creating the search alert.");
#                         }
#                     });
#                 }
#
#                 function createSearchAlertCallback(data) {
#                     if (data === "success") {
#
#                         $('#searchAlertModal').modal('hide');
#                         alert("Search Alert Created");
#                         //listmill.app.showMessage("success", "Search Alert successfully created! You should receive a confirmation email shortly.");
#                         //$("#searchAlertDialog").dialog("close");
#                     } else {
#                         $("#searchAlertContainer").html(data);
#                         newInitRecaptcha();
#                         //var $dialog = $("#searchAlertDialog");
#                         //$dialog.html(data);
#                         //$dialog.dialog("open");
#                         //listmill.app.initRecaptcha();
#                     }
#                 }
#             </script>
# </div>
# <div class="col-xs-4 col-md-4" style="padding: 15px 0px 0px 0px;">
# <a class="" href="/deals" style="color: #cb2027;"><i class="fa fa-star"></i> Deals <i class="fa fa-star"></i></a>
# </div>
# <div class="hidden-md hidden-lg" style="float: right; padding: 15px 0px 15px 15px; position: relative;">
# <!--<a data-placement="bottom" id="popoverMobileView" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>-->
# <a data-target="#filterByModal" data-toggle="modal" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>
# <div id="popovercontentMobileView" style="display: none;">
# <div style="padding: 10px; text-align: center;">
# <a class="clear-all" href="/classifieds/search?location=new-york&amp;category=all" title="Remove All">Clear All</a>
# </div>
# <div style="padding: 10px; border-top: solid 1px #aaaaaa; border-bottom: solid 1px #aaaaaa;">
# <table style="width: 100%">
# <tr>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Private Party<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=4&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Premium Vendor<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=1&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Vendors that Ship<br>
# <a class="class_checkbox " href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=True"></a>
# </br></td>
# </tr>
# <tr><td colspan="3" style="border-top: solid 1px #aaaaaa;"> </td></tr>
# <tr>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 For Sale<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=6&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 For Trade<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=5&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Want to Buy<br/>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=3&amp;ships=False"></a>
# </td>
# </tr>
# </table>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 20px;">
# <h3 style="color: #555555;">LOCATION</h3>
# <div style="position: relative; color: #000000; background: url('https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png') no-repeat center;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png" style="opacity: 0;"/>
# <div style="position: absolute; top: 20%; width: 100%; text-align: center;">
#                                     Searching in<br/>
# <h2 style="font-weight: bold; color: #000000;">
# New York
#                                     </h2>
# </div>
# </div>
# <br/>
# <div>
# <select id="locationDDL" name="stateDDL" onchange="changeLocation(this)" style="color: #000000;">
# <option value="">State</option>
# <option value="/classifieds/search?location=alabama&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Alabama
#                                     </option>
# <option value="/classifieds/search?location=alaska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Alaska
#                                     </option>
# <option value="/classifieds/search?location=arizona&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Arizona
#                                     </option>
# <option value="/classifieds/search?location=arkansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Arkansas
#                                     </option>
# <option value="/classifieds/search?location=california&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         California
#                                     </option>
# <option value="/classifieds/search?location=colorado&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Colorado
#                                     </option>
# <option value="/classifieds/search?location=connecticut&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Connecticut
#                                     </option>
# <option value="/classifieds/search?location=delaware&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Delaware
#                                     </option>
# <option value="/classifieds/search?location=florida&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Florida
#                                     </option>
# <option value="/classifieds/search?location=georgia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Georgia
#                                     </option>
# <option value="/classifieds/search?location=guam-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Guam
#                                     </option>
# <option value="/classifieds/search?location=hawaii&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Hawaii
#                                     </option>
# <option value="/classifieds/search?location=idaho&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Idaho
#                                     </option>
# <option value="/classifieds/search?location=illinois&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Illinois
#                                     </option>
# <option value="/classifieds/search?location=indiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Indiana
#                                     </option>
# <option value="/classifieds/search?location=iowa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Iowa
#                                     </option>
# <option value="/classifieds/search?location=kansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Kansas
#                                     </option>
# <option value="/classifieds/search?location=kentucky&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Kentucky
#                                     </option>
# <option value="/classifieds/search?location=louisiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Louisiana
#                                     </option>
# <option value="/classifieds/search?location=maine&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Maine
#                                     </option>
# <option value="/classifieds/search?location=maryland&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Maryland
#                                     </option>
# <option value="/classifieds/search?location=massachusetts&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Massachusetts
#                                     </option>
# <option value="/classifieds/search?location=michigan&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Michigan
#                                     </option>
# <option value="/classifieds/search?location=minnesota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Minnesota
#                                     </option>
# <option value="/classifieds/search?location=mississippi&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Mississippi
#                                     </option>
# <option value="/classifieds/search?location=missouri&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Missouri
#                                     </option>
# <option value="/classifieds/search?location=montana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Montana
#                                     </option>
# <option value="/classifieds/search?location=nebraska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Nebraska
#                                     </option>
# <option value="/classifieds/search?location=nevada&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Nevada
#                                     </option>
# <option value="/classifieds/search?location=new-hampshire&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New Hampshire
#                                     </option>
# <option value="/classifieds/search?location=nj&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New Jersey
#                                     </option>
# <option value="/classifieds/search?location=new-mexico&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New Mexico
#                                     </option>
# <option selected="selected" value="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New York
#                                     </option>
# <option value="/classifieds/search?location=north-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         North Carolina
#                                     </option>
# <option value="/classifieds/search?location=north-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         North Dakota
#                                     </option>
# <option value="/classifieds/search?location=ohio&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Ohio
#                                     </option>
# <option value="/classifieds/search?location=oklahoma&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Oklahoma
#                                     </option>
# <option value="/classifieds/search?location=oregon&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Oregon
#                                     </option>
# <option value="/classifieds/search?location=pennsylvania&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Pennsylvania
#                                     </option>
# <option value="/classifieds/search?location=puerto-rico-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Puerto Rico
#                                     </option>
# <option value="/classifieds/search?location=rhode-island&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Rhode Island
#                                     </option>
# <option value="/classifieds/search?location=south-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         South Carolina
#                                     </option>
# <option value="/classifieds/search?location=south-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         South Dakota
#                                     </option>
# <option value="/classifieds/search?location=tennessee&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Tennessee
#                                     </option>
# <option value="/classifieds/search?location=texas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Texas
#                                     </option>
# <option value="/classifieds/search?location=utah&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Utah
#                                     </option>
# <option value="/classifieds/search?location=vermont&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Vermont
#                                     </option>
# <option value="/classifieds/search?location=virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Virginia
#                                     </option>
# <option value="/classifieds/search?location=washington&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Washington
#                                     </option>
# <option value="/classifieds/search?location=west-virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         West Virginia
#                                     </option>
# <option value="/classifieds/search?location=wisconsin&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Wisconsin
#                                     </option>
# <option value="/classifieds/search?location=wyoming&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Wyoming
#                                     </option>
# </select>
# <br/> <select name="cityDDL" onchange="changeLocation(this)" style="color: #000000; margin-top: 10px;">
# <option value="">City</option>
# <option value="/classifieds/search?location=adirondacks-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Adirondacks
#                                     </option>
# <option value="/classifieds/search?location=albany-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Albany
#                                     </option>
# <option value="/classifieds/search?location=binghamton-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Binghamton
#                                     </option>
# <option value="/classifieds/search?location=buffalo-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Buffalo
#                                     </option>
# <option value="/classifieds/search?location=hudson-valley-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Hudson Valley
#                                     </option>
# <option value="/classifieds/search?location=long-island-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Long Island
#                                     </option>
# <option value="/classifieds/search?location=rochester-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Rochester
#                                     </option>
# <option value="/classifieds/search?location=syracuse-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Syracuse
#                                     </option>
# <option value="/classifieds/search?location=tri-state-area&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Tri-state area
#                                     </option>
# <option value="/classifieds/search?location=watertown&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Watertown
#                                     </option>
# </select>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 20px 20px 10px 20px;">
# <div>
# <a class="accordion-toggle chevron-rotate" data-toggle="collapse" href="#collapseCategoryMobile">
# <h3 style="color: #5c724c;">
# <i class="fa fa-chevron-right"></i> Category
#                                             </h3>
# </a>
# </div>
# <div class="collapse " id="collapseCategoryMobile" style="border-top: solid 1px #aaaaaa;">
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=guns&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Firearms</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapsegunsMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=antiques&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Antique Firearms</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=handguns&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Handguns</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=muzzle-loaders&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Muzzle Loaders</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=nfa-firearms&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">NFA Firearms</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=rifles&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Rifles</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=shotguns&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Shotguns</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=firearm-accessories&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Firearm Accessories</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapsefirearm-accessoriesMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=ammo&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Ammo</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-parts&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Gun Parts</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-safes&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Gun Safes</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=holsters&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Holsters</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=magazines&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Magazines</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=optics&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Optics</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=reloading&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Reloading</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=tactical-gear&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Tactical Gear</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=outdoors&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Outdoors Gear</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapseoutdoorsMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=archery&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Archery</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=fishing&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Fishing Gear</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=hunting&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Hunting Gear</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=knives&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Knives</h5></td>
# <td style="width: 21px;">
# ...
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=aa79cc16&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=46&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=aa79cc16"/></a></noscript>
# </div>
# <div class="ad-search">
# <!--/*
#   *
#   * Revive Adserver Javascript Tag
#   * - Generated with Revive Adserver v3.2.2
#   *
#   */-->
# <!--/*
#   * The backup image section of this tag has been generated for use on a
#   * non-SSL page. If this tag is to be placed on an SSL page, change the
#   *   'http://revive.armslist.com/revive/www/delivery/...'
#   * to
#   *   'https://revive.armslist.com/revive/www/delivery/...'
#   *
#   * This noscript section of this tag only shows image banners. There
#   * is no width or height in these banners, so if you want these tags to
#   * allocate space for the ad before it shows, you will need to add this
#   * information to the <img> tag.
#   *
#   * If you do not want to deal with the intricities of the noscript
#   * section, delete the tag (from <noscript>... to </noscript>). On
#   * average, the noscript tag is called from less than 1% of internet
#   * users.
#   */-->
# <script type="text/javascript"><!--//<![CDATA[
#    var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
# var m3_r = Math.floor(Math.random()*99999999999);
# if (!document.MAX_used) document.MAX_used = ',';
# document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
# document.write ("?zoneid=48");
# document.write ('&amp;cb=' + m3_r);
# if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
# document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
# document.write ("&amp;loc=" + escape(window.location));
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=af067137&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=48&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=af067137"/></a></noscript>
# </div>
# <div class="ad-search">
# <!--/*
#   *
#   * Revive Adserver Javascript Tag
#   * - Generated with Revive Adserver v3.2.2
#   *
#   */-->
# <!--/*
#   * The backup image section of this tag has been generated for use on a
#   * non-SSL page. If this tag is to be placed on an SSL page, change the
#   *   'http://revive.armslist.com/revive/www/delivery/...'
#   * to
#   *   'https://revive.armslist.com/revive/www/delivery/...'
#   *
#   * This noscript section of this tag only shows image banners. There
#   * is no width or height in these banners, so if you want these tags to
#   * allocate space for the ad before it shows, you will need to add this
#   * information to the <img> tag.
#   *
#   * If you do not want to deal with the intricities of the noscript
#   * section, delete the tag (from <noscript>... to </noscript>). On
#   * average, the noscript tag is called from less than 1% of internet
#   * users.
#   */-->
# <script type="text/javascript"><!--//<![CDATA[
#    var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
# var m3_r = Math.floor(Math.random()*99999999999);
# if (!document.MAX_used) document.MAX_used = ',';
# document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
# document.write ("?zoneid=47");
# document.write ('&amp;cb=' + m3_r);
# if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
# document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
# document.write ("&amp;loc=" + escape(window.location));
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=ae5ac2c4&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=47&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=ae5ac2c4"/></a></noscript>
# </div>
# <div style="padding-top: 10px;">
# <div style='background-color: #2f2d24; text-align: left; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
# <h2 style="color: #e5e0bf; padding: 5px;">Latest Video</h2>
# </div>
# <iframe allowfullscreen="" class="youtube_video" frameborder="0" src="https://www.youtube.com/embed?max-results=1&amp;controls=0&amp;showinfo=0&amp;rel=0&amp;listType=user_uploads&amp;list=ArmslistMedia"></iframe>
# <div style="clear: both;"> </div>
# </div>
# <script type="text/javascript">
#                                 $(document).ready(function () {
#                                     $(".youtube_video").wrap('<div class="youtube_container">');
#                                 });
#                             </script>
# <div id="rcjsload_dc470c"></div>
# <script type="text/javascript">
#                                 (function () {
#                                     var referer = ""; try { if (referer = document.referrer, "undefined" == typeof referer || "" == referer) throw "undefined" } catch (exception) { referer = document.location.href, ("" == referer || "undefined" == typeof referer) && (referer = document.URL) } referer = referer.substr(0, 700);
#                                     var rcds = document.getElementById("rcjsload_dc470c");
#                                     var rcel = document.createElement("script");
#                                     rcel.id = 'rc_' + Math.floor(Math.random() * 1000);
#                                     rcel.type = 'text/javascript';
#                                     rcel.src = "//trends.revcontent.com/serve.js.php?w=109511&t=" + rcel.id + "&c=" + (new Date()).getTime() + "&width=" + (window.outerWidth || document.documentElement.clientWidth) + "&referer=" + encodeURIComponent(referer);
#                                     rcel.async = true;
#                                     rcds.appendChild(rcel);
#                                 })();
#                             </script>
# </div>
# </div>
# <style type="text/css">
#                     .ad-search {
#                         margin-top: 16px;
#                     }
#                     .popover{
#                         max-width: none;
#                         width: 300px;
#                     }
#
#                     #bootstrap-overrides h2, #filterByContainer h2 {
#                         margin-top: 0px;
#                     }
#
#                     #bootstrap-overrides h3, #filterByContainer h3 {
#                         margin-top: 0px;
#                         color: #000000;
#                         font-weight: bold;
#                     }
#                     .class_checkbox {
#                         display: inline-block;
#                         padding-top: 4px;
#                         width: 43px;
#                         height: 27px;
#                         background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/OFF_desktop.png);
#                         cursor: pointer;
#
#                     }
#
#                     .class_checkbox.checked {
#                         background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/ON_desktop.png);
#                     }
#
#                     .switches {
#                         font-weight: bold;
#                         color: #000000;
#                     }
#
#                     .clickable-row {
#                         cursor: pointer;
#                     }
#                 </style>
# <script type="text/javascript">
#
#
#                     function changeLocation(location) {
#                         if (location) {
#                             window.location = $(location).val();;
#                         }
#                         return false;
#                     }
#
#                     $(document).on("click", ".clickable-row", function () {
#                         window.document.location = $(this).data("href");
#
#                     });
#
#                     $(document).on("click", ".chevron-rotate", function () {
#                         if ($(this).parent().find(".fa-chevron-right").length) {
#                             $(this).parent().find(".fa-chevron-right").removeClass("fa-chevron-right").addClass("fa-chevron-down");
#                         } else {
#                             $(this).parent().find(".fa-chevron-down").removeClass("fa-chevron-down").addClass("fa-chevron-right");
#                         }
#                     });
#
#
#                 </script>
# <!-- HACK FOR EDS -->
# <table style="display: none;">
# <tr><td class="title"><a href="/posts/9571384/long-island-new-york-optics-for-sale--vortex-viper">FS: Vortex Viper</a></td></tr>
# <tr><td class="title"><a href="/posts/9789750/long-island-new-york-rifles-for-sale-trade--chiappa-1892-alaskan-take-down">FS/FT: Chiappa 1892 Alaskan Take Down</a></td></tr>
# <tr><td class="title"><a href="/posts/9572179/long-island-new-york-gun-parts-for-sale--rossi-coach-gun-overland-parts">FS: Rossi Coach Gun Overland Parts</a></td></tr>
# <tr><td class="title"><a href="/posts/9503782/long-island-new-york-shotguns-for-sale-trade--rossi-chrome-coach-gun-rare">FS/FT: Rossi Chrome Coach Gun Rare</a></td></tr>
# <tr><td class="title"><a href="/posts/9504240/long-island-new-york-shotguns-for-sale--savage-24--22lr-over-20ga-">FS: Savage 24  22lr Over 20ga.</a></td></tr>
# <tr><td class="title"><a href="/posts/9874160/long-island-new-york-shotguns-for-sale--remington-coach-gun-new-old-stock">FS: Remington Coach Gun New Old Stock</a></td></tr>
# <tr><td class="title"><a href="/posts/10074126/long-island-new-york-rifles-for-sale--ruger-m77-hawkeye-tactical--308">FS: Ruger m77 Hawkeye Tactical .308</a></td></tr>
# <tr><td class="title"><a href="/posts/10075280/long-island-new-york-shotguns-for-sale--rossi-overland-coach-gun-">FS: Rossi Overland Coach Gun </a></td></tr>
# <tr><td class="title"><a href="/posts/10078638/long-island-new-york-ammo-for-sale--remington--22-win-mag-case">FS: Remington .22 Win Mag case</a></td></tr>
# <tr><td class="title"><a href="/posts/10078666/long-island-new-york-ammo-for-sale--winchester--410-pdx1-defender-ammo">FS: Winchester .410 PDX1 Defender Ammo</a></td></tr>
# <tr><td class="title"><a href="/posts/10078487/watertown-handguns-for-sale--ruger-security-six--357">FS: Ruger Security Six .357</a></td></tr>
# <tr><td class="title"><a href="/posts/10110105/rochester-new-york-handguns-for-sale---glock-45-9mm-10rd-3-mags-frt-ser">FS:  GLOCK 45 9MM 10RD 3 MAGS FRT SER</a></td></tr>
# <tr><td class="title"><a href="/posts/10059192/rochester-new-york-handguns-for-sale--taurus-605">FS: Taurus 605</a></td></tr>
# <tr><td class="title"><a href="/posts/7876495/rochester-new-york-holsters-for-sale--ruger-lcpii-kydex-holster-and-ruger-mag">FS: Ruger LCPII kydex holster and Ruger mag</a></td></tr>
# <tr><td class="title"><a href="/posts/7959698/rochester-new-york-handguns-for-sale--taylor---co---uberti--smoke-wagon--357">FS: Taylor &amp; Co. (Uberti) Smoke Wagon .357</a></td></tr>
# </table>
# </div>
# </main>
# <style type="text/css"> body { overflow: visible; } </style>
# <footer id="footer" style="display: table;">
# <div class="top-hold hidden-xs">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
# </div>
# </div>
# </div>
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-6 col-md-offset-3 col-sm-8 col-sm-offset-2">
# <ul class="social-list">
# <li>
# <a class="icon-youtube" href="http://www.youtube.com/user/armslistmedia?sub_confirmation=1" target="_blank" title="Armslist Youtube channel"></a>
# </li>
# <li>
# <a class="icon-instagram" href="https://instagram.com/armslist/" target="_blank" title="Armslist on Instagram"></a>
# </li>
# <li>
# <a class="icon-facebook" href="https://www.facebook.com/armslist" target="_blank" title="Armslist on Facebook"></a>
# </li>
# <li>
# <a class="icon-twitter" href="https://twitter.com/armslist" target="_blank" title="Armslist Twitter page"></a>
# </li>
# <li>
# <a class="icon-google-plus" href="https://plus.google.com/103978926144598391141/posts" target="_blank" title="Armslist on Google+"></a>
# </li>
# </ul>
# <div class="text-block">
# <p>Always comply with local, state, federal, and international law.
# ARMSLIST does not become involved in transactions between parties. Review our
# <a href="/info/privacy">privacy policy</a> and <a href="/info/terms">terms of use</a> for more
# information. Report Illegal Firearms Activity to 1-800-ATF-GUNS.  </p>
# </div>
# <span class="copy">
#                             Copyright © 2019 Armslist, LLC |
#
#                             | Version: 15.0.2
#                         </span>
# </div>
# </div>
# </div>
# <script id="LOTCC_3569" src="http://tags.crwdcntrl.net/c/3569/cc.js?ns=_cc3569" type="text/javascript"></script>
# <script language="javascript" type="text/javascript"> _cc3569.bcp(); </script>
# </footer>
# </div>
# <div class="loader-box">
# <img alt="loader" height="64" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/loader.gif" width="64"/>
# </div>
# <script>   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');    ga('create', 'UA-5138407-1', 'auto');   ga('send', 'pageview');  </script>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    ARMSLIST    -
# New York
# All Categories
# Classifieds
#   </title>
#   <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
#   <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css" rel="stylesheet"/>
#   <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css" rel="stylesheet"/>
#   <link href="//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700" rel="stylesheet" type="text/css"/>
#   <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js">
#   </script>
#   <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js">
#   </script>
#   <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/js/jquery.main.js" type="text/javascript">
#   </script>
#   <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.5/js/bootstrap.min.js">
#   </script>
#   <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/lib/jquery-cookie.js" type="text/javascript">
#   </script>
#   <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/listmill-app.js" type="text/javascript">
#   </script>
#   <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/jquery-listmill.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var appOptions = {
#                 showTermsOnLoad: "true" == "true" ? true : false,
#                 showTermsOnLoadTimeout: 0};
#
#             $(function () {
#                 if(appOptions.showTermsOnLoad) {
#                     checkTerms();
#                 }
#             });
#
#             function checkTerms() {
#                 if ((document.cookie.length == 0 || document.cookie.indexOf("terms=agreed") == -1)
#                     && window.location.href.indexOf("/info/terms") == -1
#                     && document.cookie.indexOf("listmill_auth") == -1) {
#                     showTerms();
#                 } else
#                     acceptTerms();
#             }
#
#             function acceptTerms() {
#                 var dateStr = "";
#                 if (appOptions.showTermsOnLoadTimeout > 0) {
#                     date = new Date();
#                     date.setHours(date.getHours() + appOptions.showTermsOnLoadTimeout);
#                     dateStr = "; expires=" + date.toUTCString();
#                 };
#                 document.cookie = "terms=agreed" + dateStr + "; path=/";
#
#                 $('#termsModal').modal('hide');
#
#                 //show dropin after terms are agreed
#                 //showDropin();
#             }
#
#             function showTerms() {
#                 //termsModalContainer
#                 $.ajax({
#                     url: "/info/termsagreement",
#                     dataType: "html",
#                     success: function (data) {
#                         $("#termsModalContainer").html(data);
#
#                         $('#termsModal').modal({
#                             backdrop: 'static',
#                             keyboard: false
#                         });
#
#                         $('#termsModal').modal('show');
#                     }});
#             }
#
#             function showDropin() {
#                 if(document.cookie.indexOf("dropin=true") == -1) {
#                     $.ajax({
#                         url: "/info/dropin",
#                         dataType: "html",
#                         success: function (data) {
#                             $("#dropinModalContainer").html(data);
#
#                             $('#dropinModal').modal({
#                                 backdrop: 'static',
#                                 keyboard: true
#                             });
#
#                             $('#dropinModal').modal('show');
#                         }});
#                 }
#             }
#
#             function saveDropin() {
#                 $.post( "/info/dropin", "email=" +$('#dropinModalTextBox').val() );
#                 setDropinCookie();
#             }
#
#             function noThanksDropin() {
#                 setDropinCookie();
#             }
#
#             function setDropinCookie() {
#                 var dateStr = "";
#                 date = new Date();
#                 // 2190 = 3 months, cookie expires in 3 months
#                 date.setHours(date.getHours() + 2190);
#                 dateStr = "; expires=" + date.toUTCString();
#                 document.cookie = "dropin=true" + dateStr + "; path=/";
#
#                 $('#dropinModal').modal('hide');
#             }
#   </script>
#   <meta content="Classifieds listings of All Categories in New York" name="description">
#    <meta content="New York, All Categories, classifieds" name="keywords"/>
#    <style type="text/css">
#     .youtube_container {
#         position: relative;
#         width: 100%;
#         height: 0;
#         padding-bottom: 56.25%;
#         clear: both;
#     }
#     .youtube_video {
#         position: absolute;
#         top: 0;
#         left: 0;
#         width: 100%;
#         height: 100%;
#     }
#     .blink_me {
#         animation: blinker 1s linear infinite;
#     }
#
#     @keyframes blinker {
#       50% {
#         opacity: 0;
#       }
#     }
#    </style>
#    <!-- -->
#    <!--                <style type="text/css">
#         .footer-social {  width: 100px;  margin-right: 0px !important;}
#         </style>
# -->
#    <style type="text/css">
#     #h3Overrides h3 {
#                 margin-top: 0px;
#                 color: #000000;
#             }
#    </style>
#    <!-- Javascript tag: -->
#    <!-- begin ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
#    <script language="JavaScript">
#     var zflag_nid="305"; var zflag_cid="56890/56889/1"; var zflag_sid="5734"; var zflag_width="1"; var zflag_height="1"; var zflag_sz="15"; var zflag_click="[INSERT_CLICK_TRACKER_MACRO]"; var zflag_page="[INSERT_PAGE_URL]";
#    </script>
#    <script language="JavaScript" src="http://c5.zedo.com/jsc/c5/fo.js">
#    </script>
#    <!-- end ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
#    <!--ALC script-->
#    <script>
#     var _alcTag = _alcTag || [];
#     (function () {
#         var atag = document.createElement('script');
#         atag.async = 1;
#         atag.src = '//al-p.alcmpn.com/wt/388/webtag.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(atag, node);
#     })();
#    </script>
#    <!--End ALC script-->
#    <!-- OneTag Container: armslist-->
#   </meta>
#  </head>
#  <body style="-webkit-overflow-scrolling: touch;">
#   <div class="modal fade" id="termsModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#    <div class="modal-dialog">
#     <!-- Modal content-->
#     <div class="modal-content">
#      <div class="modal-header">
#       <h4 style="color: #655d5b">
#        TERMS OF USE
#       </h4>
#      </div>
#      <div class="modal-body">
#       <div id="termsModalContainer">
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-default" onclick="acceptTerms()" type="button">
#        Accept
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="promotionModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#    <div class="modal-dialog">
#     <!-- Modal content-->
#     <div class="modal-content">
#      <div class="modal-header">
#       <h4 style="color: #655d5b">
#        PROMOTIONAL LINK
#       </h4>
#      </div>
#      <div class="modal-body">
#       <div id="promotionModalContainer">
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-default" data-dismiss="modal" type="button">
#        Close
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="filterByModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#    <div class="modal-dialog">
#     <!-- Modal content-->
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h4 style="color: #655d5b">
#        Filter By
#       </h4>
#      </div>
#      <div class="modal-body">
#       <div id="filterByContainer">
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-default" data-dismiss="modal" type="button">
#        Close
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="dropinModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#    <div class="modal-dialog">
#     <!-- Modal content-->
#     <div class="modal-content">
#      <div class="modal-header">
#       <h4 style="color: #655d5b">
#        Armslist
#       </h4>
#      </div>
#      <div class="modal-body">
#       <div id="dropinModalContainer">
#       </div>
#       <input id="dropinModalTextBox" type="text"/>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-default" onclick="noThanksDropin()" style="float: left;" type="button">
#        Close
#       </button>
#       <button class="btn btn-primary" onclick="saveDropin()" type="button">
#        Submit
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="contactSellerEmailModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#    <div class="modal-dialog">
#     <!-- Modal content-->
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h4 style="color: #655d5b">
#        Contact Seller
#       </h4>
#      </div>
#      <div class="modal-body">
#       <div id="messageSellerContainer">
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="pull-left btn btn-default" id="contactFormSubmitBtn" onclick="doMessageSend()" type="button">
#        Send
#       </button>
#       <button class="btn btn-default" data-dismiss="modal" type="button">
#        Cancel
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal fade" id="searchAlertModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#    <div class="modal-dialog">
#     <!-- Modal content-->
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h4 style="color: #655d5b">
#        Search Alert
#       </h4>
#      </div>
#      <div class="modal-body">
#       <div id="searchAlertContainer">
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="pull-left btn btn-default" id="searchAlertFormSubmitBtn" onclick="createSearchAlert()" type="button">
#        Create
#       </button>
#       <button class="btn btn-default" data-dismiss="modal" type="button">
#        Cancel
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="wrapper">
#    <header class="navbar-default text-uppercase" id="header" role="navigation">
#     <div class="top-holder">
#      <div class="container-fluid">
#       <button class="navbar-toggle text-uppercase pull-left" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" id="popoverMobileViewMainMenu" type="button">
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="text">
#         Menu
#        </span>
#       </button>
#       <div id="popovercontentMobileViewMainMenu" style="display: none;">
#        <div class="container-fluid">
#         <div class="row" id="h3Overrides">
#          <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0">
#           <h3 class="text-uppercase">
#            ACCOUNT &amp; LISTINGS
#           </h3>
#           <ul class="nav-footer">
#            <li>
#             <a href="//www.armslist.com/accountlogin/new">
#              Account Login
#             </a>
#            </li>
#            <li>
#             <a href="//www.armslist.com/account/new">
#              New Account
#             </a>
#            </li>
#            <li>
#             <a href="//www.armslist.com/posts/new">
#              Create a New Listing
#             </a>
#            </li>
#            <li>
#             <a href="//www.armslist.com/posts/resendactivation">
#              Edit or Remove a Listing
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-lg-2 col-md-3 col-sm-6">
#           <h3 class="text-uppercase">
#            ABOUT &amp; HELP
#           </h3>
#           <ul class="nav-footer">
#            <li>
#             <a href="//www.armslist.com/info/faqs">
#              FAQs
#             </a>
#            </li>
#            <li>
#             <a href="//www.armslist.com/info/contact">
#              Contact Armslist
#             </a>
#            </li>
#            <li>
#             <a href="//www.armslist.com/info/privacy">
#              Privacy Policy
#             </a>
#            </li>
#            <li>
#             <a href="//www.armslist.com/info/terms">
#              Terms of Use
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-md-3 col-sm-6">
#           <h3 class="text-uppercase">
#            MORE ARMSLIST LINKS
#           </h3>
#           <ul class="nav-footer">
#            <li>
#             <a href="https://www.armslist.com/blog/">
#              Armslist Blog
#             </a>
#            </li>
#            <li>
#             <a href="https://www.armslist.com/giveaways">
#              Armslist Giveaway
#             </a>
#            </li>
#            <li>
#             <a href="http://www.armslist.com/contests/">
#              Armslist Contests
#             </a>
#            </li>
#            <li>
#             <a href="http://www.armslistlegaldefensefund.com/">
#              Armslist Legal Defense Fund
#             </a>
#            </li>
#            <li>
#             <a href="//www.armslist.com/info/advertise">
#              Advertising with Armslist
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="col-md-3 col-sm-6">
#           <h3 class="text-uppercase">
#            PARTNER SITES
#           </h3>
#           <ul class="nav-footer">
#            <li>
#             <a href="http://www.torquelist.com/">
#              Torquelist Vehicle Trader
#             </a>
#            </li>
#            <li>
#             <a href="http://www.rangemonkey.com/">
#              Range Monkey
#             </a>
#            </li>
#            <li>
#             <a href="http://www.invictusgearcompany.com/">
#              Invictus Gear
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#       <script type="text/javascript">
#        $(document).ready(function () {
#
#                             $("#popoverMobileViewMainMenu").popover({
#                                 html: true,
#                                 container: 'body',
#                                 content: function () {
#                                     return $('#popovercontentMobileViewMainMenu').html();
#                                 }
#                             });
#
#                             $('html').on('click', function (e) {
#                                 if (typeof $(e.target).data('original-title') == 'undefined' &&
#                                     !$(e.target).parents().is('.popover.in') &&
#                                     $(e.target).parent().attr("id") !== "popoverMobileViewMainMenu") {
#                                     $('[data-original-title]').popover('hide');
#                                 }
#                             });
#                         });
#       </script>
#       <div class="pull-right align-right">
#        <form action="/classifieds/search" class="search-form navbar-form hidden-xs" method="get" role="search">
#         <fieldset>
#          <div class="form-group">
#           <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
#           <input name="location" type="hidden" value="new-york">
#            <input name="category" type="hidden" value="all"/>
#            <input name="posttype" type="hidden" value="7"/>
#            <input name="ships" type="hidden"/>
#           </input>
#          </div>
#          <button class="btn btn-default icon-search" type="submit">
#          </button>
#         </fieldset>
#        </form>
#        <a class="btn btn-warning create-btn text-uppercase" href="/posts/new">
#         <span class="hidden-sm hidden-xs">
#          CREATE A LISTING
#         </span>
#         <i class="icon-pencil">
#         </i>
#         <span class="visible-sm visible-xs">
#          list
#         </span>
#        </a>
#        <ul class="users-list hidden-xs">
#         <li>
#          <a href="/account/new">
#           CREATE AN ACCOUNT
#          </a>
#         </li>
#         <li>
#          <a href="/accountlogin">
#           LOGIN
#          </a>
#         </li>
#        </ul>
#        <button class="btn btn-warning create-btn text-uppercase visible-xs" onclick="showHideSearchMobile()" type="button">
#         <i class="icon-search">
#         </i>
#         <span class="visible-xs">
#          search
#         </span>
#        </button>
#        <script type="text/javascript">
#         function showHideSearchMobile() {
#                                 $("#searchMobileView").fadeToggle();
#                             }
#        </script>
#       </div>
#       <div class="pull-left" id="logo">
#        <a href="/" title="ARMSLIST - Firearms Classifieds">
#         <picture>
#          <!--[if IE 9]><video style="display: none;"><![endif]-->
#          <source media="(max-width: 767px)" srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile@2x.png 2x"/>
#          <source srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop@2x.png 2x"/>
#          <!--[if IE 9]></video><![endif]-->
#          <img alt="armslist firearms marketplace" height="66" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png" width="260"/>
#         </picture>
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="hidden-xs">
#      <br/>
#      <br/>
#     </div>
#     <div class="alert " id="mainMessageContainer" style="display: none; margin-bottom: 0px;">
#      <div id="mainMessageContainer_Message" style="text-align: center;">
#      </div>
#     </div>
#     <div class="hidden-sm hidden-md hidden-lg" id="searchMobileView" style="padding: 20px 10px 10px 20px; text-align: center; display: none;">
#      <form action="/classifieds/search" class="search-form" method="get" role="search" style="width: 75% !important;">
#       <fieldset>
#        <div class="form-group">
#         <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
#         <input name="location" type="hidden" value="new-york">
#          <input name="category" type="hidden" value="all"/>
#          <input name="posttype" type="hidden" value="7"/>
#          <input name="ships" type="hidden"/>
#         </input>
#        </div>
#        <button class="btn btn-default icon-search" type="submit">
#        </button>
#       </fieldset>
#      </form>
#      <br/>
#      <div class="carousel slide" data-ride="carousel" id="myCarousel" style="padding-top: 20px;">
#       <!-- Wrapper for slides -->
#       <div class="carousel-inner" role="listbox">
#        <div class="item active">
#         <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
#          <a href="/classifieds/search?category=handguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">
#           HANDGUNS
#           <br/>
#           <i class="icon-handguns">
#           </i>
#          </a>
#          <a href="/classifieds/search?category=shotguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">
#           SHOTGUNS
#           <br/>
#           <i class="icon-shotguns">
#           </i>
#          </a>
#          <a href="/classifieds/search?category=rifles&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">
#           RIFLES
#           <br/>
#           <i class="icon-rifles">
#           </i>
#          </a>
#         </div>
#        </div>
#        <div class="item">
#         <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
#          <a href="/classifieds/search?category=firearm-accessories&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">
#           ACCESSORIES
#           <br/>
#           <i class="icon-scope">
#           </i>
#          </a>
#          <a href="/classifieds/search?category=outdoors&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">
#           GEAR + MORE
#           <br/>
#           <i class="icon-gear">
#           </i>
#          </a>
#         </div>
#        </div>
#       </div>
#       <!-- Left and right controls -->
#       <a class="left carousel-control" data-slide="prev" href="#myCarousel" role="button">
#        <span aria-hidden="true" class="glyphicon glyphicon-chevron-left">
#        </span>
#        <span class="sr-only">
#         Previous
#        </span>
#       </a>
#       <a class="right carousel-control" data-slide="next" href="#myCarousel" role="button">
#        <span aria-hidden="true" class="glyphicon glyphicon-chevron-right">
#        </span>
#        <span class="sr-only">
#         Next
#        </span>
#       </a>
#      </div>
#      <style type="text/css">
#       .carousel-control.left, .carousel-control.right {
#                         background-image: none;
#                     }
#      </style>
#     </div>
#    </header>
#    <main id="main">
#     <div class="container-fluid" style="color: #655D5B;">
#      <div id="bootstrap-overrides">
#       <div class="col-xs-12 col-md-4" style="padding-top: 15px;">
#        <h3>
#         1 - 15 of 1118 results in All Categories
#        </h3>
#       </div>
#       <div class="col-xs-12 col-md-8">
#        <div class="col-xs-3 col-md-3" style="padding: 15px 0px 0px 0px; margin: 0px;">
#         <a class="hidden-md hidden-lg" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)">
#          <i class="fa fa-bullhorn">
#          </i>
#          Alert
#         </a>
#         <a class="hidden-xs hidden-sm" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)">
#          <i class="fa fa-bullhorn">
#          </i>
#          Set a Search Alert
#         </a>
#         <script type="text/javascript">
#          function newInitRecaptcha() {
#                     $.getScript("https://www.google.com/recaptcha/api/js/recaptcha_ajax.js", function () {
#                         Recaptcha.create(
#                             RecaptchaOptions.publicKey,     // public key, declared in Recaptcha view
#                             "recaptchaControls",            // id
#                             RecaptchaOptions                // options, declared in Recaptcha view
#                         );
#                     });
#                 }
#
#                 function doCreateSearchAlert(obj) {
#                     //var $dialog = $("#searchAlertDialog");
#                     //if ($dialog.length == 0) {
#                     //    $dialog = $('<div id="searchAlertDialog"></div>');
#                     //    $("body").append($dialog);
#                     //}
#                     //$dialog.html("");
#                     $.ajax({
#                         url: "/searchalerts/new",
#                         cache: false,
#                         success: function (data) {
#                             $("#searchAlertContainer").html(data);
#                             newInitRecaptcha();
#                             //$dialog.html(data);
#                             //listmill.app.initRecaptcha();
#                             //$dialog.dialog({
#                             //    title: "New Search Alert",
#                             //    modal: true,
#                             //    width: 460,
#                             //    buttons: [
#                             //        { text: "Create", click: createSearchAlert },
#                             //        { text: "Cancel", click: function () { $(this).dialog("close"); } },
#                             //    ]
#                             //});
#                             //$("#name").focus();
#                         }
#                     });
#                     return false;
#                 }
#
#                 function createSearchAlert() {
#                     var $dialog = $("#searchAlertContainer");
#                     var $form = $dialog.find("form");
#                     $.ajax({
#                         url: $form.attr("action"),
#                         type: "POST",
#                         data: $form.serialize(),
#                         success: createSearchAlertCallback,
#                         error: function () {
#                             $('#searchAlertModal').modal('hide');
#                             alert("There was a problem creating the search alert.");
#                         }
#                     });
#                 }
#
#                 function createSearchAlertCallback(data) {
#                     if (data === "success") {
#
#                         $('#searchAlertModal').modal('hide');
#                         alert("Search Alert Created");
#                         //listmill.app.showMessage("success", "Search Alert successfully created! You should receive a confirmation email shortly.");
#                         //$("#searchAlertDialog").dialog("close");
#                     } else {
#                         $("#searchAlertContainer").html(data);
#                         newInitRecaptcha();
#                         //var $dialog = $("#searchAlertDialog");
#                         //$dialog.html(data);
#                         //$dialog.dialog("open");
#                         //listmill.app.initRecaptcha();
#                     }
#                 }
#         </script>
#        </div>
#        <div class="col-xs-4 col-md-4" style="padding: 15px 0px 0px 0px;">
#         <a class="" href="/deals" style="color: #cb2027;">
#          <i class="fa fa-star">
#          </i>
#          Deals
#          <i class="fa fa-star">
#          </i>
#         </a>
#        </div>
#        <div class="hidden-md hidden-lg" style="float: right; padding: 15px 0px 15px 15px; position: relative;">
#         <!--<a data-placement="bottom" id="popoverMobileView" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>-->
#         <a data-target="#filterByModal" data-toggle="modal" href="#">
#          <i class="fa fa-chevron-right">
#          </i>
#          FILTERED BY
#         </a>
#         <div id="popovercontentMobileView" style="display: none;">
#          <div style="padding: 10px; text-align: center;">
#           <a class="clear-all" href="/classifieds/search?location=new-york&amp;category=all" title="Remove All">
#            Clear All
#           </a>
#          </div>
#          <div style="padding: 10px; border-top: solid 1px #aaaaaa; border-bottom: solid 1px #aaaaaa;">
#           <table style="width: 100%">
#            <tr>
#             <td class="switches" style="text-align: center;" valign="middle">
#              Private Party
#              <br>
#               <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=4&amp;ships=False">
#               </a>
#              </br>
#             </td>
#             <td class="switches" style="text-align: center;" valign="middle">
#              Premium Vendor
#              <br>
#               <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=1&amp;ships=False">
#               </a>
#              </br>
#             </td>
#             <td class="switches" style="text-align: center;" valign="middle">
#              Vendors that Ship
#              <br>
#               <a class="class_checkbox " href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=True">
#               </a>
#              </br>
#             </td>
#            </tr>
#            <tr>
#             <td colspan="3" style="border-top: solid 1px #aaaaaa;">
#             </td>
#            </tr>
#            <tr>
#             <td class="switches" style="text-align: center;" valign="middle">
#              For Sale
#              <br>
#               <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=6&amp;ships=False">
#               </a>
#              </br>
#             </td>
#             <td class="switches" style="text-align: center;" valign="middle">
#              For Trade
#              <br>
#               <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=5&amp;ships=False">
#               </a>
#              </br>
#             </td>
#             <td class="switches" style="text-align: center;" valign="middle">
#              Want to Buy
#              <br/>
#              <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=3&amp;ships=False">
#              </a>
#             </td>
#            </tr>
#           </table>
#          </div>
#          <div style="border-bottom: solid 1px #aaaaaa; padding: 20px;">
#           <h3 style="color: #555555;">
#            LOCATION
#           </h3>
#           <div style="position: relative; color: #000000; background: url('https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png') no-repeat center;">
#            <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png" style="opacity: 0;"/>
#            <div style="position: absolute; top: 20%; width: 100%; text-align: center;">
#             Searching in
#             <br/>
#             <h2 style="font-weight: bold; color: #000000;">
#              New York
#             </h2>
#            </div>
#           </div>
#           <br/>
#           <div>
#            <select id="locationDDL" name="stateDDL" onchange="changeLocation(this)" style="color: #000000;">
#             <option value="">
#              State
#             </option>
#             <option value="/classifieds/search?location=alabama&amp;category=all&amp;posttype=7&amp;ships=False">
#              Alabama
#             </option>
#             <option value="/classifieds/search?location=alaska&amp;category=all&amp;posttype=7&amp;ships=False">
#              Alaska
#             </option>
#             <option value="/classifieds/search?location=arizona&amp;category=all&amp;posttype=7&amp;ships=False">
#              Arizona
#             </option>
#             <option value="/classifieds/search?location=arkansas&amp;category=all&amp;posttype=7&amp;ships=False">
#              Arkansas
#             </option>
#             <option value="/classifieds/search?location=california&amp;category=all&amp;posttype=7&amp;ships=False">
#              California
#             </option>
#             <option value="/classifieds/search?location=colorado&amp;category=all&amp;posttype=7&amp;ships=False">
#              Colorado
#             </option>
#             <option value="/classifieds/search?location=connecticut&amp;category=all&amp;posttype=7&amp;ships=False">
#              Connecticut
#             </option>
#             <option value="/classifieds/search?location=delaware&amp;category=all&amp;posttype=7&amp;ships=False">
#              Delaware
#             </option>
#             <option value="/classifieds/search?location=florida&amp;category=all&amp;posttype=7&amp;ships=False">
#              Florida
#             </option>
#             <option value="/classifieds/search?location=georgia&amp;category=all&amp;posttype=7&amp;ships=False">
#              Georgia
#             </option>
#             <option value="/classifieds/search?location=guam-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#              Guam
#             </option>
#             <option value="/classifieds/search?location=hawaii&amp;category=all&amp;posttype=7&amp;ships=False">
#              Hawaii
#             </option>
#             <option value="/classifieds/search?location=idaho&amp;category=all&amp;posttype=7&amp;ships=False">
#              Idaho
#             </option>
#             <option value="/classifieds/search?location=illinois&amp;category=all&amp;posttype=7&amp;ships=False">
#              Illinois
#             </option>
#             <option value="/classifieds/search?location=indiana&amp;category=all&amp;posttype=7&amp;ships=False">
#              Indiana
#             </option>
#             <option value="/classifieds/search?location=iowa&amp;category=all&amp;posttype=7&amp;ships=False">
#              Iowa
#             </option>
#             <option value="/classifieds/search?location=kansas&amp;category=all&amp;posttype=7&amp;ships=False">
#              Kansas
#             </option>
#             <option value="/classifieds/search?location=kentucky&amp;category=all&amp;posttype=7&amp;ships=False">
#              Kentucky
#             </option>
#             <option value="/classifieds/search?location=louisiana&amp;category=all&amp;posttype=7&amp;ships=False">
#              Louisiana
#             </option>
#             <option value="/classifieds/search?location=maine&amp;category=all&amp;posttype=7&amp;ships=False">
#              Maine
#             </option>
#             <option value="/classifieds/search?location=maryland&amp;category=all&amp;posttype=7&amp;ships=False">
#              Maryland
#             </option>
#             <option value="/classifieds/search?location=massachusetts&amp;category=all&amp;posttype=7&amp;ships=False">
#              Massachusetts
#             </option>
#             <option value="/classifieds/search?location=michigan&amp;category=all&amp;posttype=7&amp;ships=False">
#              Michigan
#             </option>
#             <option value="/classifieds/search?location=minnesota&amp;category=all&amp;posttype=7&amp;ships=False">
#              Minnesota
#             </option>
#             <option value="/classifieds/search?location=mississippi&amp;category=all&amp;posttype=7&amp;ships=False">
#              Mississippi
#             </option>
#             <option value="/classifieds/search?location=missouri&amp;category=all&amp;posttype=7&amp;ships=False">
#              Missouri
#             </option>
#             <option value="/classifieds/search?location=montana&amp;category=all&amp;posttype=7&amp;ships=False">
#              Montana
#             </option>
#             <option value="/classifieds/search?location=nebraska&amp;category=all&amp;posttype=7&amp;ships=False">
#              Nebraska
#             </option>
#             <option value="/classifieds/search?location=nevada&amp;category=all&amp;posttype=7&amp;ships=False">
#              Nevada
#             </option>
#             <option value="/classifieds/search?location=new-hampshire&amp;category=all&amp;posttype=7&amp;ships=False">
#              New Hampshire
#             </option>
#             <option value="/classifieds/search?location=nj&amp;category=all&amp;posttype=7&amp;ships=False">
#              New Jersey
#             </option>
#             <option value="/classifieds/search?location=new-mexico&amp;category=all&amp;posttype=7&amp;ships=False">
#              New Mexico
#             </option>
#             <option selected="selected" value="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#              New York
#             </option>
#             <option value="/classifieds/search?location=north-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#              North Carolina
#             </option>
#             <option value="/classifieds/search?location=north-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#              North Dakota
#             </option>
#             <option value="/classifieds/search?location=ohio&amp;category=all&amp;posttype=7&amp;ships=False">
#              Ohio
#             </option>
#             <option value="/classifieds/search?location=oklahoma&amp;category=all&amp;posttype=7&amp;ships=False">
#              Oklahoma
#             </option>
#             <option value="/classifieds/search?location=oregon&amp;category=all&amp;posttype=7&amp;ships=False">
#              Oregon
#             </option>
#             <option value="/classifieds/search?location=pennsylvania&amp;category=all&amp;posttype=7&amp;ships=False">
#              Pennsylvania
#             </option>
#             <option value="/classifieds/search?location=puerto-rico-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#              Puerto Rico
#             </option>
#             <option value="/classifieds/search?location=rhode-island&amp;category=all&amp;posttype=7&amp;ships=False">
#              Rhode Island
#             </option>
#             <option value="/classifieds/search?location=south-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#              South Carolina
#             </option>
#             <option value="/classifieds/search?location=south-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#              South Dakota
#             </option>
#             <option value="/classifieds/search?location=tennessee&amp;category=all&amp;posttype=7&amp;ships=False">
#              Tennessee
#             </option>
#             <option value="/classifieds/search?location=texas&amp;category=all&amp;posttype=7&amp;ships=False">
#              Texas
#             </option>
#             <option value="/classifieds/search?location=utah&amp;category=all&amp;posttype=7&amp;ships=False">
#              Utah
#             </option>
#             <option value="/classifieds/search?location=vermont&amp;category=all&amp;posttype=7&amp;ships=False">
#              Vermont
#             </option>
#             <option value="/classifieds/search?location=virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#              Virginia
#             </option>
#             <option value="/classifieds/search?location=washington&amp;category=all&amp;posttype=7&amp;ships=False">
#              Washington
#             </option>
#             <option value="/classifieds/search?location=west-virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#              West Virginia
#             </option>
#             <option value="/classifieds/search?location=wisconsin&amp;category=all&amp;posttype=7&amp;ships=False">
#              Wisconsin
#             </option>
#             <option value="/classifieds/search?location=wyoming&amp;category=all&amp;posttype=7&amp;ships=False">
#              Wyoming
#             </option>
#            </select>
#            <br/>
#            <select name="cityDDL" onchange="changeLocation(this)" style="color: #000000; margin-top: 10px;">
#             <option value="">
#              City
#             </option>
#             <option value="/classifieds/search?location=adirondacks-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#              Adirondacks
#             </option>
#             <option value="/classifieds/search?location=albany-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#              Albany
#             </option>
#             <option value="/classifieds/search?location=binghamton-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#              Binghamton
#             </option>
#             <option value="/classifieds/search?location=buffalo-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#              Buffalo
#             </option>
#             <option value="/classifieds/search?location=hudson-valley-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#              Hudson Valley
#             </option>
#             <option value="/classifieds/search?location=long-island-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#              Long Island
#             </option>
#             <option value="/classifieds/search?location=rochester-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#              Rochester
#             </option>
#             <option value="/classifieds/search?location=syracuse-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#              Syracuse
#             </option>
#             <option value="/classifieds/search?location=tri-state-area&amp;category=all&amp;posttype=7&amp;ships=False">
#              Tri-state area
#             </option>
#             <option value="/classifieds/search?location=watertown&amp;category=all&amp;posttype=7&amp;ships=False">
#              Watertown
#             </option>
#            </select>
#           </div>
#          </div>
#          <div style="border-bottom: solid 1px #aaaaaa; padding: 20px 20px 10px 20px;">
#           <div>
#            <a class="accordion-toggle chevron-rotate" data-toggle="collapse" href="#collapseCategoryMobile">
#             <h3 style="color: #5c724c;">
#              <i class="fa fa-chevron-right">
#              </i>
#              Category
#             </h3>
#            </a>
#           </div>
#           <div class="collapse " id="collapseCategoryMobile" style="border-top: solid 1px #aaaaaa;">
#            <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
#             <table style="width: 100%;">
#              <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=guns&amp;posttype=7&amp;ships=False">
#               <td>
#                <h4 style="color: #5c724c; font-weight: 400;">
#                 Firearms
#                </h4>
#               </td>
#               <td style="width: 21px;">
#                <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#               </td>
#              </tr>
#             </table>
#             <div class="collapse " id="collapsegunsMobile" style="padding: 0px 0px 0px 20px;">
#              <div>
#               <table style="width: 100%;">
#                <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=antiques&amp;posttype=7&amp;ships=False">
#                 <td>
#                  <h5 style="color: #5c724c; font-weight: 400;">
#                   Antique Firearms
#                  </h5>
#                 </td>
#                 <td style="width: 21px;">
#                  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#                 </td>
#                </tr>
#               </table>
#              </div>
#              <div>
#               <table style="width: 100%;">
#                <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=handguns&amp;posttype=7&amp;ships=False">
#                 <td>
#                  <h5 style="color: #5c724c; font-weight: 400;">
#                   Handguns
#                  </h5>
#                 </td>
#                 <td style="width: 21px;">
#                  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#                 </td>
#                </tr>
#               </table>
#              </div>
#              <div>
#               <table style="width: 100%;">
#                <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=muzzle-loaders&amp;posttype=7&amp;ships=False">
#                 <td>
#                  <h5 style="color: #5c724c; font-weight: 400;">
#                   Muzzle Loaders
#                  </h5>
#                 </td>
#                 <td style="width: 21px;">
#                  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#                 </td>
#                </tr>
#               </table>
#              </div>
#              <div>
#               <table style="width: 100%;">
#                <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=nfa-firearms&amp;posttype=7&amp;ships=False">
#                 <td>
#                  <h5 style="color: #5c724c; font-weight: 400;">
#                   NFA Firearms
#                  </h5>
#                 </td>
#                 <td style="width: 21px;">
#                  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#                 </td>
#                </tr>
#               </table>
#              </div>
#              <div>
#               <table style="width: 100%;">
#                <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=rifles&amp;posttype=7&amp;ships=False">
#                 <td>
#                  <h5 style="color: #5c724c; font-weight: 400;">
#                   Rifles
#                  </h5>
#                 </td>
#                 <td style="width: 21px;">
#                  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#                 </td>
#                </tr>
#               </table>
#              </div>
#              <div>
#               <table style="width: 100%;">
#                <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=shotguns&amp;posttype=7&amp;ships=False">
#                 <td>
#                  <h5 style="color: #5c724c; font-weight: 400;">
#                   Shotguns
#                  </h5>
#                 </td>
#                 <td style="width: 21px;">
#                  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#                 </td>
#                </tr>
#               </table>
#              </div>
#             </div>
#            </div>
#            <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
#             <table style="width: 100%;">
#              <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=firearm-accessories&amp;posttype=7&amp;ships=False">
#               <td>
#                <h4 style="color: #5c724c; font-weight: 400;">
#                 Firearm Accessories
#                </h4>
#               </td>
#               <td style="width: 21px;">
#                <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#               </td>
#              </tr>
#             </table>
#             <div class="collapse " id="collapsefirearm-accessoriesMobile" style="padding: 0px 0px 0px 20px;">
#              <div>
#               <table style="width: 100%;">
#                <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=ammo&amp;posttype=7&amp;ships=False">
#                 <td>
#                  <h5 style="color: #5c724c; font-weight: 400;">
#                   Ammo
#                  </h5>
#                 </td>
#                 <td style="width: 21px;">
#                  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#                 </td>
#                </tr>
#               </table>
#              </div>
#              <div>
#               <table style="width: 100%;">
#                <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-parts&amp;posttype=7&amp;ships=False">
#                 <td>
#                  <h5 style="color: #5c724c; font-weight: 400;">
#                   Gun Parts
#                  </h5>
#                 </td>
#                 <td style="width: 21px;">
#                  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#                 </td>
#                </tr>
#               </table>
#              </div>
#              <div>
# ...
#           <img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=48&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=af067137"/>
#          </a>
#         </noscript>
#        </div>
#        <div class="ad-search">
#         <!--/*
#   *
#   * Revive Adserver Javascript Tag
#   * - Generated with Revive Adserver v3.2.2
#   *
#   */-->
#         <!--/*
#   * The backup image section of this tag has been generated for use on a
#   * non-SSL page. If this tag is to be placed on an SSL page, change the
#   *   'http://revive.armslist.com/revive/www/delivery/...'
#   * to
#   *   'https://revive.armslist.com/revive/www/delivery/...'
#   *
#   * This noscript section of this tag only shows image banners. There
#   * is no width or height in these banners, so if you want these tags to
#   * allocate space for the ad before it shows, you will need to add this
#   * information to the <img> tag.
#   *
#   * If you do not want to deal with the intricities of the noscript
#   * section, delete the tag (from <noscript>... to </noscript>). On
#   * average, the noscript tag is called from less than 1% of internet
#   * users.
#   */-->
#         <script type="text/javascript">
#          <!--//<![CDATA[
#    var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
# var m3_r = Math.floor(Math.random()*99999999999);
# if (!document.MAX_used) document.MAX_used = ',';
# document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
# document.write ("?zoneid=47");
# document.write ('&amp;cb=' + m3_r);
# if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
# document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
# document.write ("&amp;loc=" + escape(window.location));
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>-->
#         </script>
#         <noscript>
#          <a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=ae5ac2c4&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank">
#           <img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=47&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=ae5ac2c4"/>
#          </a>
#         </noscript>
#        </div>
#        <div style="padding-top: 10px;">
#         <div style='background-color: #2f2d24; text-align: left; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
#          <h2 style="color: #e5e0bf; padding: 5px;">
#           Latest Video
#          </h2>
#         </div>
#         <iframe allowfullscreen="" class="youtube_video" frameborder="0" src="https://www.youtube.com/embed?max-results=1&amp;controls=0&amp;showinfo=0&amp;rel=0&amp;listType=user_uploads&amp;list=ArmslistMedia">
#         </iframe>
#         <div style="clear: both;">
#         </div>
#        </div>
#        <script type="text/javascript">
#         $(document).ready(function () {
#                                     $(".youtube_video").wrap('<div class="youtube_container">');
#                                 });
#        </script>
#        <div id="rcjsload_dc470c">
#        </div>
#        <script type="text/javascript">
#         (function () {
#                                     var referer = ""; try { if (referer = document.referrer, "undefined" == typeof referer || "" == referer) throw "undefined" } catch (exception) { referer = document.location.href, ("" == referer || "undefined" == typeof referer) && (referer = document.URL) } referer = referer.substr(0, 700);
#                                     var rcds = document.getElementById("rcjsload_dc470c");
#                                     var rcel = document.createElement("script");
#                                     rcel.id = 'rc_' + Math.floor(Math.random() * 1000);
#                                     rcel.type = 'text/javascript';
#                                     rcel.src = "//trends.revcontent.com/serve.js.php?w=109511&t=" + rcel.id + "&c=" + (new Date()).getTime() + "&width=" + (window.outerWidth || document.documentElement.clientWidth) + "&referer=" + encodeURIComponent(referer);
#                                     rcel.async = true;
#                                     rcds.appendChild(rcel);
#                                 })();
#        </script>
#       </div>
#      </div>
#      <style type="text/css">
#       .ad-search {
#                         margin-top: 16px;
#                     }
#                     .popover{
#                         max-width: none;
#                         width: 300px;
#                     }
#
#                     #bootstrap-overrides h2, #filterByContainer h2 {
#                         margin-top: 0px;
#                     }
#
#                     #bootstrap-overrides h3, #filterByContainer h3 {
#                         margin-top: 0px;
#                         color: #000000;
#                         font-weight: bold;
#                     }
#                     .class_checkbox {
#                         display: inline-block;
#                         padding-top: 4px;
#                         width: 43px;
#                         height: 27px;
#                         background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/OFF_desktop.png);
#                         cursor: pointer;
#
#                     }
#
#                     .class_checkbox.checked {
#                         background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/ON_desktop.png);
#                     }
#
#                     .switches {
#                         font-weight: bold;
#                         color: #000000;
#                     }
#
#                     .clickable-row {
#                         cursor: pointer;
#                     }
#      </style>
#      <script type="text/javascript">
#       function changeLocation(location) {
#                         if (location) {
#                             window.location = $(location).val();;
#                         }
#                         return false;
#                     }
#
#                     $(document).on("click", ".clickable-row", function () {
#                         window.document.location = $(this).data("href");
#
#                     });
#
#                     $(document).on("click", ".chevron-rotate", function () {
#                         if ($(this).parent().find(".fa-chevron-right").length) {
#                             $(this).parent().find(".fa-chevron-right").removeClass("fa-chevron-right").addClass("fa-chevron-down");
#                         } else {
#                             $(this).parent().find(".fa-chevron-down").removeClass("fa-chevron-down").addClass("fa-chevron-right");
#                         }
#                     });
#      </script>
#      <!-- HACK FOR EDS -->
#      <table style="display: none;">
#       <tr>
#        <td class="title">
#         <a href="/posts/9571384/long-island-new-york-optics-for-sale--vortex-viper">
#          FS: Vortex Viper
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/9789750/long-island-new-york-rifles-for-sale-trade--chiappa-1892-alaskan-take-down">
#          FS/FT: Chiappa 1892 Alaskan Take Down
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/9572179/long-island-new-york-gun-parts-for-sale--rossi-coach-gun-overland-parts">
#          FS: Rossi Coach Gun Overland Parts
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/9503782/long-island-new-york-shotguns-for-sale-trade--rossi-chrome-coach-gun-rare">
#          FS/FT: Rossi Chrome Coach Gun Rare
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/9504240/long-island-new-york-shotguns-for-sale--savage-24--22lr-over-20ga-">
#          FS: Savage 24  22lr Over 20ga.
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/9874160/long-island-new-york-shotguns-for-sale--remington-coach-gun-new-old-stock">
#          FS: Remington Coach Gun New Old Stock
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/10074126/long-island-new-york-rifles-for-sale--ruger-m77-hawkeye-tactical--308">
#          FS: Ruger m77 Hawkeye Tactical .308
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/10075280/long-island-new-york-shotguns-for-sale--rossi-overland-coach-gun-">
#          FS: Rossi Overland Coach Gun
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/10078638/long-island-new-york-ammo-for-sale--remington--22-win-mag-case">
#          FS: Remington .22 Win Mag case
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/10078666/long-island-new-york-ammo-for-sale--winchester--410-pdx1-defender-ammo">
#          FS: Winchester .410 PDX1 Defender Ammo
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/10078487/watertown-handguns-for-sale--ruger-security-six--357">
#          FS: Ruger Security Six .357
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/10110105/rochester-new-york-handguns-for-sale---glock-45-9mm-10rd-3-mags-frt-ser">
#          FS:  GLOCK 45 9MM 10RD 3 MAGS FRT SER
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/10059192/rochester-new-york-handguns-for-sale--taurus-605">
#          FS: Taurus 605
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/7876495/rochester-new-york-holsters-for-sale--ruger-lcpii-kydex-holster-and-ruger-mag">
#          FS: Ruger LCPII kydex holster and Ruger mag
#         </a>
#        </td>
#       </tr>
#       <tr>
#        <td class="title">
#         <a href="/posts/7959698/rochester-new-york-handguns-for-sale--taylor---co---uberti--smoke-wagon--357">
#          FS: Taylor &amp; Co. (Uberti) Smoke Wagon .357
#         </a>
#        </td>
#       </tr>
#      </table>
#     </div>
#    </main>
#    <style type="text/css">
#     body { overflow: visible; }
#    </style>
#    <footer id="footer" style="display: table;">
#     <div class="top-hold hidden-xs">
#      <div class="container-fluid">
#       <div class="row">
#        <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0">
#         <h3 class="text-uppercase">
#          ACCOUNT &amp; LISTINGS
#         </h3>
#         <ul class="nav-footer">
#          <li>
#           <a href="//www.armslist.com/accountlogin/new">
#            Account Login
#           </a>
#          </li>
#          <li>
#           <a href="//www.armslist.com/account/new">
#            New Account
#           </a>
#          </li>
#          <li>
#           <a href="//www.armslist.com/posts/new">
#            Create a New Listing
#           </a>
#          </li>
#          <li>
#           <a href="//www.armslist.com/posts/resendactivation">
#            Edit or Remove a Listing
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-lg-2 col-md-3 col-sm-6">
#         <h3 class="text-uppercase">
#          ABOUT &amp; HELP
#         </h3>
#         <ul class="nav-footer">
#          <li>
#           <a href="//www.armslist.com/info/faqs">
#            FAQs
#           </a>
#          </li>
#          <li>
#           <a href="//www.armslist.com/info/contact">
#            Contact Armslist
#           </a>
#          </li>
#          <li>
#           <a href="//www.armslist.com/info/privacy">
#            Privacy Policy
#           </a>
#          </li>
#          <li>
#           <a href="//www.armslist.com/info/terms">
#            Terms of Use
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-3 col-sm-6">
#         <h3 class="text-uppercase">
#          MORE ARMSLIST LINKS
#         </h3>
#         <ul class="nav-footer">
#          <li>
#           <a href="https://www.armslist.com/blog/">
#            Armslist Blog
#           </a>
#          </li>
#          <li>
#           <a href="https://www.armslist.com/giveaways">
#            Armslist Giveaway
#           </a>
#          </li>
#          <li>
#           <a href="http://www.armslist.com/contests/">
#            Armslist Contests
#           </a>
#          </li>
#          <li>
#           <a href="http://www.armslistlegaldefensefund.com/">
#            Armslist Legal Defense Fund
#           </a>
#          </li>
#          <li>
#           <a href="//www.armslist.com/info/advertise">
#            Advertising with Armslist
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-3 col-sm-6">
#         <h3 class="text-uppercase">
#          PARTNER SITES
#         </h3>
#         <ul class="nav-footer">
#          <li>
#           <a href="http://www.torquelist.com/">
#            Torquelist Vehicle Trader
#           </a>
#          </li>
#          <li>
#           <a href="http://www.rangemonkey.com/">
#            Range Monkey
#           </a>
#          </li>
#          <li>
#           <a href="http://www.invictusgearcompany.com/">
#            Invictus Gear
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="container-fluid">
#      <div class="row">
#       <div class="col-md-6 col-md-offset-3 col-sm-8 col-sm-offset-2">
#        <ul class="social-list">
#         <li>
#          <a class="icon-youtube" href="http://www.youtube.com/user/armslistmedia?sub_confirmation=1" target="_blank" title="Armslist Youtube channel">
#          </a>
#         </li>
#         <li>
#          <a class="icon-instagram" href="https://instagram.com/armslist/" target="_blank" title="Armslist on Instagram">
#          </a>
#         </li>
#         <li>
#          <a class="icon-facebook" href="https://www.facebook.com/armslist" target="_blank" title="Armslist on Facebook">
#          </a>
#         </li>
#         <li>
#          <a class="icon-twitter" href="https://twitter.com/armslist" target="_blank" title="Armslist Twitter page">
#          </a>
#         </li>
#         <li>
#          <a class="icon-google-plus" href="https://plus.google.com/103978926144598391141/posts" target="_blank" title="Armslist on Google+">
#          </a>
#         </li>
#        </ul>
#        <div class="text-block">
#         <p>
#          Always comply with local, state, federal, and international law.
# ARMSLIST does not become involved in transactions between parties. Review our
#          <a href="/info/privacy">
#           privacy policy
#          </a>
#          and
#          <a href="/info/terms">
#           terms of use
#          </a>
#          for more
# information. Report Illegal Firearms Activity to 1-800-ATF-GUNS.
#         </p>
#        </div>
#        <span class="copy">
#         Copyright © 2019 Armslist, LLC |
#
#                             | Version: 15.0.2
#        </span>
#       </div>
#      </div>
#     </div>
#     <script id="LOTCC_3569" src="http://tags.crwdcntrl.net/c/3569/cc.js?ns=_cc3569" type="text/javascript">
#     </script>
#     <script language="javascript" type="text/javascript">
#      _cc3569.bcp();
#     </script>
#    </footer>
#   </div>
#   <div class="loader-box">
#    <img alt="loader" height="64" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/loader.gif" width="64"/>
#   </div>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');    ga('create', 'UA-5138407-1', 'auto');   ga('send', 'pageview');
#   </script>
#  </body>
# </html>

# %% [markdown]
# **Get the children of the main object**

# %%
list(soup.children)
# Out:
# ['\n', 'html', '\n', <html>
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <title>
#      ARMSLIST    -
#  New York
#  All Categories
#  Classifieds
#  </title>
#  <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
#  <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css" rel="stylesheet"/>
#  <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css" rel="stylesheet"/>
#  <link href="//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700" rel="stylesheet" type="text/css"/>
#  <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
#  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
#  <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
#  <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/js/jquery.main.js" type="text/javascript"></script>
#  <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.5/js/bootstrap.min.js"></script>
#  <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/lib/jquery-cookie.js" type="text/javascript"></script>
#  <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/listmill-app.js" type="text/javascript"></script>
#  <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/jquery-listmill.js" type="text/javascript"></script>
#  <script type="text/javascript">
#              var appOptions = {
#                  showTermsOnLoad: "true" == "true" ? true : false,
#                  showTermsOnLoadTimeout: 0};
#
#              $(function () {
#                  if(appOptions.showTermsOnLoad) {
#                      checkTerms();
#                  }
#              });
#
#              function checkTerms() {
#                  if ((document.cookie.length == 0 || document.cookie.indexOf("terms=agreed") == -1)
#                      && window.location.href.indexOf("/info/terms") == -1
#                      && document.cookie.indexOf("listmill_auth") == -1) {
#                      showTerms();
#                  } else
#                      acceptTerms();
#              }
#
#              function acceptTerms() {
#                  var dateStr = "";
#                  if (appOptions.showTermsOnLoadTimeout > 0) {
#                      date = new Date();
#                      date.setHours(date.getHours() + appOptions.showTermsOnLoadTimeout);
#                      dateStr = "; expires=" + date.toUTCString();
#                  };
#                  document.cookie = "terms=agreed" + dateStr + "; path=/";
#
#                  $('#termsModal').modal('hide');
#
#                  //show dropin after terms are agreed
#                  //showDropin();
#              }
#
#              function showTerms() {
#                  //termsModalContainer
#                  $.ajax({
#                      url: "/info/termsagreement",
#                      dataType: "html",
#                      success: function (data) {
#                          $("#termsModalContainer").html(data);
#
#                          $('#termsModal').modal({
#                              backdrop: 'static',
#                              keyboard: false
#                          });
#
#                          $('#termsModal').modal('show');
#                      }});
#              }
#
#              function showDropin() {
#                  if(document.cookie.indexOf("dropin=true") == -1) {
#                      $.ajax({
#                          url: "/info/dropin",
#                          dataType: "html",
#                          success: function (data) {
#                              $("#dropinModalContainer").html(data);
#
#                              $('#dropinModal').modal({
#                                  backdrop: 'static',
#                                  keyboard: true
#                              });
#
#                              $('#dropinModal').modal('show');
#                          }});
#                  }
#              }
#
#              function saveDropin() {
#                  $.post( "/info/dropin", "email=" +$('#dropinModalTextBox').val() );
#                  setDropinCookie();
#              }
#
#              function noThanksDropin() {
#                  setDropinCookie();
#              }
#
#              function setDropinCookie() {
#                  var dateStr = "";
#                  date = new Date();
#                  // 2190 = 3 months, cookie expires in 3 months
#                  date.setHours(date.getHours() + 2190);
#                  dateStr = "; expires=" + date.toUTCString();
#                  document.cookie = "dropin=true" + dateStr + "; path=/";
#
#                  $('#dropinModal').modal('hide');
#              }
#
#          </script>
#  <meta content="Classifieds listings of All Categories in New York" name="description">
#  <meta content="New York, All Categories, classifieds" name="keywords"/>
#  <style type="text/css">
#          .youtube_container {
#          position: relative;
#          width: 100%;
#          height: 0;
#          padding-bottom: 56.25%;
#          clear: both;
#      }
#      .youtube_video {
#          position: absolute;
#          top: 0;
#          left: 0;
#          width: 100%;
#          height: 100%;
#      }
#      .blink_me {
#          animation: blinker 1s linear infinite;
#      }
#
#      @keyframes blinker {
#        50% {
#          opacity: 0;
#        }
#      }
#      </style>
#  <!-- -->
#  <!--                <style type="text/css">
#          .footer-social {  width: 100px;  margin-right: 0px !important;}
#          </style>
#  -->
#  <style type="text/css">
#              #h3Overrides h3 {
#                  margin-top: 0px;
#                  color: #000000;
#              }
#          </style>
#  <!-- Javascript tag: -->
#  <!-- begin ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
#  <script language="JavaScript">
#  var zflag_nid="305"; var zflag_cid="56890/56889/1"; var zflag_sid="5734"; var zflag_width="1"; var zflag_height="1"; var zflag_sz="15"; var zflag_click="[INSERT_CLICK_TRACKER_MACRO]"; var zflag_page="[INSERT_PAGE_URL]";
#  </script>
#  <script language="JavaScript" src="http://c5.zedo.com/jsc/c5/fo.js"></script>
#  <!-- end ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
#  <!--ALC script-->
#  <script>
#      var _alcTag = _alcTag || [];
#      (function () {
#          var atag = document.createElement('script');
#          atag.async = 1;
#          atag.src = '//al-p.alcmpn.com/wt/388/webtag.js';
#          var node = document.getElementsByTagName('script')[0];
#          node.parentNode.insertBefore(atag, node);
#      })();
#
#          </script>
#  <!--End ALC script-->
#  <!-- OneTag Container: armslist-->
#  </meta></head>
#  <body style="-webkit-overflow-scrolling: touch;">
#  <div class="modal fade" id="termsModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <h4 style="color: #655d5b">TERMS OF USE</h4>
#  </div>
#  <div class="modal-body">
#  <div id="termsModalContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-default" onclick="acceptTerms()" type="button">Accept</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="promotionModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <h4 style="color: #655d5b">PROMOTIONAL LINK</h4>
#  </div>
#  <div class="modal-body">
#  <div id="promotionModalContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="filterByModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <button class="close" data-dismiss="modal" type="button">×</button>
#  <h4 style="color: #655d5b">Filter By</h4>
#  </div>
#  <div class="modal-body">
#  <div id="filterByContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="dropinModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <h4 style="color: #655d5b">Armslist</h4>
#  </div>
#  <div class="modal-body">
#  <div id="dropinModalContainer"></div>
#  <input id="dropinModalTextBox" type="text"/>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-default" onclick="noThanksDropin()" style="float: left;" type="button">Close</button>
#  <button class="btn btn-primary" onclick="saveDropin()" type="button">Submit</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="contactSellerEmailModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <button class="close" data-dismiss="modal" type="button">×</button>
#  <h4 style="color: #655d5b">Contact Seller</h4>
#  </div>
#  <div class="modal-body">
#  <div id="messageSellerContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="pull-left btn btn-default" id="contactFormSubmitBtn" onclick="doMessageSend()" type="button">Send</button>
#  <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="searchAlertModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <button class="close" data-dismiss="modal" type="button">×</button>
#  <h4 style="color: #655d5b">Search Alert</h4>
#  </div>
#  <div class="modal-body">
#  <div id="searchAlertContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="pull-left btn btn-default" id="searchAlertFormSubmitBtn" onclick="createSearchAlert()" type="button">Create</button>
#  <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div id="wrapper">
#  <header class="navbar-default text-uppercase" id="header" role="navigation">
#  <div class="top-holder">
#  <div class="container-fluid">
#  <button class="navbar-toggle text-uppercase pull-left" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" id="popoverMobileViewMainMenu" type="button">
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="text">Menu</span>
#  </button>
#  <div id="popovercontentMobileViewMainMenu" style="display: none;">
#  <div class="container-fluid">
#  <div class="row" id="h3Overrides">
#  <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
#  </div>
#  </div>
#  </div>
#  <script type="text/javascript">
#                          $(document).ready(function () {
#
#                              $("#popoverMobileViewMainMenu").popover({
#                                  html: true,
#                                  container: 'body',
#                                  content: function () {
#                                      return $('#popovercontentMobileViewMainMenu').html();
#                                  }
#                              });
#
#                              $('html').on('click', function (e) {
#                                  if (typeof $(e.target).data('original-title') == 'undefined' &&
#                                      !$(e.target).parents().is('.popover.in') &&
#                                      $(e.target).parent().attr("id") !== "popoverMobileViewMainMenu") {
#                                      $('[data-original-title]').popover('hide');
#                                  }
#                              });
#                          });
#
#                      </script>
#  <div class="pull-right align-right">
#  <form action="/classifieds/search" class="search-form navbar-form hidden-xs" method="get" role="search"> <fieldset>
#  <div class="form-group">
#  <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
#  <input name="location" type="hidden" value="new-york">
#  <input name="category" type="hidden" value="all"/>
#  <input name="posttype" type="hidden" value="7"/>
#  <input name="ships" type="hidden"/>
#  </input></div>
#  <button class="btn btn-default icon-search" type="submit"></button>
#  </fieldset>
#  </form>
#  <a class="btn btn-warning create-btn text-uppercase" href="/posts/new"><span class="hidden-sm hidden-xs">CREATE A LISTING</span> <i class="icon-pencil"></i> <span class="visible-sm visible-xs">list</span></a>
#  <ul class="users-list hidden-xs">
#  <li><a href="/account/new">CREATE AN ACCOUNT</a></li>
#  <li><a href="/accountlogin">LOGIN</a></li>
#  </ul>
#  <button class="btn btn-warning create-btn text-uppercase visible-xs" onclick="showHideSearchMobile()" type="button"><i class="icon-search"></i> <span class="visible-xs">search</span></button>
#  <script type="text/javascript">
#                              function showHideSearchMobile() {
#                                  $("#searchMobileView").fadeToggle();
#                              }
#                          </script>
#  </div>
#  <div class="pull-left" id="logo">
#  <a href="/" title="ARMSLIST - Firearms Classifieds">
#  <picture>
#  <!--[if IE 9]><video style="display: none;"><![endif]-->
#  <source media="(max-width: 767px)" srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile@2x.png 2x"/>
#  <source srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop@2x.png 2x"/>
#  <!--[if IE 9]></video><![endif]-->
#  <img alt="armslist firearms marketplace" height="66" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png" width="260"/>
#  </picture>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="hidden-xs"><br/><br/></div>
#  <div class="alert " id="mainMessageContainer" style="display: none; margin-bottom: 0px;">
#  <div id="mainMessageContainer_Message" style="text-align: center;"></div>
#  </div>
#  <div class="hidden-sm hidden-md hidden-lg" id="searchMobileView" style="padding: 20px 10px 10px 20px; text-align: center; display: none;">
#  <form action="/classifieds/search" class="search-form" method="get" role="search" style="width: 75% !important;"> <fieldset>
#  <div class="form-group">
#  <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
#  <input name="location" type="hidden" value="new-york">
#  <input name="category" type="hidden" value="all"/>
#  <input name="posttype" type="hidden" value="7"/>
#  <input name="ships" type="hidden"/>
#  </input></div>
#  <button class="btn btn-default icon-search" type="submit"></button>
#  </fieldset>
#  </form> <br/>
#  <div class="carousel slide" data-ride="carousel" id="myCarousel" style="padding-top: 20px;">
#  <!-- Wrapper for slides -->
#  <div class="carousel-inner" role="listbox">
#  <div class="item active">
#  <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
#  <a href="/classifieds/search?category=handguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">HANDGUNS <br/><i class="icon-handguns"></i></a>
#  <a href="/classifieds/search?category=shotguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">SHOTGUNS <br/><i class="icon-shotguns"></i></a>
#  <a href="/classifieds/search?category=rifles&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">RIFLES <br/><i class="icon-rifles"></i></a>
#  </div>
#  </div>
#  <div class="item">
#  <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
#  <a href="/classifieds/search?category=firearm-accessories&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">ACCESSORIES <br/><i class="icon-scope"></i></a>
#  <a href="/classifieds/search?category=outdoors&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">GEAR + MORE <br/><i class="icon-gear"></i></a>
#  </div>
#  </div>
#  </div>
#  <!-- Left and right controls -->
#  <a class="left carousel-control" data-slide="prev" href="#myCarousel" role="button">
#  <span aria-hidden="true" class="glyphicon glyphicon-chevron-left"></span>
#  <span class="sr-only">Previous</span>
#  </a>
#  <a class="right carousel-control" data-slide="next" href="#myCarousel" role="button">
#  <span aria-hidden="true" class="glyphicon glyphicon-chevron-right"></span>
#  <span class="sr-only">Next</span>
#  </a>
#  </div>
#  <style type="text/css">
#                      .carousel-control.left, .carousel-control.right {
#                          background-image: none;
#                      }
#                  </style>
#  </div>
#  </header>
#  <main id="main">
#  <div class="container-fluid" style="color: #655D5B;">
#  <div id="bootstrap-overrides">
#  <div class="col-xs-12 col-md-4" style="padding-top: 15px;">
#  <h3>1 - 15 of 1118 results in All Categories</h3>
#  </div>
#  <div class="col-xs-12 col-md-8">
#  <div class="col-xs-3 col-md-3" style="padding: 15px 0px 0px 0px; margin: 0px;">
#  <a class="hidden-md hidden-lg" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Alert</a>
#  <a class="hidden-xs hidden-sm" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Set a Search Alert</a>
#  <script type="text/javascript">
#                  function newInitRecaptcha() {
#                      $.getScript("https://www.google.com/recaptcha/api/js/recaptcha_ajax.js", function () {
#                          Recaptcha.create(
#                              RecaptchaOptions.publicKey,     // public key, declared in Recaptcha view
#                              "recaptchaControls",            // id
#                              RecaptchaOptions                // options, declared in Recaptcha view
#                          );
#                      });
#                  }
#
#                  function doCreateSearchAlert(obj) {
#                      //var $dialog = $("#searchAlertDialog");
#                      //if ($dialog.length == 0) {
#                      //    $dialog = $('<div id="searchAlertDialog"></div>');
#                      //    $("body").append($dialog);
#                      //}
#                      //$dialog.html("");
#                      $.ajax({
#                          url: "/searchalerts/new",
#                          cache: false,
#                          success: function (data) {
#                              $("#searchAlertContainer").html(data);
#                              newInitRecaptcha();
#                              //$dialog.html(data);
#                              //listmill.app.initRecaptcha();
#                              //$dialog.dialog({
#                              //    title: "New Search Alert",
#                              //    modal: true,
#                              //    width: 460,
#                              //    buttons: [
#                              //        { text: "Create", click: createSearchAlert },
#                              //        { text: "Cancel", click: function () { $(this).dialog("close"); } },
#                              //    ]
#                              //});
#                              //$("#name").focus();
#                          }
#                      });
#                      return false;
#                  }
#
#                  function createSearchAlert() {
#                      var $dialog = $("#searchAlertContainer");
#                      var $form = $dialog.find("form");
#                      $.ajax({
#                          url: $form.attr("action"),
#                          type: "POST",
#                          data: $form.serialize(),
#                          success: createSearchAlertCallback,
#                          error: function () {
#                              $('#searchAlertModal').modal('hide');
#                              alert("There was a problem creating the search alert.");
#                          }
#                      });
#                  }
#
#                  function createSearchAlertCallback(data) {
#                      if (data === "success") {
#
#                          $('#searchAlertModal').modal('hide');
#                          alert("Search Alert Created");
#                          //listmill.app.showMessage("success", "Search Alert successfully created! You should receive a confirmation email shortly.");
#                          //$("#searchAlertDialog").dialog("close");
#                      } else {
#                          $("#searchAlertContainer").html(data);
#                          newInitRecaptcha();
#                          //var $dialog = $("#searchAlertDialog");
#                          //$dialog.html(data);
#                          //$dialog.dialog("open");
#                          //listmill.app.initRecaptcha();
#                      }
#                  }
#              </script>
#  </div>
#  <div class="col-xs-4 col-md-4" style="padding: 15px 0px 0px 0px;">
#  <a class="" href="/deals" style="color: #cb2027;"><i class="fa fa-star"></i> Deals <i class="fa fa-star"></i></a>
#  </div>
#  <div class="hidden-md hidden-lg" style="float: right; padding: 15px 0px 15px 15px; position: relative;">
#  <!--<a data-placement="bottom" id="popoverMobileView" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>-->
#  <a data-target="#filterByModal" data-toggle="modal" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>
#  <div id="popovercontentMobileView" style="display: none;">
#  <div style="padding: 10px; text-align: center;">
#  <a class="clear-all" href="/classifieds/search?location=new-york&amp;category=all" title="Remove All">Clear All</a>
#  </div>
#  <div style="padding: 10px; border-top: solid 1px #aaaaaa; border-bottom: solid 1px #aaaaaa;">
#  <table style="width: 100%">
#  <tr>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  Private Party<br>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=4&amp;ships=False"></a>
#  </br></td>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  Premium Vendor<br>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=1&amp;ships=False"></a>
#  </br></td>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  Vendors that Ship<br>
#  <a class="class_checkbox " href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=True"></a>
#  </br></td>
#  </tr>
#  <tr><td colspan="3" style="border-top: solid 1px #aaaaaa;"> </td></tr>
#  <tr>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  For Sale<br>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=6&amp;ships=False"></a>
#  </br></td>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  For Trade<br>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=5&amp;ships=False"></a>
#  </br></td>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  Want to Buy<br/>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=3&amp;ships=False"></a>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 20px;">
#  <h3 style="color: #555555;">LOCATION</h3>
#  <div style="position: relative; color: #000000; background: url('https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png') no-repeat center;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png" style="opacity: 0;"/>
#  <div style="position: absolute; top: 20%; width: 100%; text-align: center;">
#                                      Searching in<br/>
#  <h2 style="font-weight: bold; color: #000000;">
#  New York
#                                      </h2>
#  </div>
#  </div>
#  <br/>
#  <div>
#  <select id="locationDDL" name="stateDDL" onchange="changeLocation(this)" style="color: #000000;">
#  <option value="">State</option>
#  <option value="/classifieds/search?location=alabama&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Alabama
#                                      </option>
#  <option value="/classifieds/search?location=alaska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Alaska
#                                      </option>
#  <option value="/classifieds/search?location=arizona&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Arizona
#                                      </option>
#  <option value="/classifieds/search?location=arkansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Arkansas
#                                      </option>
#  <option value="/classifieds/search?location=california&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          California
#                                      </option>
#  <option value="/classifieds/search?location=colorado&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Colorado
#                                      </option>
#  <option value="/classifieds/search?location=connecticut&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Connecticut
#                                      </option>
#  <option value="/classifieds/search?location=delaware&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Delaware
#                                      </option>
#  <option value="/classifieds/search?location=florida&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Florida
#                                      </option>
#  <option value="/classifieds/search?location=georgia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Georgia
#                                      </option>
#  <option value="/classifieds/search?location=guam-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Guam
#                                      </option>
#  <option value="/classifieds/search?location=hawaii&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Hawaii
#                                      </option>
#  <option value="/classifieds/search?location=idaho&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Idaho
#                                      </option>
#  <option value="/classifieds/search?location=illinois&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Illinois
#                                      </option>
#  <option value="/classifieds/search?location=indiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Indiana
#                                      </option>
#  <option value="/classifieds/search?location=iowa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Iowa
#                                      </option>
#  <option value="/classifieds/search?location=kansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Kansas
#                                      </option>
#  <option value="/classifieds/search?location=kentucky&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Kentucky
#                                      </option>
#  <option value="/classifieds/search?location=louisiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Louisiana
#                                      </option>
#  <option value="/classifieds/search?location=maine&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Maine
#                                      </option>
#  <option value="/classifieds/search?location=maryland&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Maryland
#                                      </option>
#  <option value="/classifieds/search?location=massachusetts&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Massachusetts
#                                      </option>
#  <option value="/classifieds/search?location=michigan&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Michigan
#                                      </option>
#  <option value="/classifieds/search?location=minnesota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Minnesota
#                                      </option>
#  <option value="/classifieds/search?location=mississippi&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Mississippi
#                                      </option>
#  <option value="/classifieds/search?location=missouri&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Missouri
#                                      </option>
#  <option value="/classifieds/search?location=montana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Montana
#                                      </option>
#  <option value="/classifieds/search?location=nebraska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Nebraska
#                                      </option>
#  <option value="/classifieds/search?location=nevada&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Nevada
#                                      </option>
#  <option value="/classifieds/search?location=new-hampshire&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          New Hampshire
#                                      </option>
#  <option value="/classifieds/search?location=nj&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          New Jersey
#                                      </option>
#  <option value="/classifieds/search?location=new-mexico&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          New Mexico
#                                      </option>
#  <option selected="selected" value="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          New York
#                                      </option>
#  <option value="/classifieds/search?location=north-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          North Carolina
#                                      </option>
#  <option value="/classifieds/search?location=north-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          North Dakota
#                                      </option>
#  <option value="/classifieds/search?location=ohio&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Ohio
#                                      </option>
#  <option value="/classifieds/search?location=oklahoma&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Oklahoma
#                                      </option>
#  <option value="/classifieds/search?location=oregon&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Oregon
#                                      </option>
#  <option value="/classifieds/search?location=pennsylvania&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Pennsylvania
#                                      </option>
#  <option value="/classifieds/search?location=puerto-rico-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Puerto Rico
#                                      </option>
#  <option value="/classifieds/search?location=rhode-island&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Rhode Island
#                                      </option>
#  <option value="/classifieds/search?location=south-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          South Carolina
#                                      </option>
#  <option value="/classifieds/search?location=south-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          South Dakota
#                                      </option>
#  <option value="/classifieds/search?location=tennessee&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Tennessee
#                                      </option>
#  <option value="/classifieds/search?location=texas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Texas
#                                      </option>
#  <option value="/classifieds/search?location=utah&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Utah
#                                      </option>
#  <option value="/classifieds/search?location=vermont&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Vermont
#                                      </option>
#  <option value="/classifieds/search?location=virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Virginia
#                                      </option>
#  <option value="/classifieds/search?location=washington&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Washington
#                                      </option>
#  <option value="/classifieds/search?location=west-virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          West Virginia
#                                      </option>
#  <option value="/classifieds/search?location=wisconsin&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Wisconsin
#                                      </option>
#  <option value="/classifieds/search?location=wyoming&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Wyoming
#                                      </option>
#  </select>
#  <br/> <select name="cityDDL" onchange="changeLocation(this)" style="color: #000000; margin-top: 10px;">
#  <option value="">City</option>
#  <option value="/classifieds/search?location=adirondacks-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Adirondacks
#                                      </option>
#  <option value="/classifieds/search?location=albany-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Albany
#                                      </option>
#  <option value="/classifieds/search?location=binghamton-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Binghamton
#                                      </option>
#  <option value="/classifieds/search?location=buffalo-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Buffalo
#                                      </option>
#  <option value="/classifieds/search?location=hudson-valley-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Hudson Valley
#                                      </option>
#  <option value="/classifieds/search?location=long-island-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Long Island
#                                      </option>
#  <option value="/classifieds/search?location=rochester-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Rochester
#                                      </option>
#  <option value="/classifieds/search?location=syracuse-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Syracuse
#                                      </option>
#  <option value="/classifieds/search?location=tri-state-area&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Tri-state area
#                                      </option>
#  <option value="/classifieds/search?location=watertown&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Watertown
#                                      </option>
#  </select>
#  </div>
#  </div>
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 20px 20px 10px 20px;">
#  <div>
#  <a class="accordion-toggle chevron-rotate" data-toggle="collapse" href="#collapseCategoryMobile">
#  <h3 style="color: #5c724c;">
#  <i class="fa fa-chevron-right"></i> Category
#                                              </h3>
#  </a>
#  </div>
#  <div class="collapse " id="collapseCategoryMobile" style="border-top: solid 1px #aaaaaa;">
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=guns&amp;posttype=7&amp;ships=False">
#  <td><h4 style="color: #5c724c; font-weight: 400;">Firearms</h4></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  <div class="collapse " id="collapsegunsMobile" style="padding: 0px 0px 0px 20px;">
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=antiques&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Antique Firearms</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=handguns&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Handguns</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=muzzle-loaders&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Muzzle Loaders</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=nfa-firearms&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">NFA Firearms</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=rifles&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Rifles</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=shotguns&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Shotguns</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  </div>
#  </div>
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=firearm-accessories&amp;posttype=7&amp;ships=False">
#  <td><h4 style="color: #5c724c; font-weight: 400;">Firearm Accessories</h4></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  <div class="collapse " id="collapsefirearm-accessoriesMobile" style="padding: 0px 0px 0px 20px;">
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=ammo&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Ammo</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-parts&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Gun Parts</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-safes&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Gun Safes</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=holsters&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Holsters</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=magazines&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Magazines</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=optics&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Optics</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=reloading&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Reloading</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=tactical-gear&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Tactical Gear</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  </div>
#  </div>
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=outdoors&amp;posttype=7&amp;ships=False">
#  <td><h4 style="color: #5c724c; font-weight: 400;">Outdoors Gear</h4></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  <div class="collapse " id="collapseoutdoorsMobile" style="padding: 0px 0px 0px 20px;">
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=archery&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Archery</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
# ...
#  //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=aa79cc16&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=46&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=aa79cc16"/></a></noscript>
#  </div>
#  <div class="ad-search">
#  <!--/*
#    *
#    * Revive Adserver Javascript Tag
#    * - Generated with Revive Adserver v3.2.2
#    *
#    */-->
#  <!--/*
#    * The backup image section of this tag has been generated for use on a
#    * non-SSL page. If this tag is to be placed on an SSL page, change the
#    *   'http://revive.armslist.com/revive/www/delivery/...'
#    * to
#    *   'https://revive.armslist.com/revive/www/delivery/...'
#    *
#    * This noscript section of this tag only shows image banners. There
#    * is no width or height in these banners, so if you want these tags to
#    * allocate space for the ad before it shows, you will need to add this
#    * information to the <img> tag.
#    *
#    * If you do not want to deal with the intricities of the noscript
#    * section, delete the tag (from <noscript>... to </noscript>). On
#    * average, the noscript tag is called from less than 1% of internet
#    * users.
#    */-->
#  <script type="text/javascript"><!--//<![CDATA[
#     var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
#  var m3_r = Math.floor(Math.random()*99999999999);
#  if (!document.MAX_used) document.MAX_used = ',';
#  document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
#  document.write ("?zoneid=48");
#  document.write ('&amp;cb=' + m3_r);
#  if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
#  document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
#  document.write ("&amp;loc=" + escape(window.location));
#  if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
#  if (document.context) document.write ("&context=" + escape(document.context));
#  if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
#  document.write ("'><\/scr"+"ipt>");
#  //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=af067137&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=48&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=af067137"/></a></noscript>
#  </div>
#  <div class="ad-search">
#  <!--/*
#    *
#    * Revive Adserver Javascript Tag
#    * - Generated with Revive Adserver v3.2.2
#    *
#    */-->
#  <!--/*
#    * The backup image section of this tag has been generated for use on a
#    * non-SSL page. If this tag is to be placed on an SSL page, change the
#    *   'http://revive.armslist.com/revive/www/delivery/...'
#    * to
#    *   'https://revive.armslist.com/revive/www/delivery/...'
#    *
#    * This noscript section of this tag only shows image banners. There
#    * is no width or height in these banners, so if you want these tags to
#    * allocate space for the ad before it shows, you will need to add this
#    * information to the <img> tag.
#    *
#    * If you do not want to deal with the intricities of the noscript
#    * section, delete the tag (from <noscript>... to </noscript>). On
#    * average, the noscript tag is called from less than 1% of internet
#    * users.
#    */-->
#  <script type="text/javascript"><!--//<![CDATA[
#     var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
#  var m3_r = Math.floor(Math.random()*99999999999);
#  if (!document.MAX_used) document.MAX_used = ',';
#  document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
#  document.write ("?zoneid=47");
#  document.write ('&amp;cb=' + m3_r);
#  if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
#  document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
#  document.write ("&amp;loc=" + escape(window.location));
#  if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
#  if (document.context) document.write ("&context=" + escape(document.context));
#  if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
#  document.write ("'><\/scr"+"ipt>");
#  //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=ae5ac2c4&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=47&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=ae5ac2c4"/></a></noscript>
#  </div>
#  <div style="padding-top: 10px;">
#  <div style='background-color: #2f2d24; text-align: left; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
#  <h2 style="color: #e5e0bf; padding: 5px;">Latest Video</h2>
#  </div>
#  <iframe allowfullscreen="" class="youtube_video" frameborder="0" src="https://www.youtube.com/embed?max-results=1&amp;controls=0&amp;showinfo=0&amp;rel=0&amp;listType=user_uploads&amp;list=ArmslistMedia"></iframe>
#  <div style="clear: both;"> </div>
#  </div>
#  <script type="text/javascript">
#                                  $(document).ready(function () {
#                                      $(".youtube_video").wrap('<div class="youtube_container">');
#                                  });
#                              </script>
#  <div id="rcjsload_dc470c"></div>
#  <script type="text/javascript">
#                                  (function () {
#                                      var referer = ""; try { if (referer = document.referrer, "undefined" == typeof referer || "" == referer) throw "undefined" } catch (exception) { referer = document.location.href, ("" == referer || "undefined" == typeof referer) && (referer = document.URL) } referer = referer.substr(0, 700);
#                                      var rcds = document.getElementById("rcjsload_dc470c");
#                                      var rcel = document.createElement("script");
#                                      rcel.id = 'rc_' + Math.floor(Math.random() * 1000);
#                                      rcel.type = 'text/javascript';
#                                      rcel.src = "//trends.revcontent.com/serve.js.php?w=109511&t=" + rcel.id + "&c=" + (new Date()).getTime() + "&width=" + (window.outerWidth || document.documentElement.clientWidth) + "&referer=" + encodeURIComponent(referer);
#                                      rcel.async = true;
#                                      rcds.appendChild(rcel);
#                                  })();
#                              </script>
#  </div>
#  </div>
#  <style type="text/css">
#                      .ad-search {
#                          margin-top: 16px;
#                      }
#                      .popover{
#                          max-width: none;
#                          width: 300px;
#                      }
#
#                      #bootstrap-overrides h2, #filterByContainer h2 {
#                          margin-top: 0px;
#                      }
#
#                      #bootstrap-overrides h3, #filterByContainer h3 {
#                          margin-top: 0px;
#                          color: #000000;
#                          font-weight: bold;
#                      }
#                      .class_checkbox {
#                          display: inline-block;
#                          padding-top: 4px;
#                          width: 43px;
#                          height: 27px;
#                          background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/OFF_desktop.png);
#                          cursor: pointer;
#
#                      }
#
#                      .class_checkbox.checked {
#                          background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/ON_desktop.png);
#                      }
#
#                      .switches {
#                          font-weight: bold;
#                          color: #000000;
#                      }
#
#                      .clickable-row {
#                          cursor: pointer;
#                      }
#                  </style>
#  <script type="text/javascript">
#
#
#                      function changeLocation(location) {
#                          if (location) {
#                              window.location = $(location).val();;
#                          }
#                          return false;
#                      }
#
#                      $(document).on("click", ".clickable-row", function () {
#                          window.document.location = $(this).data("href");
#
#                      });
#
#                      $(document).on("click", ".chevron-rotate", function () {
#                          if ($(this).parent().find(".fa-chevron-right").length) {
#                              $(this).parent().find(".fa-chevron-right").removeClass("fa-chevron-right").addClass("fa-chevron-down");
#                          } else {
#                              $(this).parent().find(".fa-chevron-down").removeClass("fa-chevron-down").addClass("fa-chevron-right");
#                          }
#                      });
#
#
#                  </script>
#  <!-- HACK FOR EDS -->
#  <table style="display: none;">
#  <tr><td class="title"><a href="/posts/9571384/long-island-new-york-optics-for-sale--vortex-viper">FS: Vortex Viper</a></td></tr>
#  <tr><td class="title"><a href="/posts/9789750/long-island-new-york-rifles-for-sale-trade--chiappa-1892-alaskan-take-down">FS/FT: Chiappa 1892 Alaskan Take Down</a></td></tr>
#  <tr><td class="title"><a href="/posts/9572179/long-island-new-york-gun-parts-for-sale--rossi-coach-gun-overland-parts">FS: Rossi Coach Gun Overland Parts</a></td></tr>
#  <tr><td class="title"><a href="/posts/9503782/long-island-new-york-shotguns-for-sale-trade--rossi-chrome-coach-gun-rare">FS/FT: Rossi Chrome Coach Gun Rare</a></td></tr>
#  <tr><td class="title"><a href="/posts/9504240/long-island-new-york-shotguns-for-sale--savage-24--22lr-over-20ga-">FS: Savage 24  22lr Over 20ga.</a></td></tr>
#  <tr><td class="title"><a href="/posts/9874160/long-island-new-york-shotguns-for-sale--remington-coach-gun-new-old-stock">FS: Remington Coach Gun New Old Stock</a></td></tr>
#  <tr><td class="title"><a href="/posts/10074126/long-island-new-york-rifles-for-sale--ruger-m77-hawkeye-tactical--308">FS: Ruger m77 Hawkeye Tactical .308</a></td></tr>
#  <tr><td class="title"><a href="/posts/10075280/long-island-new-york-shotguns-for-sale--rossi-overland-coach-gun-">FS: Rossi Overland Coach Gun </a></td></tr>
#  <tr><td class="title"><a href="/posts/10078638/long-island-new-york-ammo-for-sale--remington--22-win-mag-case">FS: Remington .22 Win Mag case</a></td></tr>
#  <tr><td class="title"><a href="/posts/10078666/long-island-new-york-ammo-for-sale--winchester--410-pdx1-defender-ammo">FS: Winchester .410 PDX1 Defender Ammo</a></td></tr>
#  <tr><td class="title"><a href="/posts/10078487/watertown-handguns-for-sale--ruger-security-six--357">FS: Ruger Security Six .357</a></td></tr>
#  <tr><td class="title"><a href="/posts/10110105/rochester-new-york-handguns-for-sale---glock-45-9mm-10rd-3-mags-frt-ser">FS:  GLOCK 45 9MM 10RD 3 MAGS FRT SER</a></td></tr>
#  <tr><td class="title"><a href="/posts/10059192/rochester-new-york-handguns-for-sale--taurus-605">FS: Taurus 605</a></td></tr>
#  <tr><td class="title"><a href="/posts/7876495/rochester-new-york-holsters-for-sale--ruger-lcpii-kydex-holster-and-ruger-mag">FS: Ruger LCPII kydex holster and Ruger mag</a></td></tr>
#  <tr><td class="title"><a href="/posts/7959698/rochester-new-york-handguns-for-sale--taylor---co---uberti--smoke-wagon--357">FS: Taylor &amp; Co. (Uberti) Smoke Wagon .357</a></td></tr>
#  </table>
#  </div>
#  </main>
#  <style type="text/css"> body { overflow: visible; } </style>
#  <footer id="footer" style="display: table;">
#  <div class="top-hold hidden-xs">
#  <div class="container-fluid">
#  <div class="row">
#  <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
#  </div>
#  </div>
#  </div>
#  <div class="container-fluid">
#  <div class="row">
#  <div class="col-md-6 col-md-offset-3 col-sm-8 col-sm-offset-2">
#  <ul class="social-list">
#  <li>
#  <a class="icon-youtube" href="http://www.youtube.com/user/armslistmedia?sub_confirmation=1" target="_blank" title="Armslist Youtube channel"></a>
#  </li>
#  <li>
#  <a class="icon-instagram" href="https://instagram.com/armslist/" target="_blank" title="Armslist on Instagram"></a>
#  </li>
#  <li>
#  <a class="icon-facebook" href="https://www.facebook.com/armslist" target="_blank" title="Armslist on Facebook"></a>
#  </li>
#  <li>
#  <a class="icon-twitter" href="https://twitter.com/armslist" target="_blank" title="Armslist Twitter page"></a>
#  </li>
#  <li>
#  <a class="icon-google-plus" href="https://plus.google.com/103978926144598391141/posts" target="_blank" title="Armslist on Google+"></a>
#  </li>
#  </ul>
#  <div class="text-block">
#  <p>Always comply with local, state, federal, and international law.
#  ARMSLIST does not become involved in transactions between parties. Review our
#  <a href="/info/privacy">privacy policy</a> and <a href="/info/terms">terms of use</a> for more
#  information. Report Illegal Firearms Activity to 1-800-ATF-GUNS.  </p>
#  </div>
#  <span class="copy">
#                              Copyright © 2019 Armslist, LLC |
#
#                              | Version: 15.0.2
#                          </span>
#  </div>
#  </div>
#  </div>
#  <script id="LOTCC_3569" src="http://tags.crwdcntrl.net/c/3569/cc.js?ns=_cc3569" type="text/javascript"></script>
#  <script language="javascript" type="text/javascript"> _cc3569.bcp(); </script>
#  </footer>
#  </div>
#  <div class="loader-box">
#  <img alt="loader" height="64" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/loader.gif" width="64"/>
#  </div>
#  <script>   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');    ga('create', 'UA-5138407-1', 'auto');   ga('send', 'pageview');  </script>
#  </body>
#  </html>, '\n']

# %%
list(soup.children)[3]
# Out:
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
#     ARMSLIST    -
# New York
# All Categories
# Classifieds
# </title>
# <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
# <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css" rel="stylesheet"/>
# <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css" rel="stylesheet"/>
# <link href="//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
# <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/js/jquery.main.js" type="text/javascript"></script>
# <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.5/js/bootstrap.min.js"></script>
# <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/lib/jquery-cookie.js" type="text/javascript"></script>
# <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/listmill-app.js" type="text/javascript"></script>
# <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/jquery-listmill.js" type="text/javascript"></script>
# <script type="text/javascript">
#             var appOptions = {
#                 showTermsOnLoad: "true" == "true" ? true : false,
#                 showTermsOnLoadTimeout: 0};
#
#             $(function () {
#                 if(appOptions.showTermsOnLoad) {
#                     checkTerms();
#                 }
#             });
#
#             function checkTerms() {
#                 if ((document.cookie.length == 0 || document.cookie.indexOf("terms=agreed") == -1)
#                     && window.location.href.indexOf("/info/terms") == -1
#                     && document.cookie.indexOf("listmill_auth") == -1) {
#                     showTerms();
#                 } else
#                     acceptTerms();
#             }
#
#             function acceptTerms() {
#                 var dateStr = "";
#                 if (appOptions.showTermsOnLoadTimeout > 0) {
#                     date = new Date();
#                     date.setHours(date.getHours() + appOptions.showTermsOnLoadTimeout);
#                     dateStr = "; expires=" + date.toUTCString();
#                 };
#                 document.cookie = "terms=agreed" + dateStr + "; path=/";
#
#                 $('#termsModal').modal('hide');
#
#                 //show dropin after terms are agreed
#                 //showDropin();
#             }
#
#             function showTerms() {
#                 //termsModalContainer
#                 $.ajax({
#                     url: "/info/termsagreement",
#                     dataType: "html",
#                     success: function (data) {
#                         $("#termsModalContainer").html(data);
#
#                         $('#termsModal').modal({
#                             backdrop: 'static',
#                             keyboard: false
#                         });
#
#                         $('#termsModal').modal('show');
#                     }});
#             }
#
#             function showDropin() {
#                 if(document.cookie.indexOf("dropin=true") == -1) {
#                     $.ajax({
#                         url: "/info/dropin",
#                         dataType: "html",
#                         success: function (data) {
#                             $("#dropinModalContainer").html(data);
#
#                             $('#dropinModal').modal({
#                                 backdrop: 'static',
#                                 keyboard: true
#                             });
#
#                             $('#dropinModal').modal('show');
#                         }});
#                 }
#             }
#
#             function saveDropin() {
#                 $.post( "/info/dropin", "email=" +$('#dropinModalTextBox').val() );
#                 setDropinCookie();
#             }
#
#             function noThanksDropin() {
#                 setDropinCookie();
#             }
#
#             function setDropinCookie() {
#                 var dateStr = "";
#                 date = new Date();
#                 // 2190 = 3 months, cookie expires in 3 months
#                 date.setHours(date.getHours() + 2190);
#                 dateStr = "; expires=" + date.toUTCString();
#                 document.cookie = "dropin=true" + dateStr + "; path=/";
#
#                 $('#dropinModal').modal('hide');
#             }
#
#         </script>
# <meta content="Classifieds listings of All Categories in New York" name="description">
# <meta content="New York, All Categories, classifieds" name="keywords"/>
# <style type="text/css">
#         .youtube_container {
#         position: relative;
#         width: 100%;
#         height: 0;
#         padding-bottom: 56.25%;
#         clear: both;
#     }
#     .youtube_video {
#         position: absolute;
#         top: 0;
#         left: 0;
#         width: 100%;
#         height: 100%;
#     }
#     .blink_me {
#         animation: blinker 1s linear infinite;
#     }
#
#     @keyframes blinker {
#       50% {
#         opacity: 0;
#       }
#     }
#     </style>
# <!-- -->
# <!--                <style type="text/css">
#         .footer-social {  width: 100px;  margin-right: 0px !important;}
#         </style>
# -->
# <style type="text/css">
#             #h3Overrides h3 {
#                 margin-top: 0px;
#                 color: #000000;
#             }
#         </style>
# <!-- Javascript tag: -->
# <!-- begin ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
# <script language="JavaScript">
# var zflag_nid="305"; var zflag_cid="56890/56889/1"; var zflag_sid="5734"; var zflag_width="1"; var zflag_height="1"; var zflag_sz="15"; var zflag_click="[INSERT_CLICK_TRACKER_MACRO]"; var zflag_page="[INSERT_PAGE_URL]";
# </script>
# <script language="JavaScript" src="http://c5.zedo.com/jsc/c5/fo.js"></script>
# <!-- end ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
# <!--ALC script-->
# <script>
#     var _alcTag = _alcTag || [];
#     (function () {
#         var atag = document.createElement('script');
#         atag.async = 1;
#         atag.src = '//al-p.alcmpn.com/wt/388/webtag.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(atag, node);
#     })();
#
#         </script>
# <!--End ALC script-->
# <!-- OneTag Container: armslist-->
# </meta></head>
# <body style="-webkit-overflow-scrolling: touch;">
# <div class="modal fade" id="termsModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">TERMS OF USE</h4>
# </div>
# <div class="modal-body">
# <div id="termsModalContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" onclick="acceptTerms()" type="button">Accept</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="promotionModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">PROMOTIONAL LINK</h4>
# </div>
# <div class="modal-body">
# <div id="promotionModalContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="filterByModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 style="color: #655d5b">Filter By</h4>
# </div>
# <div class="modal-body">
# <div id="filterByContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="dropinModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">Armslist</h4>
# </div>
# <div class="modal-body">
# <div id="dropinModalContainer"></div>
# <input id="dropinModalTextBox" type="text"/>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" onclick="noThanksDropin()" style="float: left;" type="button">Close</button>
# <button class="btn btn-primary" onclick="saveDropin()" type="button">Submit</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="contactSellerEmailModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 style="color: #655d5b">Contact Seller</h4>
# </div>
# <div class="modal-body">
# <div id="messageSellerContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="pull-left btn btn-default" id="contactFormSubmitBtn" onclick="doMessageSend()" type="button">Send</button>
# <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="searchAlertModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 style="color: #655d5b">Search Alert</h4>
# </div>
# <div class="modal-body">
# <div id="searchAlertContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="pull-left btn btn-default" id="searchAlertFormSubmitBtn" onclick="createSearchAlert()" type="button">Create</button>
# <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
# </div>
# </div>
# </div>
# </div>
# <div id="wrapper">
# <header class="navbar-default text-uppercase" id="header" role="navigation">
# <div class="top-holder">
# <div class="container-fluid">
# <button class="navbar-toggle text-uppercase pull-left" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" id="popoverMobileViewMainMenu" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="text">Menu</span>
# </button>
# <div id="popovercontentMobileViewMainMenu" style="display: none;">
# <div class="container-fluid">
# <div class="row" id="h3Overrides">
# <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#                         $(document).ready(function () {
#
#                             $("#popoverMobileViewMainMenu").popover({
#                                 html: true,
#                                 container: 'body',
#                                 content: function () {
#                                     return $('#popovercontentMobileViewMainMenu').html();
#                                 }
#                             });
#
#                             $('html').on('click', function (e) {
#                                 if (typeof $(e.target).data('original-title') == 'undefined' &&
#                                     !$(e.target).parents().is('.popover.in') &&
#                                     $(e.target).parent().attr("id") !== "popoverMobileViewMainMenu") {
#                                     $('[data-original-title]').popover('hide');
#                                 }
#                             });
#                         });
#
#                     </script>
# <div class="pull-right align-right">
# <form action="/classifieds/search" class="search-form navbar-form hidden-xs" method="get" role="search"> <fieldset>
# <div class="form-group">
# <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
# <input name="location" type="hidden" value="new-york">
# <input name="category" type="hidden" value="all"/>
# <input name="posttype" type="hidden" value="7"/>
# <input name="ships" type="hidden"/>
# </input></div>
# <button class="btn btn-default icon-search" type="submit"></button>
# </fieldset>
# </form>
# <a class="btn btn-warning create-btn text-uppercase" href="/posts/new"><span class="hidden-sm hidden-xs">CREATE A LISTING</span> <i class="icon-pencil"></i> <span class="visible-sm visible-xs">list</span></a>
# <ul class="users-list hidden-xs">
# <li><a href="/account/new">CREATE AN ACCOUNT</a></li>
# <li><a href="/accountlogin">LOGIN</a></li>
# </ul>
# <button class="btn btn-warning create-btn text-uppercase visible-xs" onclick="showHideSearchMobile()" type="button"><i class="icon-search"></i> <span class="visible-xs">search</span></button>
# <script type="text/javascript">
#                             function showHideSearchMobile() {
#                                 $("#searchMobileView").fadeToggle();
#                             }
#                         </script>
# </div>
# <div class="pull-left" id="logo">
# <a href="/" title="ARMSLIST - Firearms Classifieds">
# <picture>
# <!--[if IE 9]><video style="display: none;"><![endif]-->
# <source media="(max-width: 767px)" srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile@2x.png 2x"/>
# <source srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop@2x.png 2x"/>
# <!--[if IE 9]></video><![endif]-->
# <img alt="armslist firearms marketplace" height="66" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png" width="260"/>
# </picture>
# </a>
# </div>
# </div>
# </div>
# <div class="hidden-xs"><br/><br/></div>
# <div class="alert " id="mainMessageContainer" style="display: none; margin-bottom: 0px;">
# <div id="mainMessageContainer_Message" style="text-align: center;"></div>
# </div>
# <div class="hidden-sm hidden-md hidden-lg" id="searchMobileView" style="padding: 20px 10px 10px 20px; text-align: center; display: none;">
# <form action="/classifieds/search" class="search-form" method="get" role="search" style="width: 75% !important;"> <fieldset>
# <div class="form-group">
# <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
# <input name="location" type="hidden" value="new-york">
# <input name="category" type="hidden" value="all"/>
# <input name="posttype" type="hidden" value="7"/>
# <input name="ships" type="hidden"/>
# </input></div>
# <button class="btn btn-default icon-search" type="submit"></button>
# </fieldset>
# </form> <br/>
# <div class="carousel slide" data-ride="carousel" id="myCarousel" style="padding-top: 20px;">
# <!-- Wrapper for slides -->
# <div class="carousel-inner" role="listbox">
# <div class="item active">
# <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
# <a href="/classifieds/search?category=handguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">HANDGUNS <br/><i class="icon-handguns"></i></a>
# <a href="/classifieds/search?category=shotguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">SHOTGUNS <br/><i class="icon-shotguns"></i></a>
# <a href="/classifieds/search?category=rifles&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">RIFLES <br/><i class="icon-rifles"></i></a>
# </div>
# </div>
# <div class="item">
# <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
# <a href="/classifieds/search?category=firearm-accessories&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">ACCESSORIES <br/><i class="icon-scope"></i></a>
# <a href="/classifieds/search?category=outdoors&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">GEAR + MORE <br/><i class="icon-gear"></i></a>
# </div>
# </div>
# </div>
# <!-- Left and right controls -->
# <a class="left carousel-control" data-slide="prev" href="#myCarousel" role="button">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-left"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="right carousel-control" data-slide="next" href="#myCarousel" role="button">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-right"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# <style type="text/css">
#                     .carousel-control.left, .carousel-control.right {
#                         background-image: none;
#                     }
#                 </style>
# </div>
# </header>
# <main id="main">
# <div class="container-fluid" style="color: #655D5B;">
# <div id="bootstrap-overrides">
# <div class="col-xs-12 col-md-4" style="padding-top: 15px;">
# <h3>1 - 15 of 1118 results in All Categories</h3>
# </div>
# <div class="col-xs-12 col-md-8">
# <div class="col-xs-3 col-md-3" style="padding: 15px 0px 0px 0px; margin: 0px;">
# <a class="hidden-md hidden-lg" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Alert</a>
# <a class="hidden-xs hidden-sm" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Set a Search Alert</a>
# <script type="text/javascript">
#                 function newInitRecaptcha() {
#                     $.getScript("https://www.google.com/recaptcha/api/js/recaptcha_ajax.js", function () {
#                         Recaptcha.create(
#                             RecaptchaOptions.publicKey,     // public key, declared in Recaptcha view
#                             "recaptchaControls",            // id
#                             RecaptchaOptions                // options, declared in Recaptcha view
#                         );
#                     });
#                 }
#
#                 function doCreateSearchAlert(obj) {
#                     //var $dialog = $("#searchAlertDialog");
#                     //if ($dialog.length == 0) {
#                     //    $dialog = $('<div id="searchAlertDialog"></div>');
#                     //    $("body").append($dialog);
#                     //}
#                     //$dialog.html("");
#                     $.ajax({
#                         url: "/searchalerts/new",
#                         cache: false,
#                         success: function (data) {
#                             $("#searchAlertContainer").html(data);
#                             newInitRecaptcha();
#                             //$dialog.html(data);
#                             //listmill.app.initRecaptcha();
#                             //$dialog.dialog({
#                             //    title: "New Search Alert",
#                             //    modal: true,
#                             //    width: 460,
#                             //    buttons: [
#                             //        { text: "Create", click: createSearchAlert },
#                             //        { text: "Cancel", click: function () { $(this).dialog("close"); } },
#                             //    ]
#                             //});
#                             //$("#name").focus();
#                         }
#                     });
#                     return false;
#                 }
#
#                 function createSearchAlert() {
#                     var $dialog = $("#searchAlertContainer");
#                     var $form = $dialog.find("form");
#                     $.ajax({
#                         url: $form.attr("action"),
#                         type: "POST",
#                         data: $form.serialize(),
#                         success: createSearchAlertCallback,
#                         error: function () {
#                             $('#searchAlertModal').modal('hide');
#                             alert("There was a problem creating the search alert.");
#                         }
#                     });
#                 }
#
#                 function createSearchAlertCallback(data) {
#                     if (data === "success") {
#
#                         $('#searchAlertModal').modal('hide');
#                         alert("Search Alert Created");
#                         //listmill.app.showMessage("success", "Search Alert successfully created! You should receive a confirmation email shortly.");
#                         //$("#searchAlertDialog").dialog("close");
#                     } else {
#                         $("#searchAlertContainer").html(data);
#                         newInitRecaptcha();
#                         //var $dialog = $("#searchAlertDialog");
#                         //$dialog.html(data);
#                         //$dialog.dialog("open");
#                         //listmill.app.initRecaptcha();
#                     }
#                 }
#             </script>
# </div>
# <div class="col-xs-4 col-md-4" style="padding: 15px 0px 0px 0px;">
# <a class="" href="/deals" style="color: #cb2027;"><i class="fa fa-star"></i> Deals <i class="fa fa-star"></i></a>
# </div>
# <div class="hidden-md hidden-lg" style="float: right; padding: 15px 0px 15px 15px; position: relative;">
# <!--<a data-placement="bottom" id="popoverMobileView" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>-->
# <a data-target="#filterByModal" data-toggle="modal" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>
# <div id="popovercontentMobileView" style="display: none;">
# <div style="padding: 10px; text-align: center;">
# <a class="clear-all" href="/classifieds/search?location=new-york&amp;category=all" title="Remove All">Clear All</a>
# </div>
# <div style="padding: 10px; border-top: solid 1px #aaaaaa; border-bottom: solid 1px #aaaaaa;">
# <table style="width: 100%">
# <tr>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Private Party<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=4&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Premium Vendor<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=1&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Vendors that Ship<br>
# <a class="class_checkbox " href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=True"></a>
# </br></td>
# </tr>
# <tr><td colspan="3" style="border-top: solid 1px #aaaaaa;"> </td></tr>
# <tr>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 For Sale<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=6&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 For Trade<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=5&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Want to Buy<br/>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=3&amp;ships=False"></a>
# </td>
# </tr>
# </table>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 20px;">
# <h3 style="color: #555555;">LOCATION</h3>
# <div style="position: relative; color: #000000; background: url('https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png') no-repeat center;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png" style="opacity: 0;"/>
# <div style="position: absolute; top: 20%; width: 100%; text-align: center;">
#                                     Searching in<br/>
# <h2 style="font-weight: bold; color: #000000;">
# New York
#                                     </h2>
# </div>
# </div>
# <br/>
# <div>
# <select id="locationDDL" name="stateDDL" onchange="changeLocation(this)" style="color: #000000;">
# <option value="">State</option>
# <option value="/classifieds/search?location=alabama&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Alabama
#                                     </option>
# <option value="/classifieds/search?location=alaska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Alaska
#                                     </option>
# <option value="/classifieds/search?location=arizona&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Arizona
#                                     </option>
# <option value="/classifieds/search?location=arkansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Arkansas
#                                     </option>
# <option value="/classifieds/search?location=california&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         California
#                                     </option>
# <option value="/classifieds/search?location=colorado&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Colorado
#                                     </option>
# <option value="/classifieds/search?location=connecticut&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Connecticut
#                                     </option>
# <option value="/classifieds/search?location=delaware&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Delaware
#                                     </option>
# <option value="/classifieds/search?location=florida&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Florida
#                                     </option>
# <option value="/classifieds/search?location=georgia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Georgia
#                                     </option>
# <option value="/classifieds/search?location=guam-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Guam
#                                     </option>
# <option value="/classifieds/search?location=hawaii&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Hawaii
#                                     </option>
# <option value="/classifieds/search?location=idaho&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Idaho
#                                     </option>
# <option value="/classifieds/search?location=illinois&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Illinois
#                                     </option>
# <option value="/classifieds/search?location=indiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Indiana
#                                     </option>
# <option value="/classifieds/search?location=iowa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Iowa
#                                     </option>
# <option value="/classifieds/search?location=kansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Kansas
#                                     </option>
# <option value="/classifieds/search?location=kentucky&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Kentucky
#                                     </option>
# <option value="/classifieds/search?location=louisiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Louisiana
#                                     </option>
# <option value="/classifieds/search?location=maine&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Maine
#                                     </option>
# <option value="/classifieds/search?location=maryland&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Maryland
#                                     </option>
# <option value="/classifieds/search?location=massachusetts&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Massachusetts
#                                     </option>
# <option value="/classifieds/search?location=michigan&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Michigan
#                                     </option>
# <option value="/classifieds/search?location=minnesota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Minnesota
#                                     </option>
# <option value="/classifieds/search?location=mississippi&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Mississippi
#                                     </option>
# <option value="/classifieds/search?location=missouri&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Missouri
#                                     </option>
# <option value="/classifieds/search?location=montana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Montana
#                                     </option>
# <option value="/classifieds/search?location=nebraska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Nebraska
#                                     </option>
# <option value="/classifieds/search?location=nevada&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Nevada
#                                     </option>
# <option value="/classifieds/search?location=new-hampshire&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New Hampshire
#                                     </option>
# <option value="/classifieds/search?location=nj&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New Jersey
#                                     </option>
# <option value="/classifieds/search?location=new-mexico&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New Mexico
#                                     </option>
# <option selected="selected" value="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New York
#                                     </option>
# <option value="/classifieds/search?location=north-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         North Carolina
#                                     </option>
# <option value="/classifieds/search?location=north-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         North Dakota
#                                     </option>
# <option value="/classifieds/search?location=ohio&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Ohio
#                                     </option>
# <option value="/classifieds/search?location=oklahoma&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Oklahoma
#                                     </option>
# <option value="/classifieds/search?location=oregon&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Oregon
#                                     </option>
# <option value="/classifieds/search?location=pennsylvania&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Pennsylvania
#                                     </option>
# <option value="/classifieds/search?location=puerto-rico-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Puerto Rico
#                                     </option>
# <option value="/classifieds/search?location=rhode-island&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Rhode Island
#                                     </option>
# <option value="/classifieds/search?location=south-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         South Carolina
#                                     </option>
# <option value="/classifieds/search?location=south-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         South Dakota
#                                     </option>
# <option value="/classifieds/search?location=tennessee&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Tennessee
#                                     </option>
# <option value="/classifieds/search?location=texas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Texas
#                                     </option>
# <option value="/classifieds/search?location=utah&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Utah
#                                     </option>
# <option value="/classifieds/search?location=vermont&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Vermont
#                                     </option>
# <option value="/classifieds/search?location=virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Virginia
#                                     </option>
# <option value="/classifieds/search?location=washington&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Washington
#                                     </option>
# <option value="/classifieds/search?location=west-virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         West Virginia
#                                     </option>
# <option value="/classifieds/search?location=wisconsin&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Wisconsin
#                                     </option>
# <option value="/classifieds/search?location=wyoming&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Wyoming
#                                     </option>
# </select>
# <br/> <select name="cityDDL" onchange="changeLocation(this)" style="color: #000000; margin-top: 10px;">
# <option value="">City</option>
# <option value="/classifieds/search?location=adirondacks-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Adirondacks
#                                     </option>
# <option value="/classifieds/search?location=albany-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Albany
#                                     </option>
# <option value="/classifieds/search?location=binghamton-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Binghamton
#                                     </option>
# <option value="/classifieds/search?location=buffalo-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Buffalo
#                                     </option>
# <option value="/classifieds/search?location=hudson-valley-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Hudson Valley
#                                     </option>
# <option value="/classifieds/search?location=long-island-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Long Island
#                                     </option>
# <option value="/classifieds/search?location=rochester-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Rochester
#                                     </option>
# <option value="/classifieds/search?location=syracuse-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Syracuse
#                                     </option>
# <option value="/classifieds/search?location=tri-state-area&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Tri-state area
#                                     </option>
# <option value="/classifieds/search?location=watertown&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Watertown
#                                     </option>
# </select>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 20px 20px 10px 20px;">
# <div>
# <a class="accordion-toggle chevron-rotate" data-toggle="collapse" href="#collapseCategoryMobile">
# <h3 style="color: #5c724c;">
# <i class="fa fa-chevron-right"></i> Category
#                                             </h3>
# </a>
# </div>
# <div class="collapse " id="collapseCategoryMobile" style="border-top: solid 1px #aaaaaa;">
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=guns&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Firearms</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapsegunsMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=antiques&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Antique Firearms</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=handguns&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Handguns</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=muzzle-loaders&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Muzzle Loaders</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=nfa-firearms&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">NFA Firearms</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=rifles&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Rifles</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=shotguns&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Shotguns</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=firearm-accessories&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Firearm Accessories</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapsefirearm-accessoriesMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=ammo&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Ammo</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-parts&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Gun Parts</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-safes&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Gun Safes</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=holsters&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Holsters</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=magazines&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Magazines</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=optics&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Optics</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=reloading&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Reloading</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=tactical-gear&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Tactical Gear</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=outdoors&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Outdoors Gear</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapseoutdoorsMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=archery&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Archery</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=fishing&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Fishing Gear</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=hunting&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Hunting Gear</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=knives&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Knives</h5></td>
# <td style="width: 21px;">
# ...
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=aa79cc16&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=46&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=aa79cc16"/></a></noscript>
# </div>
# <div class="ad-search">
# <!--/*
#   *
#   * Revive Adserver Javascript Tag
#   * - Generated with Revive Adserver v3.2.2
#   *
#   */-->
# <!--/*
#   * The backup image section of this tag has been generated for use on a
#   * non-SSL page. If this tag is to be placed on an SSL page, change the
#   *   'http://revive.armslist.com/revive/www/delivery/...'
#   * to
#   *   'https://revive.armslist.com/revive/www/delivery/...'
#   *
#   * This noscript section of this tag only shows image banners. There
#   * is no width or height in these banners, so if you want these tags to
#   * allocate space for the ad before it shows, you will need to add this
#   * information to the <img> tag.
#   *
#   * If you do not want to deal with the intricities of the noscript
#   * section, delete the tag (from <noscript>... to </noscript>). On
#   * average, the noscript tag is called from less than 1% of internet
#   * users.
#   */-->
# <script type="text/javascript"><!--//<![CDATA[
#    var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
# var m3_r = Math.floor(Math.random()*99999999999);
# if (!document.MAX_used) document.MAX_used = ',';
# document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
# document.write ("?zoneid=48");
# document.write ('&amp;cb=' + m3_r);
# if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
# document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
# document.write ("&amp;loc=" + escape(window.location));
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=af067137&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=48&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=af067137"/></a></noscript>
# </div>
# <div class="ad-search">
# <!--/*
#   *
#   * Revive Adserver Javascript Tag
#   * - Generated with Revive Adserver v3.2.2
#   *
#   */-->
# <!--/*
#   * The backup image section of this tag has been generated for use on a
#   * non-SSL page. If this tag is to be placed on an SSL page, change the
#   *   'http://revive.armslist.com/revive/www/delivery/...'
#   * to
#   *   'https://revive.armslist.com/revive/www/delivery/...'
#   *
#   * This noscript section of this tag only shows image banners. There
#   * is no width or height in these banners, so if you want these tags to
#   * allocate space for the ad before it shows, you will need to add this
#   * information to the <img> tag.
#   *
#   * If you do not want to deal with the intricities of the noscript
#   * section, delete the tag (from <noscript>... to </noscript>). On
#   * average, the noscript tag is called from less than 1% of internet
#   * users.
#   */-->
# <script type="text/javascript"><!--//<![CDATA[
#    var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
# var m3_r = Math.floor(Math.random()*99999999999);
# if (!document.MAX_used) document.MAX_used = ',';
# document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
# document.write ("?zoneid=47");
# document.write ('&amp;cb=' + m3_r);
# if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
# document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
# document.write ("&amp;loc=" + escape(window.location));
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=ae5ac2c4&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=47&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=ae5ac2c4"/></a></noscript>
# </div>
# <div style="padding-top: 10px;">
# <div style='background-color: #2f2d24; text-align: left; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
# <h2 style="color: #e5e0bf; padding: 5px;">Latest Video</h2>
# </div>
# <iframe allowfullscreen="" class="youtube_video" frameborder="0" src="https://www.youtube.com/embed?max-results=1&amp;controls=0&amp;showinfo=0&amp;rel=0&amp;listType=user_uploads&amp;list=ArmslistMedia"></iframe>
# <div style="clear: both;"> </div>
# </div>
# <script type="text/javascript">
#                                 $(document).ready(function () {
#                                     $(".youtube_video").wrap('<div class="youtube_container">');
#                                 });
#                             </script>
# <div id="rcjsload_dc470c"></div>
# <script type="text/javascript">
#                                 (function () {
#                                     var referer = ""; try { if (referer = document.referrer, "undefined" == typeof referer || "" == referer) throw "undefined" } catch (exception) { referer = document.location.href, ("" == referer || "undefined" == typeof referer) && (referer = document.URL) } referer = referer.substr(0, 700);
#                                     var rcds = document.getElementById("rcjsload_dc470c");
#                                     var rcel = document.createElement("script");
#                                     rcel.id = 'rc_' + Math.floor(Math.random() * 1000);
#                                     rcel.type = 'text/javascript';
#                                     rcel.src = "//trends.revcontent.com/serve.js.php?w=109511&t=" + rcel.id + "&c=" + (new Date()).getTime() + "&width=" + (window.outerWidth || document.documentElement.clientWidth) + "&referer=" + encodeURIComponent(referer);
#                                     rcel.async = true;
#                                     rcds.appendChild(rcel);
#                                 })();
#                             </script>
# </div>
# </div>
# <style type="text/css">
#                     .ad-search {
#                         margin-top: 16px;
#                     }
#                     .popover{
#                         max-width: none;
#                         width: 300px;
#                     }
#
#                     #bootstrap-overrides h2, #filterByContainer h2 {
#                         margin-top: 0px;
#                     }
#
#                     #bootstrap-overrides h3, #filterByContainer h3 {
#                         margin-top: 0px;
#                         color: #000000;
#                         font-weight: bold;
#                     }
#                     .class_checkbox {
#                         display: inline-block;
#                         padding-top: 4px;
#                         width: 43px;
#                         height: 27px;
#                         background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/OFF_desktop.png);
#                         cursor: pointer;
#
#                     }
#
#                     .class_checkbox.checked {
#                         background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/ON_desktop.png);
#                     }
#
#                     .switches {
#                         font-weight: bold;
#                         color: #000000;
#                     }
#
#                     .clickable-row {
#                         cursor: pointer;
#                     }
#                 </style>
# <script type="text/javascript">
#
#
#                     function changeLocation(location) {
#                         if (location) {
#                             window.location = $(location).val();;
#                         }
#                         return false;
#                     }
#
#                     $(document).on("click", ".clickable-row", function () {
#                         window.document.location = $(this).data("href");
#
#                     });
#
#                     $(document).on("click", ".chevron-rotate", function () {
#                         if ($(this).parent().find(".fa-chevron-right").length) {
#                             $(this).parent().find(".fa-chevron-right").removeClass("fa-chevron-right").addClass("fa-chevron-down");
#                         } else {
#                             $(this).parent().find(".fa-chevron-down").removeClass("fa-chevron-down").addClass("fa-chevron-right");
#                         }
#                     });
#
#
#                 </script>
# <!-- HACK FOR EDS -->
# <table style="display: none;">
# <tr><td class="title"><a href="/posts/9571384/long-island-new-york-optics-for-sale--vortex-viper">FS: Vortex Viper</a></td></tr>
# <tr><td class="title"><a href="/posts/9789750/long-island-new-york-rifles-for-sale-trade--chiappa-1892-alaskan-take-down">FS/FT: Chiappa 1892 Alaskan Take Down</a></td></tr>
# <tr><td class="title"><a href="/posts/9572179/long-island-new-york-gun-parts-for-sale--rossi-coach-gun-overland-parts">FS: Rossi Coach Gun Overland Parts</a></td></tr>
# <tr><td class="title"><a href="/posts/9503782/long-island-new-york-shotguns-for-sale-trade--rossi-chrome-coach-gun-rare">FS/FT: Rossi Chrome Coach Gun Rare</a></td></tr>
# <tr><td class="title"><a href="/posts/9504240/long-island-new-york-shotguns-for-sale--savage-24--22lr-over-20ga-">FS: Savage 24  22lr Over 20ga.</a></td></tr>
# <tr><td class="title"><a href="/posts/9874160/long-island-new-york-shotguns-for-sale--remington-coach-gun-new-old-stock">FS: Remington Coach Gun New Old Stock</a></td></tr>
# <tr><td class="title"><a href="/posts/10074126/long-island-new-york-rifles-for-sale--ruger-m77-hawkeye-tactical--308">FS: Ruger m77 Hawkeye Tactical .308</a></td></tr>
# <tr><td class="title"><a href="/posts/10075280/long-island-new-york-shotguns-for-sale--rossi-overland-coach-gun-">FS: Rossi Overland Coach Gun </a></td></tr>
# <tr><td class="title"><a href="/posts/10078638/long-island-new-york-ammo-for-sale--remington--22-win-mag-case">FS: Remington .22 Win Mag case</a></td></tr>
# <tr><td class="title"><a href="/posts/10078666/long-island-new-york-ammo-for-sale--winchester--410-pdx1-defender-ammo">FS: Winchester .410 PDX1 Defender Ammo</a></td></tr>
# <tr><td class="title"><a href="/posts/10078487/watertown-handguns-for-sale--ruger-security-six--357">FS: Ruger Security Six .357</a></td></tr>
# <tr><td class="title"><a href="/posts/10110105/rochester-new-york-handguns-for-sale---glock-45-9mm-10rd-3-mags-frt-ser">FS:  GLOCK 45 9MM 10RD 3 MAGS FRT SER</a></td></tr>
# <tr><td class="title"><a href="/posts/10059192/rochester-new-york-handguns-for-sale--taurus-605">FS: Taurus 605</a></td></tr>
# <tr><td class="title"><a href="/posts/7876495/rochester-new-york-holsters-for-sale--ruger-lcpii-kydex-holster-and-ruger-mag">FS: Ruger LCPII kydex holster and Ruger mag</a></td></tr>
# <tr><td class="title"><a href="/posts/7959698/rochester-new-york-handguns-for-sale--taylor---co---uberti--smoke-wagon--357">FS: Taylor &amp; Co. (Uberti) Smoke Wagon .357</a></td></tr>
# </table>
# </div>
# </main>
# <style type="text/css"> body { overflow: visible; } </style>
# <footer id="footer" style="display: table;">
# <div class="top-hold hidden-xs">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
# </div>
# </div>
# </div>
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-6 col-md-offset-3 col-sm-8 col-sm-offset-2">
# <ul class="social-list">
# <li>
# <a class="icon-youtube" href="http://www.youtube.com/user/armslistmedia?sub_confirmation=1" target="_blank" title="Armslist Youtube channel"></a>
# </li>
# <li>
# <a class="icon-instagram" href="https://instagram.com/armslist/" target="_blank" title="Armslist on Instagram"></a>
# </li>
# <li>
# <a class="icon-facebook" href="https://www.facebook.com/armslist" target="_blank" title="Armslist on Facebook"></a>
# </li>
# <li>
# <a class="icon-twitter" href="https://twitter.com/armslist" target="_blank" title="Armslist Twitter page"></a>
# </li>
# <li>
# <a class="icon-google-plus" href="https://plus.google.com/103978926144598391141/posts" target="_blank" title="Armslist on Google+"></a>
# </li>
# </ul>
# <div class="text-block">
# <p>Always comply with local, state, federal, and international law.
# ARMSLIST does not become involved in transactions between parties. Review our
# <a href="/info/privacy">privacy policy</a> and <a href="/info/terms">terms of use</a> for more
# information. Report Illegal Firearms Activity to 1-800-ATF-GUNS.  </p>
# </div>
# <span class="copy">
#                             Copyright © 2019 Armslist, LLC |
#
#                             | Version: 15.0.2
#                         </span>
# </div>
# </div>
# </div>
# <script id="LOTCC_3569" src="http://tags.crwdcntrl.net/c/3569/cc.js?ns=_cc3569" type="text/javascript"></script>
# <script language="javascript" type="text/javascript"> _cc3569.bcp(); </script>
# </footer>
# </div>
# <div class="loader-box">
# <img alt="loader" height="64" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/loader.gif" width="64"/>
# </div>
# <script>   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');    ga('create', 'UA-5138407-1', 'auto');   ga('send', 'pageview');  </script>
# </body>
# </html>

# %%
for baby in list(soup.children):
    print(type(baby))
# Out:
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Doctype'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>

# %% [markdown]
# **Get the main `html` element from the children and then its own children**

# %%
myHtml = list(soup.children)[3]

# %%
type(myHtml)
# Out:
# bs4.element.Tag

# %%
list(myHtml.children)
# Out:
# ['\n', <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <title>
#      ARMSLIST    -
#  New York
#  All Categories
#  Classifieds
#  </title>
#  <link href="https://s3.amazonaws.com/mgm-content/sites/armslist/content/system/favicon.ico" rel="shortcut icon"/>
#  <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/bootstrap.css" rel="stylesheet"/>
#  <link href="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/css/all.css" rel="stylesheet"/>
#  <link href="//fonts.googleapis.com/css?family=Oswald:400,300%7CLato:400,700" rel="stylesheet" type="text/css"/>
#  <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" rel="stylesheet"/>
#  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
#  <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
#  <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/js/jquery.main.js" type="text/javascript"></script>
#  <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.5/js/bootstrap.min.js"></script>
#  <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/lib/jquery-cookie.js" type="text/javascript"></script>
#  <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/listmill-app.js" type="text/javascript"></script>
#  <script src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/scripts/jquery-listmill.js" type="text/javascript"></script>
#  <script type="text/javascript">
#              var appOptions = {
#                  showTermsOnLoad: "true" == "true" ? true : false,
#                  showTermsOnLoadTimeout: 0};
#
#              $(function () {
#                  if(appOptions.showTermsOnLoad) {
#                      checkTerms();
#                  }
#              });
#
#              function checkTerms() {
#                  if ((document.cookie.length == 0 || document.cookie.indexOf("terms=agreed") == -1)
#                      && window.location.href.indexOf("/info/terms") == -1
#                      && document.cookie.indexOf("listmill_auth") == -1) {
#                      showTerms();
#                  } else
#                      acceptTerms();
#              }
#
#              function acceptTerms() {
#                  var dateStr = "";
#                  if (appOptions.showTermsOnLoadTimeout > 0) {
#                      date = new Date();
#                      date.setHours(date.getHours() + appOptions.showTermsOnLoadTimeout);
#                      dateStr = "; expires=" + date.toUTCString();
#                  };
#                  document.cookie = "terms=agreed" + dateStr + "; path=/";
#
#                  $('#termsModal').modal('hide');
#
#                  //show dropin after terms are agreed
#                  //showDropin();
#              }
#
#              function showTerms() {
#                  //termsModalContainer
#                  $.ajax({
#                      url: "/info/termsagreement",
#                      dataType: "html",
#                      success: function (data) {
#                          $("#termsModalContainer").html(data);
#
#                          $('#termsModal').modal({
#                              backdrop: 'static',
#                              keyboard: false
#                          });
#
#                          $('#termsModal').modal('show');
#                      }});
#              }
#
#              function showDropin() {
#                  if(document.cookie.indexOf("dropin=true") == -1) {
#                      $.ajax({
#                          url: "/info/dropin",
#                          dataType: "html",
#                          success: function (data) {
#                              $("#dropinModalContainer").html(data);
#
#                              $('#dropinModal').modal({
#                                  backdrop: 'static',
#                                  keyboard: true
#                              });
#
#                              $('#dropinModal').modal('show');
#                          }});
#                  }
#              }
#
#              function saveDropin() {
#                  $.post( "/info/dropin", "email=" +$('#dropinModalTextBox').val() );
#                  setDropinCookie();
#              }
#
#              function noThanksDropin() {
#                  setDropinCookie();
#              }
#
#              function setDropinCookie() {
#                  var dateStr = "";
#                  date = new Date();
#                  // 2190 = 3 months, cookie expires in 3 months
#                  date.setHours(date.getHours() + 2190);
#                  dateStr = "; expires=" + date.toUTCString();
#                  document.cookie = "dropin=true" + dateStr + "; path=/";
#
#                  $('#dropinModal').modal('hide');
#              }
#
#          </script>
#  <meta content="Classifieds listings of All Categories in New York" name="description">
#  <meta content="New York, All Categories, classifieds" name="keywords"/>
#  <style type="text/css">
#          .youtube_container {
#          position: relative;
#          width: 100%;
#          height: 0;
#          padding-bottom: 56.25%;
#          clear: both;
#      }
#      .youtube_video {
#          position: absolute;
#          top: 0;
#          left: 0;
#          width: 100%;
#          height: 100%;
#      }
#      .blink_me {
#          animation: blinker 1s linear infinite;
#      }
#
#      @keyframes blinker {
#        50% {
#          opacity: 0;
#        }
#      }
#      </style>
#  <!-- -->
#  <!--                <style type="text/css">
#          .footer-social {  width: 100px;  margin-right: 0px !important;}
#          </style>
#  -->
#  <style type="text/css">
#              #h3Overrides h3 {
#                  margin-top: 0px;
#                  color: #000000;
#              }
#          </style>
#  <!-- Javascript tag: -->
#  <!-- begin ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
#  <script language="JavaScript">
#  var zflag_nid="305"; var zflag_cid="56890/56889/1"; var zflag_sid="5734"; var zflag_width="1"; var zflag_height="1"; var zflag_sz="15"; var zflag_click="[INSERT_CLICK_TRACKER_MACRO]"; var zflag_page="[INSERT_PAGE_URL]";
#  </script>
#  <script language="JavaScript" src="http://c5.zedo.com/jsc/c5/fo.js"></script>
#  <!-- end ZEDO for channel:  Armslist - CLB , publisher: Armslist , Ad Dimension: Pixel/Popup - 1 x 1 -->
#  <!--ALC script-->
#  <script>
#      var _alcTag = _alcTag || [];
#      (function () {
#          var atag = document.createElement('script');
#          atag.async = 1;
#          atag.src = '//al-p.alcmpn.com/wt/388/webtag.js';
#          var node = document.getElementsByTagName('script')[0];
#          node.parentNode.insertBefore(atag, node);
#      })();
#
#          </script>
#  <!--End ALC script-->
#  <!-- OneTag Container: armslist-->
#  </meta></head>, '\n', <body style="-webkit-overflow-scrolling: touch;">
#  <div class="modal fade" id="termsModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <h4 style="color: #655d5b">TERMS OF USE</h4>
#  </div>
#  <div class="modal-body">
#  <div id="termsModalContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-default" onclick="acceptTerms()" type="button">Accept</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="promotionModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <h4 style="color: #655d5b">PROMOTIONAL LINK</h4>
#  </div>
#  <div class="modal-body">
#  <div id="promotionModalContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="filterByModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <button class="close" data-dismiss="modal" type="button">×</button>
#  <h4 style="color: #655d5b">Filter By</h4>
#  </div>
#  <div class="modal-body">
#  <div id="filterByContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="dropinModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <h4 style="color: #655d5b">Armslist</h4>
#  </div>
#  <div class="modal-body">
#  <div id="dropinModalContainer"></div>
#  <input id="dropinModalTextBox" type="text"/>
#  </div>
#  <div class="modal-footer">
#  <button class="btn btn-default" onclick="noThanksDropin()" style="float: left;" type="button">Close</button>
#  <button class="btn btn-primary" onclick="saveDropin()" type="button">Submit</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="contactSellerEmailModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <button class="close" data-dismiss="modal" type="button">×</button>
#  <h4 style="color: #655d5b">Contact Seller</h4>
#  </div>
#  <div class="modal-body">
#  <div id="messageSellerContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="pull-left btn btn-default" id="contactFormSubmitBtn" onclick="doMessageSend()" type="button">Send</button>
#  <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="modal fade" id="searchAlertModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
#  <div class="modal-dialog">
#  <!-- Modal content-->
#  <div class="modal-content">
#  <div class="modal-header">
#  <button class="close" data-dismiss="modal" type="button">×</button>
#  <h4 style="color: #655d5b">Search Alert</h4>
#  </div>
#  <div class="modal-body">
#  <div id="searchAlertContainer"></div>
#  </div>
#  <div class="modal-footer">
#  <button class="pull-left btn btn-default" id="searchAlertFormSubmitBtn" onclick="createSearchAlert()" type="button">Create</button>
#  <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div id="wrapper">
#  <header class="navbar-default text-uppercase" id="header" role="navigation">
#  <div class="top-holder">
#  <div class="container-fluid">
#  <button class="navbar-toggle text-uppercase pull-left" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" id="popoverMobileViewMainMenu" type="button">
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="text">Menu</span>
#  </button>
#  <div id="popovercontentMobileViewMainMenu" style="display: none;">
#  <div class="container-fluid">
#  <div class="row" id="h3Overrides">
#  <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
#  </div>
#  </div>
#  </div>
#  <script type="text/javascript">
#                          $(document).ready(function () {
#
#                              $("#popoverMobileViewMainMenu").popover({
#                                  html: true,
#                                  container: 'body',
#                                  content: function () {
#                                      return $('#popovercontentMobileViewMainMenu').html();
#                                  }
#                              });
#
#                              $('html').on('click', function (e) {
#                                  if (typeof $(e.target).data('original-title') == 'undefined' &&
#                                      !$(e.target).parents().is('.popover.in') &&
#                                      $(e.target).parent().attr("id") !== "popoverMobileViewMainMenu") {
#                                      $('[data-original-title]').popover('hide');
#                                  }
#                              });
#                          });
#
#                      </script>
#  <div class="pull-right align-right">
#  <form action="/classifieds/search" class="search-form navbar-form hidden-xs" method="get" role="search"> <fieldset>
#  <div class="form-group">
#  <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
#  <input name="location" type="hidden" value="new-york">
#  <input name="category" type="hidden" value="all"/>
#  <input name="posttype" type="hidden" value="7"/>
#  <input name="ships" type="hidden"/>
#  </input></div>
#  <button class="btn btn-default icon-search" type="submit"></button>
#  </fieldset>
#  </form>
#  <a class="btn btn-warning create-btn text-uppercase" href="/posts/new"><span class="hidden-sm hidden-xs">CREATE A LISTING</span> <i class="icon-pencil"></i> <span class="visible-sm visible-xs">list</span></a>
#  <ul class="users-list hidden-xs">
#  <li><a href="/account/new">CREATE AN ACCOUNT</a></li>
#  <li><a href="/accountlogin">LOGIN</a></li>
#  </ul>
#  <button class="btn btn-warning create-btn text-uppercase visible-xs" onclick="showHideSearchMobile()" type="button"><i class="icon-search"></i> <span class="visible-xs">search</span></button>
#  <script type="text/javascript">
#                              function showHideSearchMobile() {
#                                  $("#searchMobileView").fadeToggle();
#                              }
#                          </script>
#  </div>
#  <div class="pull-left" id="logo">
#  <a href="/" title="ARMSLIST - Firearms Classifieds">
#  <picture>
#  <!--[if IE 9]><video style="display: none;"><![endif]-->
#  <source media="(max-width: 767px)" srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile@2x.png 2x"/>
#  <source srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop@2x.png 2x"/>
#  <!--[if IE 9]></video><![endif]-->
#  <img alt="armslist firearms marketplace" height="66" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png" width="260"/>
#  </picture>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="hidden-xs"><br/><br/></div>
#  <div class="alert " id="mainMessageContainer" style="display: none; margin-bottom: 0px;">
#  <div id="mainMessageContainer_Message" style="text-align: center;"></div>
#  </div>
#  <div class="hidden-sm hidden-md hidden-lg" id="searchMobileView" style="padding: 20px 10px 10px 20px; text-align: center; display: none;">
#  <form action="/classifieds/search" class="search-form" method="get" role="search" style="width: 75% !important;"> <fieldset>
#  <div class="form-group">
#  <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
#  <input name="location" type="hidden" value="new-york">
#  <input name="category" type="hidden" value="all"/>
#  <input name="posttype" type="hidden" value="7"/>
#  <input name="ships" type="hidden"/>
#  </input></div>
#  <button class="btn btn-default icon-search" type="submit"></button>
#  </fieldset>
#  </form> <br/>
#  <div class="carousel slide" data-ride="carousel" id="myCarousel" style="padding-top: 20px;">
#  <!-- Wrapper for slides -->
#  <div class="carousel-inner" role="listbox">
#  <div class="item active">
#  <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
#  <a href="/classifieds/search?category=handguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">HANDGUNS <br/><i class="icon-handguns"></i></a>
#  <a href="/classifieds/search?category=shotguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">SHOTGUNS <br/><i class="icon-shotguns"></i></a>
#  <a href="/classifieds/search?category=rifles&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">RIFLES <br/><i class="icon-rifles"></i></a>
#  </div>
#  </div>
#  <div class="item">
#  <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
#  <a href="/classifieds/search?category=firearm-accessories&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">ACCESSORIES <br/><i class="icon-scope"></i></a>
#  <a href="/classifieds/search?category=outdoors&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">GEAR + MORE <br/><i class="icon-gear"></i></a>
#  </div>
#  </div>
#  </div>
#  <!-- Left and right controls -->
#  <a class="left carousel-control" data-slide="prev" href="#myCarousel" role="button">
#  <span aria-hidden="true" class="glyphicon glyphicon-chevron-left"></span>
#  <span class="sr-only">Previous</span>
#  </a>
#  <a class="right carousel-control" data-slide="next" href="#myCarousel" role="button">
#  <span aria-hidden="true" class="glyphicon glyphicon-chevron-right"></span>
#  <span class="sr-only">Next</span>
#  </a>
#  </div>
#  <style type="text/css">
#                      .carousel-control.left, .carousel-control.right {
#                          background-image: none;
#                      }
#                  </style>
#  </div>
#  </header>
#  <main id="main">
#  <div class="container-fluid" style="color: #655D5B;">
#  <div id="bootstrap-overrides">
#  <div class="col-xs-12 col-md-4" style="padding-top: 15px;">
#  <h3>1 - 15 of 1118 results in All Categories</h3>
#  </div>
#  <div class="col-xs-12 col-md-8">
#  <div class="col-xs-3 col-md-3" style="padding: 15px 0px 0px 0px; margin: 0px;">
#  <a class="hidden-md hidden-lg" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Alert</a>
#  <a class="hidden-xs hidden-sm" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Set a Search Alert</a>
#  <script type="text/javascript">
#                  function newInitRecaptcha() {
#                      $.getScript("https://www.google.com/recaptcha/api/js/recaptcha_ajax.js", function () {
#                          Recaptcha.create(
#                              RecaptchaOptions.publicKey,     // public key, declared in Recaptcha view
#                              "recaptchaControls",            // id
#                              RecaptchaOptions                // options, declared in Recaptcha view
#                          );
#                      });
#                  }
#
#                  function doCreateSearchAlert(obj) {
#                      //var $dialog = $("#searchAlertDialog");
#                      //if ($dialog.length == 0) {
#                      //    $dialog = $('<div id="searchAlertDialog"></div>');
#                      //    $("body").append($dialog);
#                      //}
#                      //$dialog.html("");
#                      $.ajax({
#                          url: "/searchalerts/new",
#                          cache: false,
#                          success: function (data) {
#                              $("#searchAlertContainer").html(data);
#                              newInitRecaptcha();
#                              //$dialog.html(data);
#                              //listmill.app.initRecaptcha();
#                              //$dialog.dialog({
#                              //    title: "New Search Alert",
#                              //    modal: true,
#                              //    width: 460,
#                              //    buttons: [
#                              //        { text: "Create", click: createSearchAlert },
#                              //        { text: "Cancel", click: function () { $(this).dialog("close"); } },
#                              //    ]
#                              //});
#                              //$("#name").focus();
#                          }
#                      });
#                      return false;
#                  }
#
#                  function createSearchAlert() {
#                      var $dialog = $("#searchAlertContainer");
#                      var $form = $dialog.find("form");
#                      $.ajax({
#                          url: $form.attr("action"),
#                          type: "POST",
#                          data: $form.serialize(),
#                          success: createSearchAlertCallback,
#                          error: function () {
#                              $('#searchAlertModal').modal('hide');
#                              alert("There was a problem creating the search alert.");
#                          }
#                      });
#                  }
#
#                  function createSearchAlertCallback(data) {
#                      if (data === "success") {
#
#                          $('#searchAlertModal').modal('hide');
#                          alert("Search Alert Created");
#                          //listmill.app.showMessage("success", "Search Alert successfully created! You should receive a confirmation email shortly.");
#                          //$("#searchAlertDialog").dialog("close");
#                      } else {
#                          $("#searchAlertContainer").html(data);
#                          newInitRecaptcha();
#                          //var $dialog = $("#searchAlertDialog");
#                          //$dialog.html(data);
#                          //$dialog.dialog("open");
#                          //listmill.app.initRecaptcha();
#                      }
#                  }
#              </script>
#  </div>
#  <div class="col-xs-4 col-md-4" style="padding: 15px 0px 0px 0px;">
#  <a class="" href="/deals" style="color: #cb2027;"><i class="fa fa-star"></i> Deals <i class="fa fa-star"></i></a>
#  </div>
#  <div class="hidden-md hidden-lg" style="float: right; padding: 15px 0px 15px 15px; position: relative;">
#  <!--<a data-placement="bottom" id="popoverMobileView" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>-->
#  <a data-target="#filterByModal" data-toggle="modal" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>
#  <div id="popovercontentMobileView" style="display: none;">
#  <div style="padding: 10px; text-align: center;">
#  <a class="clear-all" href="/classifieds/search?location=new-york&amp;category=all" title="Remove All">Clear All</a>
#  </div>
#  <div style="padding: 10px; border-top: solid 1px #aaaaaa; border-bottom: solid 1px #aaaaaa;">
#  <table style="width: 100%">
#  <tr>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  Private Party<br>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=4&amp;ships=False"></a>
#  </br></td>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  Premium Vendor<br>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=1&amp;ships=False"></a>
#  </br></td>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  Vendors that Ship<br>
#  <a class="class_checkbox " href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=True"></a>
#  </br></td>
#  </tr>
#  <tr><td colspan="3" style="border-top: solid 1px #aaaaaa;"> </td></tr>
#  <tr>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  For Sale<br>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=6&amp;ships=False"></a>
#  </br></td>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  For Trade<br>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=5&amp;ships=False"></a>
#  </br></td>
#  <td class="switches" style="text-align: center;" valign="middle">
#                                  Want to Buy<br/>
#  <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=3&amp;ships=False"></a>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 20px;">
#  <h3 style="color: #555555;">LOCATION</h3>
#  <div style="position: relative; color: #000000; background: url('https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png') no-repeat center;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png" style="opacity: 0;"/>
#  <div style="position: absolute; top: 20%; width: 100%; text-align: center;">
#                                      Searching in<br/>
#  <h2 style="font-weight: bold; color: #000000;">
#  New York
#                                      </h2>
#  </div>
#  </div>
#  <br/>
#  <div>
#  <select id="locationDDL" name="stateDDL" onchange="changeLocation(this)" style="color: #000000;">
#  <option value="">State</option>
#  <option value="/classifieds/search?location=alabama&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Alabama
#                                      </option>
#  <option value="/classifieds/search?location=alaska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Alaska
#                                      </option>
#  <option value="/classifieds/search?location=arizona&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Arizona
#                                      </option>
#  <option value="/classifieds/search?location=arkansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Arkansas
#                                      </option>
#  <option value="/classifieds/search?location=california&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          California
#                                      </option>
#  <option value="/classifieds/search?location=colorado&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Colorado
#                                      </option>
#  <option value="/classifieds/search?location=connecticut&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Connecticut
#                                      </option>
#  <option value="/classifieds/search?location=delaware&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Delaware
#                                      </option>
#  <option value="/classifieds/search?location=florida&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Florida
#                                      </option>
#  <option value="/classifieds/search?location=georgia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Georgia
#                                      </option>
#  <option value="/classifieds/search?location=guam-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Guam
#                                      </option>
#  <option value="/classifieds/search?location=hawaii&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Hawaii
#                                      </option>
#  <option value="/classifieds/search?location=idaho&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Idaho
#                                      </option>
#  <option value="/classifieds/search?location=illinois&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Illinois
#                                      </option>
#  <option value="/classifieds/search?location=indiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Indiana
#                                      </option>
#  <option value="/classifieds/search?location=iowa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Iowa
#                                      </option>
#  <option value="/classifieds/search?location=kansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Kansas
#                                      </option>
#  <option value="/classifieds/search?location=kentucky&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Kentucky
#                                      </option>
#  <option value="/classifieds/search?location=louisiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Louisiana
#                                      </option>
#  <option value="/classifieds/search?location=maine&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Maine
#                                      </option>
#  <option value="/classifieds/search?location=maryland&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Maryland
#                                      </option>
#  <option value="/classifieds/search?location=massachusetts&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Massachusetts
#                                      </option>
#  <option value="/classifieds/search?location=michigan&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Michigan
#                                      </option>
#  <option value="/classifieds/search?location=minnesota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Minnesota
#                                      </option>
#  <option value="/classifieds/search?location=mississippi&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Mississippi
#                                      </option>
#  <option value="/classifieds/search?location=missouri&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Missouri
#                                      </option>
#  <option value="/classifieds/search?location=montana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Montana
#                                      </option>
#  <option value="/classifieds/search?location=nebraska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Nebraska
#                                      </option>
#  <option value="/classifieds/search?location=nevada&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Nevada
#                                      </option>
#  <option value="/classifieds/search?location=new-hampshire&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          New Hampshire
#                                      </option>
#  <option value="/classifieds/search?location=nj&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          New Jersey
#                                      </option>
#  <option value="/classifieds/search?location=new-mexico&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          New Mexico
#                                      </option>
#  <option selected="selected" value="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          New York
#                                      </option>
#  <option value="/classifieds/search?location=north-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          North Carolina
#                                      </option>
#  <option value="/classifieds/search?location=north-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          North Dakota
#                                      </option>
#  <option value="/classifieds/search?location=ohio&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Ohio
#                                      </option>
#  <option value="/classifieds/search?location=oklahoma&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Oklahoma
#                                      </option>
#  <option value="/classifieds/search?location=oregon&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Oregon
#                                      </option>
#  <option value="/classifieds/search?location=pennsylvania&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Pennsylvania
#                                      </option>
#  <option value="/classifieds/search?location=puerto-rico-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Puerto Rico
#                                      </option>
#  <option value="/classifieds/search?location=rhode-island&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Rhode Island
#                                      </option>
#  <option value="/classifieds/search?location=south-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          South Carolina
#                                      </option>
#  <option value="/classifieds/search?location=south-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          South Dakota
#                                      </option>
#  <option value="/classifieds/search?location=tennessee&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Tennessee
#                                      </option>
#  <option value="/classifieds/search?location=texas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Texas
#                                      </option>
#  <option value="/classifieds/search?location=utah&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Utah
#                                      </option>
#  <option value="/classifieds/search?location=vermont&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Vermont
#                                      </option>
#  <option value="/classifieds/search?location=virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Virginia
#                                      </option>
#  <option value="/classifieds/search?location=washington&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Washington
#                                      </option>
#  <option value="/classifieds/search?location=west-virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          West Virginia
#                                      </option>
#  <option value="/classifieds/search?location=wisconsin&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Wisconsin
#                                      </option>
#  <option value="/classifieds/search?location=wyoming&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Wyoming
#                                      </option>
#  </select>
#  <br/> <select name="cityDDL" onchange="changeLocation(this)" style="color: #000000; margin-top: 10px;">
#  <option value="">City</option>
#  <option value="/classifieds/search?location=adirondacks-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Adirondacks
#                                      </option>
#  <option value="/classifieds/search?location=albany-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Albany
#                                      </option>
#  <option value="/classifieds/search?location=binghamton-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Binghamton
#                                      </option>
#  <option value="/classifieds/search?location=buffalo-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Buffalo
#                                      </option>
#  <option value="/classifieds/search?location=hudson-valley-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Hudson Valley
#                                      </option>
#  <option value="/classifieds/search?location=long-island-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Long Island
#                                      </option>
#  <option value="/classifieds/search?location=rochester-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Rochester
#                                      </option>
#  <option value="/classifieds/search?location=syracuse-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Syracuse
#                                      </option>
#  <option value="/classifieds/search?location=tri-state-area&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Tri-state area
#                                      </option>
#  <option value="/classifieds/search?location=watertown&amp;category=all&amp;posttype=7&amp;ships=False">
#                                          Watertown
#                                      </option>
#  </select>
#  </div>
#  </div>
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 20px 20px 10px 20px;">
#  <div>
#  <a class="accordion-toggle chevron-rotate" data-toggle="collapse" href="#collapseCategoryMobile">
#  <h3 style="color: #5c724c;">
#  <i class="fa fa-chevron-right"></i> Category
#                                              </h3>
#  </a>
#  </div>
#  <div class="collapse " id="collapseCategoryMobile" style="border-top: solid 1px #aaaaaa;">
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=guns&amp;posttype=7&amp;ships=False">
#  <td><h4 style="color: #5c724c; font-weight: 400;">Firearms</h4></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  <div class="collapse " id="collapsegunsMobile" style="padding: 0px 0px 0px 20px;">
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=antiques&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Antique Firearms</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=handguns&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Handguns</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=muzzle-loaders&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Muzzle Loaders</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=nfa-firearms&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">NFA Firearms</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=rifles&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Rifles</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=shotguns&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Shotguns</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  </div>
#  </div>
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=firearm-accessories&amp;posttype=7&amp;ships=False">
#  <td><h4 style="color: #5c724c; font-weight: 400;">Firearm Accessories</h4></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  <div class="collapse " id="collapsefirearm-accessoriesMobile" style="padding: 0px 0px 0px 20px;">
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=ammo&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Ammo</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-parts&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Gun Parts</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-safes&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Gun Safes</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=holsters&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Holsters</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=magazines&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Magazines</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=optics&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Optics</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=reloading&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Reloading</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=tactical-gear&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Tactical Gear</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  </div>
#  </div>
#  <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=outdoors&amp;posttype=7&amp;ships=False">
#  <td><h4 style="color: #5c724c; font-weight: 400;">Outdoors Gear</h4></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  <div class="collapse " id="collapseoutdoorsMobile" style="padding: 0px 0px 0px 20px;">
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=archery&amp;posttype=7&amp;ships=False">
#  <td><h5 style="color: #5c724c; font-weight: 400;">Archery</h5></td>
#  <td style="width: 21px;">
#  <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <div>
#  <table style="width: 100%;">
#  <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=fishing&amp;posttype=7&amp;ships=False">
# ...
#  //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=aa79cc16&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=46&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=aa79cc16"/></a></noscript>
#  </div>
#  <div class="ad-search">
#  <!--/*
#    *
#    * Revive Adserver Javascript Tag
#    * - Generated with Revive Adserver v3.2.2
#    *
#    */-->
#  <!--/*
#    * The backup image section of this tag has been generated for use on a
#    * non-SSL page. If this tag is to be placed on an SSL page, change the
#    *   'http://revive.armslist.com/revive/www/delivery/...'
#    * to
#    *   'https://revive.armslist.com/revive/www/delivery/...'
#    *
#    * This noscript section of this tag only shows image banners. There
#    * is no width or height in these banners, so if you want these tags to
#    * allocate space for the ad before it shows, you will need to add this
#    * information to the <img> tag.
#    *
#    * If you do not want to deal with the intricities of the noscript
#    * section, delete the tag (from <noscript>... to </noscript>). On
#    * average, the noscript tag is called from less than 1% of internet
#    * users.
#    */-->
#  <script type="text/javascript"><!--//<![CDATA[
#     var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
#  var m3_r = Math.floor(Math.random()*99999999999);
#  if (!document.MAX_used) document.MAX_used = ',';
#  document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
#  document.write ("?zoneid=48");
#  document.write ('&amp;cb=' + m3_r);
#  if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
#  document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
#  document.write ("&amp;loc=" + escape(window.location));
#  if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
#  if (document.context) document.write ("&context=" + escape(document.context));
#  if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
#  document.write ("'><\/scr"+"ipt>");
#  //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=af067137&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=48&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=af067137"/></a></noscript>
#  </div>
#  <div class="ad-search">
#  <!--/*
#    *
#    * Revive Adserver Javascript Tag
#    * - Generated with Revive Adserver v3.2.2
#    *
#    */-->
#  <!--/*
#    * The backup image section of this tag has been generated for use on a
#    * non-SSL page. If this tag is to be placed on an SSL page, change the
#    *   'http://revive.armslist.com/revive/www/delivery/...'
#    * to
#    *   'https://revive.armslist.com/revive/www/delivery/...'
#    *
#    * This noscript section of this tag only shows image banners. There
#    * is no width or height in these banners, so if you want these tags to
#    * allocate space for the ad before it shows, you will need to add this
#    * information to the <img> tag.
#    *
#    * If you do not want to deal with the intricities of the noscript
#    * section, delete the tag (from <noscript>... to </noscript>). On
#    * average, the noscript tag is called from less than 1% of internet
#    * users.
#    */-->
#  <script type="text/javascript"><!--//<![CDATA[
#     var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
#  var m3_r = Math.floor(Math.random()*99999999999);
#  if (!document.MAX_used) document.MAX_used = ',';
#  document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
#  document.write ("?zoneid=47");
#  document.write ('&amp;cb=' + m3_r);
#  if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
#  document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
#  document.write ("&amp;loc=" + escape(window.location));
#  if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
#  if (document.context) document.write ("&context=" + escape(document.context));
#  if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
#  document.write ("'><\/scr"+"ipt>");
#  //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=ae5ac2c4&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=47&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=ae5ac2c4"/></a></noscript>
#  </div>
#  <div style="padding-top: 10px;">
#  <div style='background-color: #2f2d24; text-align: left; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
#  <h2 style="color: #e5e0bf; padding: 5px;">Latest Video</h2>
#  </div>
#  <iframe allowfullscreen="" class="youtube_video" frameborder="0" src="https://www.youtube.com/embed?max-results=1&amp;controls=0&amp;showinfo=0&amp;rel=0&amp;listType=user_uploads&amp;list=ArmslistMedia"></iframe>
#  <div style="clear: both;"> </div>
#  </div>
#  <script type="text/javascript">
#                                  $(document).ready(function () {
#                                      $(".youtube_video").wrap('<div class="youtube_container">');
#                                  });
#                              </script>
#  <div id="rcjsload_dc470c"></div>
#  <script type="text/javascript">
#                                  (function () {
#                                      var referer = ""; try { if (referer = document.referrer, "undefined" == typeof referer || "" == referer) throw "undefined" } catch (exception) { referer = document.location.href, ("" == referer || "undefined" == typeof referer) && (referer = document.URL) } referer = referer.substr(0, 700);
#                                      var rcds = document.getElementById("rcjsload_dc470c");
#                                      var rcel = document.createElement("script");
#                                      rcel.id = 'rc_' + Math.floor(Math.random() * 1000);
#                                      rcel.type = 'text/javascript';
#                                      rcel.src = "//trends.revcontent.com/serve.js.php?w=109511&t=" + rcel.id + "&c=" + (new Date()).getTime() + "&width=" + (window.outerWidth || document.documentElement.clientWidth) + "&referer=" + encodeURIComponent(referer);
#                                      rcel.async = true;
#                                      rcds.appendChild(rcel);
#                                  })();
#                              </script>
#  </div>
#  </div>
#  <style type="text/css">
#                      .ad-search {
#                          margin-top: 16px;
#                      }
#                      .popover{
#                          max-width: none;
#                          width: 300px;
#                      }
#
#                      #bootstrap-overrides h2, #filterByContainer h2 {
#                          margin-top: 0px;
#                      }
#
#                      #bootstrap-overrides h3, #filterByContainer h3 {
#                          margin-top: 0px;
#                          color: #000000;
#                          font-weight: bold;
#                      }
#                      .class_checkbox {
#                          display: inline-block;
#                          padding-top: 4px;
#                          width: 43px;
#                          height: 27px;
#                          background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/OFF_desktop.png);
#                          cursor: pointer;
#
#                      }
#
#                      .class_checkbox.checked {
#                          background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/ON_desktop.png);
#                      }
#
#                      .switches {
#                          font-weight: bold;
#                          color: #000000;
#                      }
#
#                      .clickable-row {
#                          cursor: pointer;
#                      }
#                  </style>
#  <script type="text/javascript">
#
#
#                      function changeLocation(location) {
#                          if (location) {
#                              window.location = $(location).val();;
#                          }
#                          return false;
#                      }
#
#                      $(document).on("click", ".clickable-row", function () {
#                          window.document.location = $(this).data("href");
#
#                      });
#
#                      $(document).on("click", ".chevron-rotate", function () {
#                          if ($(this).parent().find(".fa-chevron-right").length) {
#                              $(this).parent().find(".fa-chevron-right").removeClass("fa-chevron-right").addClass("fa-chevron-down");
#                          } else {
#                              $(this).parent().find(".fa-chevron-down").removeClass("fa-chevron-down").addClass("fa-chevron-right");
#                          }
#                      });
#
#
#                  </script>
#  <!-- HACK FOR EDS -->
#  <table style="display: none;">
#  <tr><td class="title"><a href="/posts/9571384/long-island-new-york-optics-for-sale--vortex-viper">FS: Vortex Viper</a></td></tr>
#  <tr><td class="title"><a href="/posts/9789750/long-island-new-york-rifles-for-sale-trade--chiappa-1892-alaskan-take-down">FS/FT: Chiappa 1892 Alaskan Take Down</a></td></tr>
#  <tr><td class="title"><a href="/posts/9572179/long-island-new-york-gun-parts-for-sale--rossi-coach-gun-overland-parts">FS: Rossi Coach Gun Overland Parts</a></td></tr>
#  <tr><td class="title"><a href="/posts/9503782/long-island-new-york-shotguns-for-sale-trade--rossi-chrome-coach-gun-rare">FS/FT: Rossi Chrome Coach Gun Rare</a></td></tr>
#  <tr><td class="title"><a href="/posts/9504240/long-island-new-york-shotguns-for-sale--savage-24--22lr-over-20ga-">FS: Savage 24  22lr Over 20ga.</a></td></tr>
#  <tr><td class="title"><a href="/posts/9874160/long-island-new-york-shotguns-for-sale--remington-coach-gun-new-old-stock">FS: Remington Coach Gun New Old Stock</a></td></tr>
#  <tr><td class="title"><a href="/posts/10074126/long-island-new-york-rifles-for-sale--ruger-m77-hawkeye-tactical--308">FS: Ruger m77 Hawkeye Tactical .308</a></td></tr>
#  <tr><td class="title"><a href="/posts/10075280/long-island-new-york-shotguns-for-sale--rossi-overland-coach-gun-">FS: Rossi Overland Coach Gun </a></td></tr>
#  <tr><td class="title"><a href="/posts/10078638/long-island-new-york-ammo-for-sale--remington--22-win-mag-case">FS: Remington .22 Win Mag case</a></td></tr>
#  <tr><td class="title"><a href="/posts/10078666/long-island-new-york-ammo-for-sale--winchester--410-pdx1-defender-ammo">FS: Winchester .410 PDX1 Defender Ammo</a></td></tr>
#  <tr><td class="title"><a href="/posts/10078487/watertown-handguns-for-sale--ruger-security-six--357">FS: Ruger Security Six .357</a></td></tr>
#  <tr><td class="title"><a href="/posts/10110105/rochester-new-york-handguns-for-sale---glock-45-9mm-10rd-3-mags-frt-ser">FS:  GLOCK 45 9MM 10RD 3 MAGS FRT SER</a></td></tr>
#  <tr><td class="title"><a href="/posts/10059192/rochester-new-york-handguns-for-sale--taurus-605">FS: Taurus 605</a></td></tr>
#  <tr><td class="title"><a href="/posts/7876495/rochester-new-york-holsters-for-sale--ruger-lcpii-kydex-holster-and-ruger-mag">FS: Ruger LCPII kydex holster and Ruger mag</a></td></tr>
#  <tr><td class="title"><a href="/posts/7959698/rochester-new-york-handguns-for-sale--taylor---co---uberti--smoke-wagon--357">FS: Taylor &amp; Co. (Uberti) Smoke Wagon .357</a></td></tr>
#  </table>
#  </div>
#  </main>
#  <style type="text/css"> body { overflow: visible; } </style>
#  <footer id="footer" style="display: table;">
#  <div class="top-hold hidden-xs">
#  <div class="container-fluid">
#  <div class="row">
#  <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
#  </div>
#  </div>
#  </div>
#  <div class="container-fluid">
#  <div class="row">
#  <div class="col-md-6 col-md-offset-3 col-sm-8 col-sm-offset-2">
#  <ul class="social-list">
#  <li>
#  <a class="icon-youtube" href="http://www.youtube.com/user/armslistmedia?sub_confirmation=1" target="_blank" title="Armslist Youtube channel"></a>
#  </li>
#  <li>
#  <a class="icon-instagram" href="https://instagram.com/armslist/" target="_blank" title="Armslist on Instagram"></a>
#  </li>
#  <li>
#  <a class="icon-facebook" href="https://www.facebook.com/armslist" target="_blank" title="Armslist on Facebook"></a>
#  </li>
#  <li>
#  <a class="icon-twitter" href="https://twitter.com/armslist" target="_blank" title="Armslist Twitter page"></a>
#  </li>
#  <li>
#  <a class="icon-google-plus" href="https://plus.google.com/103978926144598391141/posts" target="_blank" title="Armslist on Google+"></a>
#  </li>
#  </ul>
#  <div class="text-block">
#  <p>Always comply with local, state, federal, and international law.
#  ARMSLIST does not become involved in transactions between parties. Review our
#  <a href="/info/privacy">privacy policy</a> and <a href="/info/terms">terms of use</a> for more
#  information. Report Illegal Firearms Activity to 1-800-ATF-GUNS.  </p>
#  </div>
#  <span class="copy">
#                              Copyright © 2019 Armslist, LLC |
#
#                              | Version: 15.0.2
#                          </span>
#  </div>
#  </div>
#  </div>
#  <script id="LOTCC_3569" src="http://tags.crwdcntrl.net/c/3569/cc.js?ns=_cc3569" type="text/javascript"></script>
#  <script language="javascript" type="text/javascript"> _cc3569.bcp(); </script>
#  </footer>
#  </div>
#  <div class="loader-box">
#  <img alt="loader" height="64" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/loader.gif" width="64"/>
#  </div>
#  <script>   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');    ga('create', 'UA-5138407-1', 'auto');   ga('send', 'pageview');  </script>
#  </body>, '\n']

# %%
list(myHtml.children)[3]
# Out:
# <body style="-webkit-overflow-scrolling: touch;">
# <div class="modal fade" id="termsModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">TERMS OF USE</h4>
# </div>
# <div class="modal-body">
# <div id="termsModalContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" onclick="acceptTerms()" type="button">Accept</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="promotionModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">PROMOTIONAL LINK</h4>
# </div>
# <div class="modal-body">
# <div id="promotionModalContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="filterByModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 style="color: #655d5b">Filter By</h4>
# </div>
# <div class="modal-body">
# <div id="filterByContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="dropinModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <h4 style="color: #655d5b">Armslist</h4>
# </div>
# <div class="modal-body">
# <div id="dropinModalContainer"></div>
# <input id="dropinModalTextBox" type="text"/>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" onclick="noThanksDropin()" style="float: left;" type="button">Close</button>
# <button class="btn btn-primary" onclick="saveDropin()" type="button">Submit</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="contactSellerEmailModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 style="color: #655d5b">Contact Seller</h4>
# </div>
# <div class="modal-body">
# <div id="messageSellerContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="pull-left btn btn-default" id="contactFormSubmitBtn" onclick="doMessageSend()" type="button">Send</button>
# <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="searchAlertModal" role="dialog" style="color: #655D5B !important; z-index: 100000 !important;">
# <div class="modal-dialog">
# <!-- Modal content-->
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 style="color: #655d5b">Search Alert</h4>
# </div>
# <div class="modal-body">
# <div id="searchAlertContainer"></div>
# </div>
# <div class="modal-footer">
# <button class="pull-left btn btn-default" id="searchAlertFormSubmitBtn" onclick="createSearchAlert()" type="button">Create</button>
# <button class="btn btn-default" data-dismiss="modal" type="button">Cancel</button>
# </div>
# </div>
# </div>
# </div>
# <div id="wrapper">
# <header class="navbar-default text-uppercase" id="header" role="navigation">
# <div class="top-holder">
# <div class="container-fluid">
# <button class="navbar-toggle text-uppercase pull-left" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" id="popoverMobileViewMainMenu" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="text">Menu</span>
# </button>
# <div id="popovercontentMobileViewMainMenu" style="display: none;">
# <div class="container-fluid">
# <div class="row" id="h3Overrides">
# <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#                         $(document).ready(function () {
#
#                             $("#popoverMobileViewMainMenu").popover({
#                                 html: true,
#                                 container: 'body',
#                                 content: function () {
#                                     return $('#popovercontentMobileViewMainMenu').html();
#                                 }
#                             });
#
#                             $('html').on('click', function (e) {
#                                 if (typeof $(e.target).data('original-title') == 'undefined' &&
#                                     !$(e.target).parents().is('.popover.in') &&
#                                     $(e.target).parent().attr("id") !== "popoverMobileViewMainMenu") {
#                                     $('[data-original-title]').popover('hide');
#                                 }
#                             });
#                         });
#
#                     </script>
# <div class="pull-right align-right">
# <form action="/classifieds/search" class="search-form navbar-form hidden-xs" method="get" role="search"> <fieldset>
# <div class="form-group">
# <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
# <input name="location" type="hidden" value="new-york">
# <input name="category" type="hidden" value="all"/>
# <input name="posttype" type="hidden" value="7"/>
# <input name="ships" type="hidden"/>
# </input></div>
# <button class="btn btn-default icon-search" type="submit"></button>
# </fieldset>
# </form>
# <a class="btn btn-warning create-btn text-uppercase" href="/posts/new"><span class="hidden-sm hidden-xs">CREATE A LISTING</span> <i class="icon-pencil"></i> <span class="visible-sm visible-xs">list</span></a>
# <ul class="users-list hidden-xs">
# <li><a href="/account/new">CREATE AN ACCOUNT</a></li>
# <li><a href="/accountlogin">LOGIN</a></li>
# </ul>
# <button class="btn btn-warning create-btn text-uppercase visible-xs" onclick="showHideSearchMobile()" type="button"><i class="icon-search"></i> <span class="visible-xs">search</span></button>
# <script type="text/javascript">
#                             function showHideSearchMobile() {
#                                 $("#searchMobileView").fadeToggle();
#                             }
#                         </script>
# </div>
# <div class="pull-left" id="logo">
# <a href="/" title="ARMSLIST - Firearms Classifieds">
# <picture>
# <!--[if IE 9]><video style="display: none;"><![endif]-->
# <source media="(max-width: 767px)" srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-mobile@2x.png 2x"/>
# <source srcset="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png, https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop@2x.png 2x"/>
# <!--[if IE 9]></video><![endif]-->
# <img alt="armslist firearms marketplace" height="66" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/logo-desktop.png" width="260"/>
# </picture>
# </a>
# </div>
# </div>
# </div>
# <div class="hidden-xs"><br/><br/></div>
# <div class="alert " id="mainMessageContainer" style="display: none; margin-bottom: 0px;">
# <div id="mainMessageContainer_Message" style="text-align: center;"></div>
# </div>
# <div class="hidden-sm hidden-md hidden-lg" id="searchMobileView" style="padding: 20px 10px 10px 20px; text-align: center; display: none;">
# <form action="/classifieds/search" class="search-form" method="get" role="search" style="width: 75% !important;"> <fieldset>
# <div class="form-group">
# <input class="form-control" name="search" placeholder="Search listings" type="text" value=""/>
# <input name="location" type="hidden" value="new-york">
# <input name="category" type="hidden" value="all"/>
# <input name="posttype" type="hidden" value="7"/>
# <input name="ships" type="hidden"/>
# </input></div>
# <button class="btn btn-default icon-search" type="submit"></button>
# </fieldset>
# </form> <br/>
# <div class="carousel slide" data-ride="carousel" id="myCarousel" style="padding-top: 20px;">
# <!-- Wrapper for slides -->
# <div class="carousel-inner" role="listbox">
# <div class="item active">
# <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
# <a href="/classifieds/search?category=handguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">HANDGUNS <br/><i class="icon-handguns"></i></a>
# <a href="/classifieds/search?category=shotguns&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">SHOTGUNS <br/><i class="icon-shotguns"></i></a>
# <a href="/classifieds/search?category=rifles&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">RIFLES <br/><i class="icon-rifles"></i></a>
# </div>
# </div>
# <div class="item">
# <div style='text-align: center; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
# <a href="/classifieds/search?category=firearm-accessories&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; padding-right: 10px; display: inline-block;">ACCESSORIES <br/><i class="icon-scope"></i></a>
# <a href="/classifieds/search?category=outdoors&amp;location=usa&amp;posttype=7&amp;ships=False" style="color: #e5e0bf; display: inline-block;">GEAR + MORE <br/><i class="icon-gear"></i></a>
# </div>
# </div>
# </div>
# <!-- Left and right controls -->
# <a class="left carousel-control" data-slide="prev" href="#myCarousel" role="button">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-left"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="right carousel-control" data-slide="next" href="#myCarousel" role="button">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-right"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# <style type="text/css">
#                     .carousel-control.left, .carousel-control.right {
#                         background-image: none;
#                     }
#                 </style>
# </div>
# </header>
# <main id="main">
# <div class="container-fluid" style="color: #655D5B;">
# <div id="bootstrap-overrides">
# <div class="col-xs-12 col-md-4" style="padding-top: 15px;">
# <h3>1 - 15 of 1118 results in All Categories</h3>
# </div>
# <div class="col-xs-12 col-md-8">
# <div class="col-xs-3 col-md-3" style="padding: 15px 0px 0px 0px; margin: 0px;">
# <a class="hidden-md hidden-lg" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Alert</a>
# <a class="hidden-xs hidden-sm" data-target="#searchAlertModal" data-toggle="modal" href="#" onclick="doCreateSearchAlert(this)"><i class="fa fa-bullhorn"></i> Set a Search Alert</a>
# <script type="text/javascript">
#                 function newInitRecaptcha() {
#                     $.getScript("https://www.google.com/recaptcha/api/js/recaptcha_ajax.js", function () {
#                         Recaptcha.create(
#                             RecaptchaOptions.publicKey,     // public key, declared in Recaptcha view
#                             "recaptchaControls",            // id
#                             RecaptchaOptions                // options, declared in Recaptcha view
#                         );
#                     });
#                 }
#
#                 function doCreateSearchAlert(obj) {
#                     //var $dialog = $("#searchAlertDialog");
#                     //if ($dialog.length == 0) {
#                     //    $dialog = $('<div id="searchAlertDialog"></div>');
#                     //    $("body").append($dialog);
#                     //}
#                     //$dialog.html("");
#                     $.ajax({
#                         url: "/searchalerts/new",
#                         cache: false,
#                         success: function (data) {
#                             $("#searchAlertContainer").html(data);
#                             newInitRecaptcha();
#                             //$dialog.html(data);
#                             //listmill.app.initRecaptcha();
#                             //$dialog.dialog({
#                             //    title: "New Search Alert",
#                             //    modal: true,
#                             //    width: 460,
#                             //    buttons: [
#                             //        { text: "Create", click: createSearchAlert },
#                             //        { text: "Cancel", click: function () { $(this).dialog("close"); } },
#                             //    ]
#                             //});
#                             //$("#name").focus();
#                         }
#                     });
#                     return false;
#                 }
#
#                 function createSearchAlert() {
#                     var $dialog = $("#searchAlertContainer");
#                     var $form = $dialog.find("form");
#                     $.ajax({
#                         url: $form.attr("action"),
#                         type: "POST",
#                         data: $form.serialize(),
#                         success: createSearchAlertCallback,
#                         error: function () {
#                             $('#searchAlertModal').modal('hide');
#                             alert("There was a problem creating the search alert.");
#                         }
#                     });
#                 }
#
#                 function createSearchAlertCallback(data) {
#                     if (data === "success") {
#
#                         $('#searchAlertModal').modal('hide');
#                         alert("Search Alert Created");
#                         //listmill.app.showMessage("success", "Search Alert successfully created! You should receive a confirmation email shortly.");
#                         //$("#searchAlertDialog").dialog("close");
#                     } else {
#                         $("#searchAlertContainer").html(data);
#                         newInitRecaptcha();
#                         //var $dialog = $("#searchAlertDialog");
#                         //$dialog.html(data);
#                         //$dialog.dialog("open");
#                         //listmill.app.initRecaptcha();
#                     }
#                 }
#             </script>
# </div>
# <div class="col-xs-4 col-md-4" style="padding: 15px 0px 0px 0px;">
# <a class="" href="/deals" style="color: #cb2027;"><i class="fa fa-star"></i> Deals <i class="fa fa-star"></i></a>
# </div>
# <div class="hidden-md hidden-lg" style="float: right; padding: 15px 0px 15px 15px; position: relative;">
# <!--<a data-placement="bottom" id="popoverMobileView" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>-->
# <a data-target="#filterByModal" data-toggle="modal" href="#"><i class="fa fa-chevron-right"></i> FILTERED BY</a>
# <div id="popovercontentMobileView" style="display: none;">
# <div style="padding: 10px; text-align: center;">
# <a class="clear-all" href="/classifieds/search?location=new-york&amp;category=all" title="Remove All">Clear All</a>
# </div>
# <div style="padding: 10px; border-top: solid 1px #aaaaaa; border-bottom: solid 1px #aaaaaa;">
# <table style="width: 100%">
# <tr>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Private Party<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=4&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Premium Vendor<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;sellertype=1&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Vendors that Ship<br>
# <a class="class_checkbox " href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=True"></a>
# </br></td>
# </tr>
# <tr><td colspan="3" style="border-top: solid 1px #aaaaaa;"> </td></tr>
# <tr>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 For Sale<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=6&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 For Trade<br>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=5&amp;ships=False"></a>
# </br></td>
# <td class="switches" style="text-align: center;" valign="middle">
#                                 Want to Buy<br/>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=3&amp;ships=False"></a>
# </td>
# </tr>
# </table>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 20px;">
# <h3 style="color: #555555;">LOCATION</h3>
# <div style="position: relative; color: #000000; background: url('https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png') no-repeat center;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/New York.png" style="opacity: 0;"/>
# <div style="position: absolute; top: 20%; width: 100%; text-align: center;">
#                                     Searching in<br/>
# <h2 style="font-weight: bold; color: #000000;">
# New York
#                                     </h2>
# </div>
# </div>
# <br/>
# <div>
# <select id="locationDDL" name="stateDDL" onchange="changeLocation(this)" style="color: #000000;">
# <option value="">State</option>
# <option value="/classifieds/search?location=alabama&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Alabama
#                                     </option>
# <option value="/classifieds/search?location=alaska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Alaska
#                                     </option>
# <option value="/classifieds/search?location=arizona&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Arizona
#                                     </option>
# <option value="/classifieds/search?location=arkansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Arkansas
#                                     </option>
# <option value="/classifieds/search?location=california&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         California
#                                     </option>
# <option value="/classifieds/search?location=colorado&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Colorado
#                                     </option>
# <option value="/classifieds/search?location=connecticut&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Connecticut
#                                     </option>
# <option value="/classifieds/search?location=delaware&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Delaware
#                                     </option>
# <option value="/classifieds/search?location=florida&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Florida
#                                     </option>
# <option value="/classifieds/search?location=georgia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Georgia
#                                     </option>
# <option value="/classifieds/search?location=guam-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Guam
#                                     </option>
# <option value="/classifieds/search?location=hawaii&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Hawaii
#                                     </option>
# <option value="/classifieds/search?location=idaho&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Idaho
#                                     </option>
# <option value="/classifieds/search?location=illinois&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Illinois
#                                     </option>
# <option value="/classifieds/search?location=indiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Indiana
#                                     </option>
# <option value="/classifieds/search?location=iowa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Iowa
#                                     </option>
# <option value="/classifieds/search?location=kansas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Kansas
#                                     </option>
# <option value="/classifieds/search?location=kentucky&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Kentucky
#                                     </option>
# <option value="/classifieds/search?location=louisiana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Louisiana
#                                     </option>
# <option value="/classifieds/search?location=maine&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Maine
#                                     </option>
# <option value="/classifieds/search?location=maryland&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Maryland
#                                     </option>
# <option value="/classifieds/search?location=massachusetts&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Massachusetts
#                                     </option>
# <option value="/classifieds/search?location=michigan&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Michigan
#                                     </option>
# <option value="/classifieds/search?location=minnesota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Minnesota
#                                     </option>
# <option value="/classifieds/search?location=mississippi&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Mississippi
#                                     </option>
# <option value="/classifieds/search?location=missouri&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Missouri
#                                     </option>
# <option value="/classifieds/search?location=montana&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Montana
#                                     </option>
# <option value="/classifieds/search?location=nebraska&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Nebraska
#                                     </option>
# <option value="/classifieds/search?location=nevada&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Nevada
#                                     </option>
# <option value="/classifieds/search?location=new-hampshire&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New Hampshire
#                                     </option>
# <option value="/classifieds/search?location=nj&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New Jersey
#                                     </option>
# <option value="/classifieds/search?location=new-mexico&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New Mexico
#                                     </option>
# <option selected="selected" value="/classifieds/search?location=new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         New York
#                                     </option>
# <option value="/classifieds/search?location=north-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         North Carolina
#                                     </option>
# <option value="/classifieds/search?location=north-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         North Dakota
#                                     </option>
# <option value="/classifieds/search?location=ohio&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Ohio
#                                     </option>
# <option value="/classifieds/search?location=oklahoma&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Oklahoma
#                                     </option>
# <option value="/classifieds/search?location=oregon&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Oregon
#                                     </option>
# <option value="/classifieds/search?location=pennsylvania&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Pennsylvania
#                                     </option>
# <option value="/classifieds/search?location=puerto-rico-usa&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Puerto Rico
#                                     </option>
# <option value="/classifieds/search?location=rhode-island&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Rhode Island
#                                     </option>
# <option value="/classifieds/search?location=south-carolina&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         South Carolina
#                                     </option>
# <option value="/classifieds/search?location=south-dakota&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         South Dakota
#                                     </option>
# <option value="/classifieds/search?location=tennessee&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Tennessee
#                                     </option>
# <option value="/classifieds/search?location=texas&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Texas
#                                     </option>
# <option value="/classifieds/search?location=utah&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Utah
#                                     </option>
# <option value="/classifieds/search?location=vermont&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Vermont
#                                     </option>
# <option value="/classifieds/search?location=virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Virginia
#                                     </option>
# <option value="/classifieds/search?location=washington&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Washington
#                                     </option>
# <option value="/classifieds/search?location=west-virginia&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         West Virginia
#                                     </option>
# <option value="/classifieds/search?location=wisconsin&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Wisconsin
#                                     </option>
# <option value="/classifieds/search?location=wyoming&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Wyoming
#                                     </option>
# </select>
# <br/> <select name="cityDDL" onchange="changeLocation(this)" style="color: #000000; margin-top: 10px;">
# <option value="">City</option>
# <option value="/classifieds/search?location=adirondacks-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Adirondacks
#                                     </option>
# <option value="/classifieds/search?location=albany-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Albany
#                                     </option>
# <option value="/classifieds/search?location=binghamton-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Binghamton
#                                     </option>
# <option value="/classifieds/search?location=buffalo-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Buffalo
#                                     </option>
# <option value="/classifieds/search?location=hudson-valley-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Hudson Valley
#                                     </option>
# <option value="/classifieds/search?location=long-island-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Long Island
#                                     </option>
# <option value="/classifieds/search?location=rochester-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Rochester
#                                     </option>
# <option value="/classifieds/search?location=syracuse-new-york&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Syracuse
#                                     </option>
# <option value="/classifieds/search?location=tri-state-area&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Tri-state area
#                                     </option>
# <option value="/classifieds/search?location=watertown&amp;category=all&amp;posttype=7&amp;ships=False">
#                                         Watertown
#                                     </option>
# </select>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 20px 20px 10px 20px;">
# <div>
# <a class="accordion-toggle chevron-rotate" data-toggle="collapse" href="#collapseCategoryMobile">
# <h3 style="color: #5c724c;">
# <i class="fa fa-chevron-right"></i> Category
#                                             </h3>
# </a>
# </div>
# <div class="collapse " id="collapseCategoryMobile" style="border-top: solid 1px #aaaaaa;">
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=guns&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Firearms</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapsegunsMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=antiques&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Antique Firearms</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=handguns&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Handguns</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=muzzle-loaders&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Muzzle Loaders</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=nfa-firearms&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">NFA Firearms</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=rifles&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Rifles</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=shotguns&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Shotguns</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=firearm-accessories&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Firearm Accessories</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapsefirearm-accessoriesMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=ammo&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Ammo</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-parts&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Gun Parts</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=gun-safes&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Gun Safes</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=holsters&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Holsters</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=magazines&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Magazines</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=optics&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Optics</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=reloading&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Reloading</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=tactical-gear&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Tactical Gear</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=outdoors&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Outdoors Gear</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapseoutdoorsMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=archery&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Archery</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=fishing&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Fishing Gear</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=hunting&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Hunting Gear</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=knives&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Knives</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=targets-and-range-equipment&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Targets and Range Equipment</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=other&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Other Items</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapseotherMobile" style="padding: 0px 0px 0px 20px;">
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=air-guns&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Air Guns</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=farming&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Farming Equipment</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=misc&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Miscellaneous</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=paintball&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Paintball/Airsoft</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# <div>
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=vehicles&amp;posttype=7&amp;ships=False">
# <td><h5 style="color: #5c724c; font-weight: 400;">Vehicles</h5></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=events&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Events</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapseeventsMobile" style="padding: 0px 0px 0px 20px;">
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=firearms-training&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Firearms Training</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapsefirearms-trainingMobile" style="padding: 0px 0px 0px 20px;">
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 5px 0px 5px 0px;">
# <table style="width: 100%;">
# <tr class="clickable-row" data-href="/classifieds/search?location=new-york&amp;category=services&amp;posttype=7&amp;ships=False">
# <td><h4 style="color: #5c724c; font-weight: 400;">Services</h4></td>
# <td style="width: 21px;">
# <img src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/circle_OFF.png"/>
# </td>
# </tr>
# </table>
# <div class="collapse " id="collapseservicesMobile" style="padding: 0px 0px 0px 20px;">
# </div>
# </div>
# </div>
# </div>
# <div style="border-bottom: solid 1px #aaaaaa; padding: 20px 20px 10px 20px;">
# <a href="/classifieds/powersearch">
# <h3 style="color: #5c724c;">
# <i class="fa fa-chevron-right"></i> Power Search
#                         </h3>
# </a>
# </div>
# </div>
# <script type="text/javascript">
#                                 $(document).ready(function () {
#                                     $("#filterByContainer").html($('#popovercontentMobileView').html());
#                                     /*$("#popoverMobileView").popover({
#                                         html: true,
#
#                                         content: function () {
#                                             return $('#popovercontentMobileView').html();
#                                         },
#                                         selector: "#popoverMobileView"
#                                     });*/
#
#                                 });
#
#                             </script>
# </div>
# </div>
# <div class="hidden-xs hidden-sm col-md-12" style="margin: 0px;">
# <div style="float: left; padding-right: 10px;">
# <table>
# <tr>
# <td class="switches" valign="middle">For Sale </td>
# <td>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=6&amp;ships=False"></a>
# </td>
# </tr>
# </table>
# </div>
# <div style="float: left; padding-right: 10px;">
# <table>
# <tr>
# <td class="switches" valign="middle">For Trade </td>
# <td>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=5&amp;ships=False"></a>
# </td>
# </tr>
# </table>
# </div>
# <div style="float: left; padding-right: 10px;">
# <table>
# <tr>
# <td class="switches" valign="middle">Want to Buy </td>
# <td>
# <a class="class_checkbox checked" href="/classifieds/search?location=new-york&amp;category=all&amp;posttype=3&amp;ships=False"></a>
# </td>
# </tr>
# </table>
# </div>
# <div style="float: right; padding-left: 10px;">
# <table>
# <tr>
# <td class="switches" valign="middle">Private Party </td>
# <td>
# ...
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=aa79cc16&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=46&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=aa79cc16"/></a></noscript>
# </div>
# <div class="ad-search">
# <!--/*
#   *
#   * Revive Adserver Javascript Tag
#   * - Generated with Revive Adserver v3.2.2
#   *
#   */-->
# <!--/*
#   * The backup image section of this tag has been generated for use on a
#   * non-SSL page. If this tag is to be placed on an SSL page, change the
#   *   'http://revive.armslist.com/revive/www/delivery/...'
#   * to
#   *   'https://revive.armslist.com/revive/www/delivery/...'
#   *
#   * This noscript section of this tag only shows image banners. There
#   * is no width or height in these banners, so if you want these tags to
#   * allocate space for the ad before it shows, you will need to add this
#   * information to the <img> tag.
#   *
#   * If you do not want to deal with the intricities of the noscript
#   * section, delete the tag (from <noscript>... to </noscript>). On
#   * average, the noscript tag is called from less than 1% of internet
#   * users.
#   */-->
# <script type="text/javascript"><!--//<![CDATA[
#    var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
# var m3_r = Math.floor(Math.random()*99999999999);
# if (!document.MAX_used) document.MAX_used = ',';
# document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
# document.write ("?zoneid=48");
# document.write ('&amp;cb=' + m3_r);
# if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
# document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
# document.write ("&amp;loc=" + escape(window.location));
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=af067137&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=48&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=af067137"/></a></noscript>
# </div>
# <div class="ad-search">
# <!--/*
#   *
#   * Revive Adserver Javascript Tag
#   * - Generated with Revive Adserver v3.2.2
#   *
#   */-->
# <!--/*
#   * The backup image section of this tag has been generated for use on a
#   * non-SSL page. If this tag is to be placed on an SSL page, change the
#   *   'http://revive.armslist.com/revive/www/delivery/...'
#   * to
#   *   'https://revive.armslist.com/revive/www/delivery/...'
#   *
#   * This noscript section of this tag only shows image banners. There
#   * is no width or height in these banners, so if you want these tags to
#   * allocate space for the ad before it shows, you will need to add this
#   * information to the <img> tag.
#   *
#   * If you do not want to deal with the intricities of the noscript
#   * section, delete the tag (from <noscript>... to </noscript>). On
#   * average, the noscript tag is called from less than 1% of internet
#   * users.
#   */-->
# <script type="text/javascript"><!--//<![CDATA[
#    var m3_u = (location.protocol=='https:'?'https://revive.armslist.com/revive/www/delivery/ajs.php':'http://revive.armslist.com/revive/www/delivery/ajs.php');
# var m3_r = Math.floor(Math.random()*99999999999);
# if (!document.MAX_used) document.MAX_used = ',';
# document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
# document.write ("?zoneid=47");
# document.write ('&amp;cb=' + m3_r);
# if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
# document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
# document.write ("&amp;loc=" + escape(window.location));
# if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
# if (document.context) document.write ("&context=" + escape(document.context));
# if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
# document.write ("'><\/scr"+"ipt>");
# //]]>--></script><noscript><a href="http://revive.armslist.com/revive/www/delivery/ck.php?n=ae5ac2c4&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" border="0" src="http://revive.armslist.com/revive/www/delivery/avw.php?zoneid=47&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=ae5ac2c4"/></a></noscript>
# </div>
# <div style="padding-top: 10px;">
# <div style='background-color: #2f2d24; text-align: left; font: 300 16px/19px "Oswald", "Arial", "Helvetica", sans-serif; text-decoration: none; text-transform: uppercase;'>
# <h2 style="color: #e5e0bf; padding: 5px;">Latest Video</h2>
# </div>
# <iframe allowfullscreen="" class="youtube_video" frameborder="0" src="https://www.youtube.com/embed?max-results=1&amp;controls=0&amp;showinfo=0&amp;rel=0&amp;listType=user_uploads&amp;list=ArmslistMedia"></iframe>
# <div style="clear: both;"> </div>
# </div>
# <script type="text/javascript">
#                                 $(document).ready(function () {
#                                     $(".youtube_video").wrap('<div class="youtube_container">');
#                                 });
#                             </script>
# <div id="rcjsload_dc470c"></div>
# <script type="text/javascript">
#                                 (function () {
#                                     var referer = ""; try { if (referer = document.referrer, "undefined" == typeof referer || "" == referer) throw "undefined" } catch (exception) { referer = document.location.href, ("" == referer || "undefined" == typeof referer) && (referer = document.URL) } referer = referer.substr(0, 700);
#                                     var rcds = document.getElementById("rcjsload_dc470c");
#                                     var rcel = document.createElement("script");
#                                     rcel.id = 'rc_' + Math.floor(Math.random() * 1000);
#                                     rcel.type = 'text/javascript';
#                                     rcel.src = "//trends.revcontent.com/serve.js.php?w=109511&t=" + rcel.id + "&c=" + (new Date()).getTime() + "&width=" + (window.outerWidth || document.documentElement.clientWidth) + "&referer=" + encodeURIComponent(referer);
#                                     rcel.async = true;
#                                     rcds.appendChild(rcel);
#                                 })();
#                             </script>
# </div>
# </div>
# <style type="text/css">
#                     .ad-search {
#                         margin-top: 16px;
#                     }
#                     .popover{
#                         max-width: none;
#                         width: 300px;
#                     }
#
#                     #bootstrap-overrides h2, #filterByContainer h2 {
#                         margin-top: 0px;
#                     }
#
#                     #bootstrap-overrides h3, #filterByContainer h3 {
#                         margin-top: 0px;
#                         color: #000000;
#                         font-weight: bold;
#                     }
#                     .class_checkbox {
#                         display: inline-block;
#                         padding-top: 4px;
#                         width: 43px;
#                         height: 27px;
#                         background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/OFF_desktop.png);
#                         cursor: pointer;
#
#                     }
#
#                     .class_checkbox.checked {
#                         background-image: url(https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/ON_desktop.png);
#                     }
#
#                     .switches {
#                         font-weight: bold;
#                         color: #000000;
#                     }
#
#                     .clickable-row {
#                         cursor: pointer;
#                     }
#                 </style>
# <script type="text/javascript">
#
#
#                     function changeLocation(location) {
#                         if (location) {
#                             window.location = $(location).val();;
#                         }
#                         return false;
#                     }
#
#                     $(document).on("click", ".clickable-row", function () {
#                         window.document.location = $(this).data("href");
#
#                     });
#
#                     $(document).on("click", ".chevron-rotate", function () {
#                         if ($(this).parent().find(".fa-chevron-right").length) {
#                             $(this).parent().find(".fa-chevron-right").removeClass("fa-chevron-right").addClass("fa-chevron-down");
#                         } else {
#                             $(this).parent().find(".fa-chevron-down").removeClass("fa-chevron-down").addClass("fa-chevron-right");
#                         }
#                     });
#
#
#                 </script>
# <!-- HACK FOR EDS -->
# <table style="display: none;">
# <tr><td class="title"><a href="/posts/9571384/long-island-new-york-optics-for-sale--vortex-viper">FS: Vortex Viper</a></td></tr>
# <tr><td class="title"><a href="/posts/9789750/long-island-new-york-rifles-for-sale-trade--chiappa-1892-alaskan-take-down">FS/FT: Chiappa 1892 Alaskan Take Down</a></td></tr>
# <tr><td class="title"><a href="/posts/9572179/long-island-new-york-gun-parts-for-sale--rossi-coach-gun-overland-parts">FS: Rossi Coach Gun Overland Parts</a></td></tr>
# <tr><td class="title"><a href="/posts/9503782/long-island-new-york-shotguns-for-sale-trade--rossi-chrome-coach-gun-rare">FS/FT: Rossi Chrome Coach Gun Rare</a></td></tr>
# <tr><td class="title"><a href="/posts/9504240/long-island-new-york-shotguns-for-sale--savage-24--22lr-over-20ga-">FS: Savage 24  22lr Over 20ga.</a></td></tr>
# <tr><td class="title"><a href="/posts/9874160/long-island-new-york-shotguns-for-sale--remington-coach-gun-new-old-stock">FS: Remington Coach Gun New Old Stock</a></td></tr>
# <tr><td class="title"><a href="/posts/10074126/long-island-new-york-rifles-for-sale--ruger-m77-hawkeye-tactical--308">FS: Ruger m77 Hawkeye Tactical .308</a></td></tr>
# <tr><td class="title"><a href="/posts/10075280/long-island-new-york-shotguns-for-sale--rossi-overland-coach-gun-">FS: Rossi Overland Coach Gun </a></td></tr>
# <tr><td class="title"><a href="/posts/10078638/long-island-new-york-ammo-for-sale--remington--22-win-mag-case">FS: Remington .22 Win Mag case</a></td></tr>
# <tr><td class="title"><a href="/posts/10078666/long-island-new-york-ammo-for-sale--winchester--410-pdx1-defender-ammo">FS: Winchester .410 PDX1 Defender Ammo</a></td></tr>
# <tr><td class="title"><a href="/posts/10078487/watertown-handguns-for-sale--ruger-security-six--357">FS: Ruger Security Six .357</a></td></tr>
# <tr><td class="title"><a href="/posts/10110105/rochester-new-york-handguns-for-sale---glock-45-9mm-10rd-3-mags-frt-ser">FS:  GLOCK 45 9MM 10RD 3 MAGS FRT SER</a></td></tr>
# <tr><td class="title"><a href="/posts/10059192/rochester-new-york-handguns-for-sale--taurus-605">FS: Taurus 605</a></td></tr>
# <tr><td class="title"><a href="/posts/7876495/rochester-new-york-holsters-for-sale--ruger-lcpii-kydex-holster-and-ruger-mag">FS: Ruger LCPII kydex holster and Ruger mag</a></td></tr>
# <tr><td class="title"><a href="/posts/7959698/rochester-new-york-handguns-for-sale--taylor---co---uberti--smoke-wagon--357">FS: Taylor &amp; Co. (Uberti) Smoke Wagon .357</a></td></tr>
# </table>
# </div>
# </main>
# <style type="text/css"> body { overflow: visible; } </style>
# <footer id="footer" style="display: table;">
# <div class="top-hold hidden-xs">
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-3 col-sm-6 col-lg-offset-1 col-md-offset-0"> <h3 class="text-uppercase">ACCOUNT &amp; LISTINGS </h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/accountlogin/new">Account Login</a></li> <li><a href="//www.armslist.com/account/new">New Account</a></li> <li><a href="//www.armslist.com/posts/new">Create a New Listing</a></li> <li><a href="//www.armslist.com/posts/resendactivation">Edit or Remove a Listing</a></li> </ul> </div> <div class="col-lg-2 col-md-3 col-sm-6"> <h3 class="text-uppercase">ABOUT &amp; HELP</h3> <ul class="nav-footer"> <li><a href="//www.armslist.com/info/faqs">FAQs</a></li> <li><a href="//www.armslist.com/info/contact">Contact Armslist</a></li> <li><a href="//www.armslist.com/info/privacy">Privacy Policy</a></li> <li><a href="//www.armslist.com/info/terms">Terms of Use</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">MORE ARMSLIST LINKS </h3> <ul class="nav-footer"> <li><a href="https://www.armslist.com/blog/">Armslist Blog</a></li> <li><a href="https://www.armslist.com/giveaways">Armslist Giveaway</a></li> <li><a href="http://www.armslist.com/contests/">Armslist Contests</a></li> <li><a href="http://www.armslistlegaldefensefund.com/">Armslist Legal Defense Fund</a></li> <li><a href="//www.armslist.com/info/advertise">Advertising with Armslist</a></li> </ul> </div> <div class="col-md-3 col-sm-6"> <h3 class="text-uppercase">PARTNER SITES</h3> <ul class="nav-footer"> <li><a href="http://www.torquelist.com/">Torquelist Vehicle Trader</a></li> <li><a href="http://www.rangemonkey.com/">Range Monkey</a></li> <li><a href="http://www.invictusgearcompany.com/">Invictus Gear </a></li> </ul> </div>
# </div>
# </div>
# </div>
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-6 col-md-offset-3 col-sm-8 col-sm-offset-2">
# <ul class="social-list">
# <li>
# <a class="icon-youtube" href="http://www.youtube.com/user/armslistmedia?sub_confirmation=1" target="_blank" title="Armslist Youtube channel"></a>
# </li>
# <li>
# <a class="icon-instagram" href="https://instagram.com/armslist/" target="_blank" title="Armslist on Instagram"></a>
# </li>
# <li>
# <a class="icon-facebook" href="https://www.facebook.com/armslist" target="_blank" title="Armslist on Facebook"></a>
# </li>
# <li>
# <a class="icon-twitter" href="https://twitter.com/armslist" target="_blank" title="Armslist Twitter page"></a>
# </li>
# <li>
# <a class="icon-google-plus" href="https://plus.google.com/103978926144598391141/posts" target="_blank" title="Armslist on Google+"></a>
# </li>
# </ul>
# <div class="text-block">
# <p>Always comply with local, state, federal, and international law.
# ARMSLIST does not become involved in transactions between parties. Review our
# <a href="/info/privacy">privacy policy</a> and <a href="/info/terms">terms of use</a> for more
# information. Report Illegal Firearms Activity to 1-800-ATF-GUNS.  </p>
# </div>
# <span class="copy">
#                             Copyright © 2019 Armslist, LLC |
#
#                             | Version: 15.0.2
#                         </span>
# </div>
# </div>
# </div>
# <script id="LOTCC_3569" src="http://tags.crwdcntrl.net/c/3569/cc.js?ns=_cc3569" type="text/javascript"></script>
# <script language="javascript" type="text/javascript"> _cc3569.bcp(); </script>
# </footer>
# </div>
# <div class="loader-box">
# <img alt="loader" height="64" src="https://s3.amazonaws.com/mgm-content/static/r131903/gzip/shared/images/loader.gif" width="64"/>
# </div>
# <script>   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');    ga('create', 'UA-5138407-1', 'auto');   ga('send', 'pageview');  </script>
# </body>

# %% [markdown]
# **Get the `body` element and explore its components**

# %%
myBody = list(myHtml.children)[3]

# %%
myBody.find_all('p')
# Out:
# [<p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>,
#  <p>
#  <small>
#  For Sale/Trade                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>,
#  <p>
#  <small>
#  For Sale/Trade                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Watertown</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 2:57 PM</small></p>,
#  <p style="margin: 0px; padding: 0px;">
#  <small style="font-weight: bold;">Premium Vendor</small>
#  </p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Rochester</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 2:47 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Rochester</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 1:14 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Rochester</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 12:01 PM</small></p>,
#  <p>
#  <small>
#  For Sale                </small>
#  </p>,
#  <p><small><i class="fa fa-map-marker fa-2"></i> Rochester</small></p>,
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 12:00 PM</small></p>,
#  <p>Always comply with local, state, federal, and international law.
#  ARMSLIST does not become involved in transactions between parties. Review our
#  <a href="/info/privacy">privacy policy</a> and <a href="/info/terms">terms of use</a> for more
#  information. Report Illegal Firearms Activity to 1-800-ATF-GUNS.  </p>]

# %% [markdown]
# **Once you've identified the `col-md-7` as the tag that holds the elements we want to get we can use that to extract those elmements from our `soup` object.**

# %%
saleInfo = myBody.find_all(class_='col-md-7')

# %%
saleInfo
# Out:
# [<div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/9571384/long-island-new-york-optics-for-sale--vortex-viper">Vortex Viper</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 500
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/9789750/long-island-new-york-rifles-for-sale-trade--chiappa-1892-alaskan-take-down">Chiappa 1892 Alaskan Take Down</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 1,250
#                  </h4>
#  <p>
#  <small>
#  For Sale/Trade                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/9572179/long-island-new-york-gun-parts-for-sale--rossi-coach-gun-overland-parts">Rossi Coach Gun Overland Parts</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 300
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/9503782/long-island-new-york-shotguns-for-sale-trade--rossi-chrome-coach-gun-rare">Rossi Chrome Coach Gun Rare</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 700
#                  </h4>
#  <p>
#  <small>
#  For Sale/Trade                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/9504240/long-island-new-york-shotguns-for-sale--savage-24--22lr-over-20ga-">Savage 24  22lr Over 20ga.</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 700
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:17 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/9874160/long-island-new-york-shotguns-for-sale--remington-coach-gun-new-old-stock">Remington Coach Gun New Old Stock</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 700
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/10074126/long-island-new-york-rifles-for-sale--ruger-m77-hawkeye-tactical--308">Ruger m77 Hawkeye Tactical .308</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 1,500
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/10075280/long-island-new-york-shotguns-for-sale--rossi-overland-coach-gun-">Rossi Overland Coach Gun </a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 675
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/10078638/long-island-new-york-ammo-for-sale--remington--22-win-mag-case">Remington .22 Win Mag case</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 100
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/10078666/long-island-new-york-ammo-for-sale--winchester--410-pdx1-defender-ammo">Winchester .410 PDX1 Defender Ammo</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 100
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Long Island</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 4:16 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/10078487/watertown-handguns-for-sale--ruger-security-six--357">Ruger Security Six .357</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 450
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Watertown</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 2:57 PM</small></p>
#  </div>, <div class="col-md-7">
#  <p style="margin: 0px; padding: 0px;">
#  <small style="font-weight: bold;">Premium Vendor</small>
#  </p>
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/10110105/rochester-new-york-handguns-for-sale---glock-45-9mm-10rd-3-mags-frt-ser"> GLOCK 45 9MM 10RD 3 MAGS FRT SER</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 500
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Rochester</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 2:47 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/10059192/rochester-new-york-handguns-for-sale--taurus-605">Taurus 605</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 280
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Rochester</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 1:14 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/7876495/rochester-new-york-holsters-for-sale--ruger-lcpii-kydex-holster-and-ruger-mag">Ruger LCPII kydex holster and Ruger mag</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 40
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Rochester</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 12:01 PM</small></p>
#  </div>, <div class="col-md-7">
#  <h4 style="margin: 0px 0px 10px 0px; padding: 0px;"><a href="/posts/7959698/rochester-new-york-handguns-for-sale--taylor---co---uberti--smoke-wagon--357">Taylor &amp; Co. (Uberti) Smoke Wagon .357</a></h4>
#  <h4 style="color: #000000; font-weight: 400;">
#                      $ 600
#                  </h4>
#  <p>
#  <small>
#  For Sale                </small>
#  </p>
#  <p><small><i class="fa fa-map-marker fa-2"></i> Rochester</small></p>
#  <p style="font-size: 80%;"><small>Tuesday, 6/18 12:00 PM</small></p>
#  </div>]

# %% [markdown]
# **We can also select items based on multiple classes**

# %%
myBody.select('.col-md-7 h4 a')
# Out:
# [<a href="/posts/9571384/long-island-new-york-optics-for-sale--vortex-viper">Vortex Viper</a>,
#  <a href="/posts/9789750/long-island-new-york-rifles-for-sale-trade--chiappa-1892-alaskan-take-down">Chiappa 1892 Alaskan Take Down</a>,
#  <a href="/posts/9572179/long-island-new-york-gun-parts-for-sale--rossi-coach-gun-overland-parts">Rossi Coach Gun Overland Parts</a>,
#  <a href="/posts/9503782/long-island-new-york-shotguns-for-sale-trade--rossi-chrome-coach-gun-rare">Rossi Chrome Coach Gun Rare</a>,
#  <a href="/posts/9504240/long-island-new-york-shotguns-for-sale--savage-24--22lr-over-20ga-">Savage 24  22lr Over 20ga.</a>,
#  <a href="/posts/9874160/long-island-new-york-shotguns-for-sale--remington-coach-gun-new-old-stock">Remington Coach Gun New Old Stock</a>,
#  <a href="/posts/10074126/long-island-new-york-rifles-for-sale--ruger-m77-hawkeye-tactical--308">Ruger m77 Hawkeye Tactical .308</a>,
#  <a href="/posts/10075280/long-island-new-york-shotguns-for-sale--rossi-overland-coach-gun-">Rossi Overland Coach Gun </a>,
#  <a href="/posts/10078638/long-island-new-york-ammo-for-sale--remington--22-win-mag-case">Remington .22 Win Mag case</a>,
#  <a href="/posts/10078666/long-island-new-york-ammo-for-sale--winchester--410-pdx1-defender-ammo">Winchester .410 PDX1 Defender Ammo</a>,
#  <a href="/posts/10078487/watertown-handguns-for-sale--ruger-security-six--357">Ruger Security Six .357</a>,
#  <a href="/posts/10110105/rochester-new-york-handguns-for-sale---glock-45-9mm-10rd-3-mags-frt-ser"> GLOCK 45 9MM 10RD 3 MAGS FRT SER</a>,
#  <a href="/posts/10059192/rochester-new-york-handguns-for-sale--taurus-605">Taurus 605</a>,
#  <a href="/posts/7876495/rochester-new-york-holsters-for-sale--ruger-lcpii-kydex-holster-and-ruger-mag">Ruger LCPII kydex holster and Ruger mag</a>,
#  <a href="/posts/7959698/rochester-new-york-handguns-for-sale--taylor---co---uberti--smoke-wagon--357">Taylor &amp; Co. (Uberti) Smoke Wagon .357</a>]

# %%
for item in myBody.select('.col-md-7 h4 a'):
    print(item.get_text())
# Out:
# Vortex Viper
# Chiappa 1892 Alaskan Take Down
# Rossi Coach Gun Overland Parts
# Rossi Chrome Coach Gun Rare
# Savage 24  22lr Over 20ga.
# Remington Coach Gun New Old Stock
# Ruger m77 Hawkeye Tactical .308
# Rossi Overland Coach Gun
# Remington .22 Win Mag case
# Winchester .410 PDX1 Defender Ammo
# Ruger Security Six .357
#  GLOCK 45 9MM 10RD 3 MAGS FRT SER
# Taurus 605
# Ruger LCPII kydex holster and Ruger mag
# Taylor & Co. (Uberti) Smoke Wagon .357

# %% [markdown]
# **Use the `%` operand to do something every other time in a loop**

# %%
counter = 0
for item in myBody.select('.col-md-7 h4'):
    counter += 1
    if counter%2 == 0:
        print(item.get_text().strip())
# Out:
# $ 500
# $ 1,250
# $ 300
# $ 700
# $ 700
# $ 700
# $ 1,500
# $ 675
# $ 100
# $ 100
# $ 450
# $ 500
# $ 280
# $ 40
# $ 600

# %% [markdown]
# **Create an empty dataframe where to put the data you scrape and then run through the loop and add the data to this dataframe**

# %%
gunData = pd.DataFrame(columns=['description', 'price'])

# %%
counter = 0
description = ""
price = ""
for item in myBody.select('.col-md-7 h4'):
    counter += 1
    if counter%2 == 0:
        price = item.get_text().strip()
        print(description, price)
        myData = [description, price]
        gunData.loc[len(gunData)] = myData
    else:
        description = item.get_text()
# Out:
# Vortex Viper $ 500
# Chiappa 1892 Alaskan Take Down $ 1,250
# Rossi Coach Gun Overland Parts $ 300
# Rossi Chrome Coach Gun Rare $ 700
# Savage 24  22lr Over 20ga. $ 700
# Remington Coach Gun New Old Stock $ 700
# Ruger m77 Hawkeye Tactical .308 $ 1,500
# Rossi Overland Coach Gun  $ 675
# Remington .22 Win Mag case $ 100
# Winchester .410 PDX1 Defender Ammo $ 100
# Ruger Security Six .357 $ 450
#  GLOCK 45 9MM 10RD 3 MAGS FRT SER $ 500
# Taurus 605 $ 280
# Ruger LCPII kydex holster and Ruger mag $ 40
# Taylor & Co. (Uberti) Smoke Wagon .357 $ 600

# %%
gunData.head()
# Out:
#                       description    price
# 0                    Vortex Viper    $ 500
# 1  Chiappa 1892 Alaskan Take Down  $ 1,250
# 2  Rossi Coach Gun Overland Parts    $ 300
# 3     Rossi Chrome Coach Gun Rare    $ 700
# 4      Savage 24  22lr Over 20ga.    $ 700

# %% [markdown]
# If you are going to do this multiple times in a row, for example if you are going to query multiple pages, you need to put everything into a global loop (to loop through the pages) and add a timer so that the website doesn't return an error.
#
# Make sur to import the `time` library.

# %%
import time
baseURL = 'https://www.armslist.com/classifieds/search?location=new-york&category=all&page='
baseURL2 = '&posttype=7&ships=False'
del gunData
gunData = pd.DataFrame(columns=['description', 'price'])

for i in range(1,11):
    request = baseURL + str(i) + baseURL2
    response = get(request)
    soup = BeautifulSoup(response.content, 'html.parser')
    myHtml = list(soup.children)[3]
    myBody = list(myHtml.children)[3]
    counter = 0
    description = ""
    price = ""
    for item in myBody.select('.col-md-7 h4'):
        counter += 1
        if counter%2 == 0:
            price = item.get_text().strip()
            print(description, price)
            myData = [description, price]
            gunData.loc[len(gunData)] = myData
        else:
            description = item.get_text()
    time.sleep(2)
gunData.head()
# Out:
# Vortex Viper $ 500
# Chiappa 1892 Alaskan Take Down $ 1,250
# Rossi Coach Gun Overland Parts $ 300
# Rossi Chrome Coach Gun Rare $ 700
# Savage 24  22lr Over 20ga. $ 700
# Remington Coach Gun New Old Stock $ 700
# Ruger m77 Hawkeye Tactical .308 $ 1,500
# Rossi Overland Coach Gun  $ 675
# Remington .22 Win Mag case $ 100
# Winchester .410 PDX1 Defender Ammo $ 100
# Ruger Security Six .357 $ 450
#  GLOCK 45 9MM 10RD 3 MAGS FRT SER $ 500
# Taurus 605 $ 280
# Ruger LCPII kydex holster and Ruger mag $ 40
# Taylor & Co. (Uberti) Smoke Wagon .357 $ 600
# Ruger Mini 14 $ 750
# New Complete 5.56 M-lok Upper $ 260
# New .625 Pencil Barrel/Gas system $ 80
# Adjustable Gas Block $ 40
# Cold Hammer Forged Barrel $ 240
# Federal 5.56 XM193 55gr SALE  $ 149
# CZ P10 C Clearance! $ 425
# Shooting DVD's (Lot of 21 Titles) $ 25
# Liberty Gun Safe -  Sale/Trade REDUCED $ 750
# AmSec SF6030 Gun Safe $ 1,899
# Lasermax Glock G43 Guide Rod Laser $ 240
# Glock 42 .380acp Magazine w/ finger extension $ 33
# EAA Witness 9mm 10 Round Mag Part 101922 $ 29
# Double Alpha & Other Competition Gear $ 1
# Alien Gear Holster $ 25
# Glock 42 Cross Breed holster set $ 60
# Dillon Mr Bullet Feeder by Double Alpha $ 470
# NIB Ruger 10/22 Take Down NRA Edition $ 390
# NIB Ruger 10/22 Buck Reaper Camo Package $ 325
# Transfer services $ 25
# Wilson Combat Beretta 92G Brigadier Package $ 1,350
# NIB pink slide Glock 43 $ 450
# BFG Glock 19 Gen 4 $ 525
# Ruger LCP in Pontus Camo $ 225
# NIB Glock 42 with Cerakoted slide $ 430
# Palmetto State Armory ARs $ 60
# NIB Ruger LC9s Neptune camo $ 400
# NIB Glock 19x $ 588
# Winchester Large Rifle Primers 1,000 ct $ 40
# AR-15 (N.Y. Legal) $ 800
# Ruger Rifle 10/22 Take Down Stainless Kryptek Typhon  $ 350
# Ruger American Rifle $ 375
# Cobra Denali $ 150
# Cobra FS380BB $ 150
# Glock 42 $ 400
# Nagant M1895 revolver $ 600
# Zastava CZ-999 $ 375
# Heritage Arms Rough Rider $ 250
# Zastava M88A $ 300
# M & P shield 9mm $ 350
# Walther CCP OD Green $ 375
# Taurus Curve $ 350
# Heizer PAR1 pistol $ 350
# Ruger LCR $ 500
# Chiappa 1873-22 Black finish $ 200
# Mossberg Shockwave $ 400
# Maverick 88 pistol grip $ 325
# ATI Shotgun Perfect for home defense $ 250
# M&P Shiel 9mm $ 300
# NEW! Delton Echo 5.56 NYS Compliant $ 675
# NEW! Ruger PC Carbine $ 525
# Savage Model 6.5 Creedmor $ 875
# Del-ton A3 5.56 NYS Compliant $ 649
# NEW! Glock 19 Gen 5 w/10 rd $ 575
# NEW! CZP-10C 9mm 10 rds $ 490
# NEW! CZ-P-07 9mm 10 rd Black $ 489
# NEW Ruger EC9s 9mm $ 230
# R Guns A1 pistol $ 850
# Remington  870 Supermag 12ga  $ 580
# Savage Axis 22-250 Heavy Barrel NNIB Weaver Rail $ 325
# New In The Box 10mm Rock Island Armory M1911 A1. $ 450
# Taurus PT940 40 s&w one 10 round mag. USED $ 325
# Taurus M82 38 Special 4" with Bulldog Magnum Top Load Vault Factory New $ 375
# AR 15 Parts $ 50
# MagPul Black AFG2 $ 30
# Odin Works KMod 5 Slot Accessory Rail $ 22
# BCMGUNFIGHTER Vertical Grip Mod 3-KeyMod- Black $ 20
# Aero Precision AR15 Stripped Lower Receiver, Gen 2 - FDE Cerakote $ 95
# Chiappa 1911-22 SPORT‏  $ 250
# Firearm Transfers $ 30
# Taurus PT-140 $ 300
# NEW Ruger LCP II .380 $ 285
# MOSSBERG 590 SHOCKWAVE 12 GAUGE 14" BARREL "OTHER" SHOTGUN $ 399
# MAGPUL STOCK MOE SL-K AR15 CARBINE MIL-SPEC TUBE BLACK $ 39
# MAGPUL STOCK MOE SL-K AR15 CARBINE MIL-SPEC TUBE FDE $ 39
# B5 Systems Bravo Butt Stock-Black $ 58
# Glock 19 Gen 5-10rd $ 559
# BEAR FLAG DEFENSE EJECTION PORT DOOR SPEED LOADER FOR FIXED MAGAZINE RIFLES $ 40
# Mossberg 702 Plinkster $ 175
# Aero Precision Stripped AR-15 Lower $ 80
# VG6 Gamma Muzzle Brake AR-15 $ 75
# BCMGUNFIGHTER Ambidextrous Charging Handle $ 85
# MagPul Black AFG2 $ 30
# Daniel Defense Enhanced AR Pistol Grip-Black $ 28
# Glock 43 9mm NEW $ 465
# Henry US Survival Rifle 22LR New In Box $249.95 $ 250
# NEW YORK SAFE ACT LEGAL Bushmaster AR-15 5.56mm Rifle $ 1,095
# Stag Arms Stag-15 5.56mm Stripped Lower Receiver $ 130
# Smith & Wesson M&P-15 Sport 5.56mm NEW YORK SAFE ACT LEGAL AR-15 $ 879
# Spike's Tactical Stripped Lower Receiver With Punisher logo $ 130
# Ruger Mini-14 Blued/Wood 223 Caliber New In Box $ 769
# Windham Weaponry WW-15 5.56mm NY SAFE ACT LEGAL Featureless AR-15 Rifle $ 950
# Just Right Carbine 9mm NEW YORK SAFE ACT LEGAL Rifle $ 810
# DEL TON AR-15 Stripped Lower Receiver $ 120
# DPMS LR-308 308win Stripped Lower Receiver $ 295
# FS: Magpul MOE AR-15 Black Grip $ 20
# New: Streamlight Protac Rail Mount 1  $ 100
# ATI AR-15 Mil-Spec Buffer Assembly $ 55
# CMMG .308 Premium Lower Parts Kit $ 80
# Aero Precision AR15 Flip-Up Sight Set $ 135
# CMMG Charging Handle Assembly, AR15 $ 27
# B5 Systems Bravo Butt Stock-Black $ 58
# AR10 rifle Butt Stocks $ 160
# Smith and Wesson Bodyguard 380acp with Crimson Trace grip-activated Green Laser $ 495
# Armscore Precision International M1911 A1 45acp Used $ 525
# Taurus Judge Magnum .45LC/.410ga (3") 5-shot DA/SA Stainless NNIB $ 550
# Magpul PMAG AR-15 10 Round Magazine $ 15
# Just Right Carbine 40 S&W Caliber NEW YORK SAFE ACT LEGAL Rifle $ 829
# Just Right Carbine 45 Caliber NEW YORK SAFE ACT LEGAL Rifle $ 849
# Hornady 17HMR 17gr V-MAX Ammo (500 Rounds) $ 150
# Remington Golden Bullet 22LR 100 Pack Ammo $ 13
# Thordsen FRS-15 AR-15 Enhanced Stock Assembly $ 140
# DP-12 Double Barrel Pump Shotgun $ 1,395
# "BLACK GUNS MATTER" T-Shirt $ 15
# Tapco AR-15 10/30 AR-15 5.56mm/223 Rem Magazine $ 25
# Trijicon HD Glock 42/43  Night Sights New! $ 136
# Trijicon HD Glock 42/43 Night sights New! $ 136
# Troy Pump Action AR Sporting Rifle 223 Optics Ready (SPMP-AR0-OOBT-01)  $ 749
# MAGPUL $ 25
# Charter Arms undercover.38special $ 200
# Hornady 50 AE  300gr xtp  $ 30
# REMINGTON TAC 14 12 GAUGE 14" "OTHER" SHOTGUN $ 430
# Delton Optics Ready 5.56 NYS Compliant $ 499
# Federal Gold Medal Match CLEARANCE! $ 20
# Mega Arms 16" .308 Barrel $ 325
# Aero Precision M5 .308 Stripper Lower $ 185
# Glock 17 & 19 MOS Optics Ready $ 650
# STI Handguns in Stock  $ 1
# EAA Witness Stock II 9mm Tanfoglio $ 1,049
# Herstal FNS 9 $ 450
# Beretta 96a1 40sw $ 875
# Puma/Chiappa 1873 ssa 22lr/22wmr $ 229
# Taurus PT 1911 S/S 45acp w/rail $ 629
# SCCY CPX-1 pink 9mm $ 259
# Ruger Lc9/s Pro $ 479
#                       description    price
# 0                    Vortex Viper    $ 500
# 1  Chiappa 1892 Alaskan Take Down  $ 1,250
# 2  Rossi Coach Gun Overland Parts    $ 300
# 3     Rossi Chrome Coach Gun Rare    $ 700
# 4      Savage 24  22lr Over 20ga.    $ 700

# %%
gunData.head(50)
# Out:
#                                           description    price
# 0                                        Vortex Viper    $ 500
# 1                      Chiappa 1892 Alaskan Take Down  $ 1,250
# 2                      Rossi Coach Gun Overland Parts    $ 300
# 3                         Rossi Chrome Coach Gun Rare    $ 700
# 4                          Savage 24  22lr Over 20ga.    $ 700
# 5                   Remington Coach Gun New Old Stock    $ 700
# 6                     Ruger m77 Hawkeye Tactical .308  $ 1,500
# 7                           Rossi Overland Coach Gun     $ 675
# 8                          Remington .22 Win Mag case    $ 100
# 9                  Winchester .410 PDX1 Defender Ammo    $ 100
# 10                            Ruger Security Six .357    $ 450
# 11                   GLOCK 45 9MM 10RD 3 MAGS FRT SER    $ 500
# 12                                         Taurus 605    $ 280
# 13            Ruger LCPII kydex holster and Ruger mag     $ 40
# 14             Taylor & Co. (Uberti) Smoke Wagon .357    $ 600
# 15                                      Ruger Mini 14    $ 750
# 16                      New Complete 5.56 M-lok Upper    $ 260
# 17                  New .625 Pencil Barrel/Gas system     $ 80
# 18                               Adjustable Gas Block     $ 40
# 19                          Cold Hammer Forged Barrel    $ 240
# 20                      Federal 5.56 XM193 55gr SALE     $ 149
# 21                                CZ P10 C Clearance!    $ 425
# 22                  Shooting DVD's (Lot of 21 Titles)     $ 25
# 23             Liberty Gun Safe -  Sale/Trade REDUCED    $ 750
# 24                              AmSec SF6030 Gun Safe  $ 1,899
# 25                 Lasermax Glock G43 Guide Rod Laser    $ 240
# 26      Glock 42 .380acp Magazine w/ finger extension     $ 33
# 27           EAA Witness 9mm 10 Round Mag Part 101922     $ 29
# 28              Double Alpha & Other Competition Gear      $ 1
# 29                                 Alien Gear Holster     $ 25
# 30                   Glock 42 Cross Breed holster set     $ 60
# 31            Dillon Mr Bullet Feeder by Double Alpha    $ 470
# 32              NIB Ruger 10/22 Take Down NRA Edition    $ 390
# 33           NIB Ruger 10/22 Buck Reaper Camo Package    $ 325
# 34                                  Transfer services     $ 25
# 35        Wilson Combat Beretta 92G Brigadier Package  $ 1,350
# 36                            NIB pink slide Glock 43    $ 450
# 37                                 BFG Glock 19 Gen 4    $ 525
# 38                           Ruger LCP in Pontus Camo    $ 225
# 39                  NIB Glock 42 with Cerakoted slide    $ 430
# 40                          Palmetto State Armory ARs     $ 60
# 41                        NIB Ruger LC9s Neptune camo    $ 400
# 42                                      NIB Glock 19x    $ 588
# 43            Winchester Large Rifle Primers 1,000 ct     $ 40
# 44                                 AR-15 (N.Y. Legal)    $ 800
# 45  Ruger Rifle 10/22 Take Down Stainless Kryptek ...    $ 350
# 46                               Ruger American Rifle    $ 375
# 47                                       Cobra Denali    $ 150
# 48                                      Cobra FS380BB    $ 150
# 49                                           Glock 42    $ 400
