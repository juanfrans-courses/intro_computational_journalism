# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import geopandas as gpd
from shapely.geometry import Point

# %%
NewYorkStateCensusTracts = gpd.read_file('../input/tl_2017_36_tract.shp')

# %%
NewYorkStateCensusTracts.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID    NAME             NAMELSAD  MTFCC  \
# 0      36      093  033102  36093033102  331.02  Census Tract 331.02  G5020
# 1      36      093  020102  36093020102  201.02  Census Tract 201.02  G5020
# 2      36      093  032504  36093032504  325.04  Census Tract 325.04  G5020
# 3      36      081  003400  36081003400      34      Census Tract 34  G5020
# 4      36      081  003900  36081003900      39      Census Tract 39  G5020
#
#   FUNCSTAT      ALAND   AWATER     INTPTLAT      INTPTLON  \
# 0        S  183329957  3232878  +42.7780137  -074.1727137
# 1        S     854904        0  +42.8295375  -073.9161408
# 2        S   65998560  1265253  +42.9010539  -074.0288936
# 3        S     213987        0  +40.6847731  -073.8581871
# 4        S     146970        0  +40.7627994  -073.9409316
#
#                                             geometry
# 0  POLYGON ((-74.30655 42.750642, -74.30624499999...
# 1  POLYGON ((-73.92513099999999 42.82029, -73.924...
# 2  POLYGON ((-74.09298 42.955868, -74.08805199999...
# 3  POLYGON ((-73.86629499999999 40.683189, -73.86...
# 4  POLYGON ((-73.943304 40.760658, -73.942472 40....

# %%
nycCTs = NewYorkStateCensusTracts[(NewYorkStateCensusTracts['COUNTYFP'] == '061') | (NewYorkStateCensusTracts['COUNTYFP'] == '081') | (NewYorkStateCensusTracts['COUNTYFP'] == '085') | (NewYorkStateCensusTracts['COUNTYFP'] == '047') | (NewYorkStateCensusTracts['COUNTYFP'] == '005')]
# (NewYorkStateCensusTracts['COUNTYFP'] == '081')
# (NewYorkStateCensusTracts['COUNTYFP'] == '085')
# (NewYorkStateCensusTracts['COUNTYFP'] == '047')
# (NewYorkStateCensusTracts['COUNTYFP'] == '005')

# %%
len(nycCTs)
# Out:
# 2167

# %%
plt.rcParams["figure.figsize"] = [10, 10]
nycCTs.plot()

# %%
nycCTs.crs
# Out:
# {'init': 'epsg:4269'}

# %%
nycCTs['geometry'] = nycCTs['geometry'].to_crs({'init': 'epsg:2263'})
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
nycCTs.plot()

# %%
censusData = pd.read_csv('../input/ACS_17_5YR_B19013.csv', delimiter=',', header=0)

# %%
censusData.head()
# Out:
#                  GEO.id      GEO.id2                        GEO.display-label  \
# 0  1400000US36005000100  36005000100   Census Tract 1, Bronx County, New York
# 1  1400000US36005000200  36005000200   Census Tract 2, Bronx County, New York
# 2  1400000US36005000400  36005000400   Census Tract 4, Bronx County, New York
# 3  1400000US36005001600  36005001600  Census Tract 16, Bronx County, New York
# 4  1400000US36005001900  36005001900  Census Tract 19, Bronx County, New York
#
#    HD01_VD01  HD02_VD01
# 0        NaN        NaN
# 1    62773.0    11556.0
# 2    82697.0     8000.0
# 3    33118.0     3520.0
# 4    40117.0     4612.0

# %%
censusData.dtypes
# Out:
# GEO.id                object
# GEO.id2                int64
# GEO.display-label     object
# HD01_VD01            float64
# HD02_VD01            float64
# dtype: object

# %%
nycCTs.dtypes
# Out:
# STATEFP     object
# COUNTYFP    object
# TRACTCE     object
# GEOID       object
# NAME        object
# NAMELSAD    object
# MTFCC       object
# FUNCSTAT    object
# ALAND        int64
# AWATER       int64
# INTPTLAT    object
# INTPTLON    object
# geometry    object
# dtype: object

# %%
censusData['GEOID'] = censusData['GEO.id2'].astype('str')

# %%
censusData.head()
# Out:
#                  GEO.id      GEO.id2                        GEO.display-label  \
# 0  1400000US36005000100  36005000100   Census Tract 1, Bronx County, New York
# 1  1400000US36005000200  36005000200   Census Tract 2, Bronx County, New York
# 2  1400000US36005000400  36005000400   Census Tract 4, Bronx County, New York
# 3  1400000US36005001600  36005001600  Census Tract 16, Bronx County, New York
# 4  1400000US36005001900  36005001900  Census Tract 19, Bronx County, New York
#
#    HD01_VD01  HD02_VD01        GEOID
# 0        NaN        NaN  36005000100
# 1    62773.0    11556.0  36005000200
# 2    82697.0     8000.0  36005000400
# 3    33118.0     3520.0  36005001600
# 4    40117.0     4612.0  36005001900

# %%
nycCTs = nycCTs.merge(censusData, how='left', left_on="theSelectedLeftColumn", right_on="theSelectedRightColumn")

# %% [markdown]
# [Diagram explaining different types of joins](https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/)
#
# [Pandas merge documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)

# %%
nycCTs.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID NAME         NAMELSAD  MTFCC FUNCSTAT  \
# 0      36      081  003400  36081003400   34  Census Tract 34  G5020        S
# 1      36      081  003900  36081003900   39  Census Tract 39  G5020        S
# 2      36      081  003600  36081003600   36  Census Tract 36  G5020        S
# 3      36      081  003700  36081003700   37  Census Tract 37  G5020        S
# 4      36      081  003800  36081003800   38  Census Tract 38  G5020        S
#
#     ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0  213987       0  +40.6847731  -073.8581871
# 1  146970       0  +40.7627994  -073.9409316
# 2  180006       0  +40.6837714  -073.8568176
# 3  386629   14591  +40.7624148  -073.9434494
# 4  176214       0  +40.6847999  -073.8474941
#
#                                             geometry                GEO.id  \
# 0  POLYGON ((1021333.167256766 188208.899368856, ...  1400000US36081003400
# 1  POLYGON ((999956.409081795 216410.0252367854, ...  1400000US36081003900
# 2  POLYGON ((1021942.135297121 187912.5437251023,...  1400000US36081003600
# 3  POLYGON ((997890.3169969553 214461.4176978127,...  1400000US36081003700
# 4  POLYGON ((1025075.082022337 188602.5456460564,...  1400000US36081003800
#
#        GEO.id2                         GEO.display-label  HD01_VD01  HD02_VD01
# 0  36081003400  Census Tract 34, Queens County, New York    71000.0    20471.0
# 1  36081003900  Census Tract 39, Queens County, New York    43194.0     8336.0
# 2  36081003600  Census Tract 36, Queens County, New York    79549.0    11590.0
# 3  36081003700  Census Tract 37, Queens County, New York        NaN        NaN
# 4  36081003800  Census Tract 38, Queens County, New York    73281.0    26350.0

# %%
nycClean = nycCTs[nycCTs['HD01_VD01'] > 0]

# %%
nycClean['MHHI'] = nycClean['HD01_VD01'].astype('int')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
nycClean.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID   NAME            NAMELSAD  MTFCC  \
# 0      36      081  003400  36081003400     34     Census Tract 34  G5020
# 1      36      081  003900  36081003900     39     Census Tract 39  G5020
# 2      36      081  003600  36081003600     36     Census Tract 36  G5020
# 4      36      081  003800  36081003800     38     Census Tract 38  G5020
# 5      36      081  004001  36081004001  40.01  Census Tract 40.01  G5020
#
#   FUNCSTAT   ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  213987       0  +40.6847731  -073.8581871
# 1        S  146970       0  +40.7627994  -073.9409316
# 2        S  180006       0  +40.6837714  -073.8568176
# 4        S  176214       0  +40.6847999  -073.8474941
# 5        S  174292       0  +40.6832481  -073.8458743
#
#                                             geometry                GEO.id  \
# 0  POLYGON ((1021333.167256766 188208.899368856, ...  1400000US36081003400
# 1  POLYGON ((999956.409081795 216410.0252367854, ...  1400000US36081003900
# 2  POLYGON ((1021942.135297121 187912.5437251023,...  1400000US36081003600
# 4  POLYGON ((1025075.082022337 188602.5456460564,...  1400000US36081003800
# 5  POLYGON ((1025539.698498706 188077.2390209684,...  1400000US36081004001
#
#        GEO.id2                            GEO.display-label  HD01_VD01  \
# 0  36081003400     Census Tract 34, Queens County, New York    71000.0
# 1  36081003900     Census Tract 39, Queens County, New York    43194.0
# 2  36081003600     Census Tract 36, Queens County, New York    79549.0
# 4  36081003800     Census Tract 38, Queens County, New York    73281.0
# 5  36081004001  Census Tract 40.01, Queens County, New York    72250.0
#
#    HD02_VD01   MHHI
# 0    20471.0  71000
# 1     8336.0  43194
# 2    11590.0  79549
# 4    26350.0  73281
# 5    21270.0  72250

# %%
nycClean.plot(column='MHHI', cmap='cool', linewidth=0.1, edgecolor='0.5')
plt.show()

# %% [markdown]
# [Matplotlib color ramps](https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html)

# %%
taxiSample = pd.read_csv('../input/TaxiSample_2013_10.csv', delimiter=',')

# %%
del taxiSampe

# %%
taxiSample.head()
# Out:
#    Unnamed: 0 vendor_id      pickup_datetime     dropoff_datetime  \
# 0     6463382       VTS  2013-10-01 07:10:00  2013-10-01 07:23:00
# 1     3959086       CMT  2013-10-22 12:39:33  2013-10-22 12:53:47
# 2     4318338       CMT  2013-10-25 13:55:45  2013-10-25 13:59:04
# 3    13891146       CMT  2013-10-02 18:41:38  2013-10-02 18:45:18
# 4     4464588       CMT  2013-10-24 14:40:05  2013-10-24 14:46:13
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1           2.81        -73.986260        40.734592
# 1                1           1.00        -73.981446        40.765865
# 2                2           0.00        -73.947737        40.772811
# 3                1           1.00        -73.949122        40.781575
# 4                1           0.70        -73.972321        40.765193
#
#    rate_code store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0          1                NaN         -74.013570         40.714595
# 1          1                  N         -73.982812         40.753442
# 2          1                  N         -73.947136         40.772706
# 3          1                  N         -73.955284         40.769184
# 4          1                  N         -73.981999         40.770587
#
#   payment_type  fare_amount  surcharge  mta_tax  tip_amount  tolls_amount  \
# 0          CRD         13.0        0.0      0.5         2.6           0.0
# 1          CSH          9.5        0.0      0.5         0.0           0.0
# 2          CSH          3.5        0.0      0.5         0.0           0.0
# 3          CRD          5.0        1.0      0.5         2.5           0.0
# 4          CSH          5.5        0.0      0.5         0.0           0.0
#
#    total_amount
# 0          16.1
# 1          10.0
# 2           4.0
# 3           9.0
# 4           6.0

# %%
geometry = [Point(xy) for xy in zip(taxiSample.dropoff_longitude, taxiSample.dropoff_latitude)]

# %%
geometry
# Out:
# [<shapely.geometry.point.Point at 0x12659f4e0>,
#  <shapely.geometry.point.Point at 0x12659f198>,
#  <shapely.geometry.point.Point at 0x12659f358>,
#  <shapely.geometry.point.Point at 0x12659feb8>,
#  <shapely.geometry.point.Point at 0x12659fb00>,
#  <shapely.geometry.point.Point at 0x12659fac8>,
#  <shapely.geometry.point.Point at 0x12659fa58>,
#  <shapely.geometry.point.Point at 0x12659f6d8>,
#  <shapely.geometry.point.Point at 0x12659fda0>,
#  <shapely.geometry.point.Point at 0x12659f470>,
#  <shapely.geometry.point.Point at 0x12659f978>,
#  <shapely.geometry.point.Point at 0x12659f8d0>,
#  <shapely.geometry.point.Point at 0x12659fba8>,
#  <shapely.geometry.point.Point at 0x12659f940>,
#  <shapely.geometry.point.Point at 0x12659f5f8>,
#  <shapely.geometry.point.Point at 0x12659f9b0>,
#  <shapely.geometry.point.Point at 0x12659fa90>,
#  <shapely.geometry.point.Point at 0x12659fc50>,
#  <shapely.geometry.point.Point at 0x121962ef0>,
#  <shapely.geometry.point.Point at 0x12659fef0>,
#  <shapely.geometry.point.Point at 0x12659ff60>,
#  <shapely.geometry.point.Point at 0x12659fd68>,
#  <shapely.geometry.point.Point at 0x12659fc18>,
#  <shapely.geometry.point.Point at 0x12659ff28>,
#  <shapely.geometry.point.Point at 0x12659fcf8>,
#  <shapely.geometry.point.Point at 0x12659f828>,
#  <shapely.geometry.point.Point at 0x12659f4a8>,
#  <shapely.geometry.point.Point at 0x12659f2b0>,
#  <shapely.geometry.point.Point at 0x12659fd30>,
#  <shapely.geometry.point.Point at 0x12659ffd0>,
#  <shapely.geometry.point.Point at 0x12659fcc0>,
#  <shapely.geometry.point.Point at 0x12659ff98>,
#  <shapely.geometry.point.Point at 0x12659fbe0>,
#  <shapely.geometry.point.Point at 0x12659fa20>,
#  <shapely.geometry.point.Point at 0x12659f160>,
#  <shapely.geometry.point.Point at 0x12659f208>,
#  <shapely.geometry.point.Point at 0x12659ad30>,
#  <shapely.geometry.point.Point at 0x12659ac88>,
#  <shapely.geometry.point.Point at 0x12659a6d8>,
#  <shapely.geometry.point.Point at 0x12659a8d0>,
#  <shapely.geometry.point.Point at 0x12659ac50>,
#  <shapely.geometry.point.Point at 0x12659ab70>,
#  <shapely.geometry.point.Point at 0x12659aa58>,
#  <shapely.geometry.point.Point at 0x12659ae48>,
#  <shapely.geometry.point.Point at 0x12659a710>,
#  <shapely.geometry.point.Point at 0x12659a940>,
#  <shapely.geometry.point.Point at 0x12659a978>,
#  <shapely.geometry.point.Point at 0x12659add8>,
#  <shapely.geometry.point.Point at 0x12659ac18>,
#  <shapely.geometry.point.Point at 0x12659afd0>,
#  <shapely.geometry.point.Point at 0x12659ae80>,
#  <shapely.geometry.point.Point at 0x12659ad68>,
#  <shapely.geometry.point.Point at 0x12659af98>,
#  <shapely.geometry.point.Point at 0x12659af60>,
#  <shapely.geometry.point.Point at 0x12659aef0>,
#  <shapely.geometry.point.Point at 0x12659a5f8>,
#  <shapely.geometry.point.Point at 0x12659abe0>,
#  <shapely.geometry.point.Point at 0x12659a358>,
#  <shapely.geometry.point.Point at 0x12659ab38>,
#  <shapely.geometry.point.Point at 0x12659ab00>,
#  <shapely.geometry.point.Point at 0x12659a748>,
#  <shapely.geometry.point.Point at 0x12659ada0>,
#  <shapely.geometry.point.Point at 0x12659acc0>,
#  <shapely.geometry.point.Point at 0x12659a908>,
#  <shapely.geometry.point.Point at 0x12659aac8>,
#  <shapely.geometry.point.Point at 0x12659a7b8>,
#  <shapely.geometry.point.Point at 0x12659a668>,
#  <shapely.geometry.point.Point at 0x12659a470>,
#  <shapely.geometry.point.Point at 0x12659acf8>,
#  <shapely.geometry.point.Point at 0x12659a6a0>,
#  <shapely.geometry.point.Point at 0x12659aeb8>,
#  <shapely.geometry.point.Point at 0x12659a7f0>,
#  <shapely.geometry.point.Point at 0x12659a898>,
#  <shapely.geometry.point.Point at 0x12659a400>,
#  <shapely.geometry.point.Point at 0x12659aa90>,
#  <shapely.geometry.point.Point at 0x12659a630>,
#  <shapely.geometry.point.Point at 0x12659aa20>,
#  <shapely.geometry.point.Point at 0x12659a438>,
#  <shapely.geometry.point.Point at 0x12659a780>,
#  <shapely.geometry.point.Point at 0x12659a4a8>,
#  <shapely.geometry.point.Point at 0x12659a320>,
#  <shapely.geometry.point.Point at 0x12659a9b0>,
#  <shapely.geometry.point.Point at 0x12659f0f0>,
#  <shapely.geometry.point.Point at 0x12659a9e8>,
#  <shapely.geometry.point.Point at 0x12659a550>,
#  <shapely.geometry.point.Point at 0x1217315f8>,
#  <shapely.geometry.point.Point at 0x121832780>,
#  <shapely.geometry.point.Point at 0x12179a080>,
#  <shapely.geometry.point.Point at 0x1217a53c8>,
#  <shapely.geometry.point.Point at 0x1218b6898>,
#  <shapely.geometry.point.Point at 0x121a08860>,
#  <shapely.geometry.point.Point at 0x1216400f0>,
#  <shapely.geometry.point.Point at 0x1217b5390>,
#  <shapely.geometry.point.Point at 0x12192bcc0>,
#  <shapely.geometry.point.Point at 0x1216ab518>,
#  <shapely.geometry.point.Point at 0x12157a5c0>,
#  <shapely.geometry.point.Point at 0x1218113c8>,
#  <shapely.geometry.point.Point at 0x1218ac4e0>,
#  <shapely.geometry.point.Point at 0x1218ac128>,
#  <shapely.geometry.point.Point at 0x1218acef0>,
#  <shapely.geometry.point.Point at 0x1218ac6d8>,
#  <shapely.geometry.point.Point at 0x1218ac2b0>,
#  <shapely.geometry.point.Point at 0x1218acd68>,
#  <shapely.geometry.point.Point at 0x1218acf60>,
#  <shapely.geometry.point.Point at 0x1218ac5f8>,
#  <shapely.geometry.point.Point at 0x1218ac860>,
#  <shapely.geometry.point.Point at 0x1218ac3c8>,
#  <shapely.geometry.point.Point at 0x1218acb38>,
#  <shapely.geometry.point.Point at 0x1218acb00>,
#  <shapely.geometry.point.Point at 0x1218ac978>,
#  <shapely.geometry.point.Point at 0x1218ace10>,
#  <shapely.geometry.point.Point at 0x1213df390>,
#  <shapely.geometry.point.Point at 0x1217c21d0>,
#  <shapely.geometry.point.Point at 0x12172dd30>,
#  <shapely.geometry.point.Point at 0x1214b5908>,
#  <shapely.geometry.point.Point at 0x121509dd8>,
#  <shapely.geometry.point.Point at 0x121509748>,
#  <shapely.geometry.point.Point at 0x1216a2ac8>,
#  <shapely.geometry.point.Point at 0x121988c88>,
#  <shapely.geometry.point.Point at 0x1217cbcf8>,
#  <shapely.geometry.point.Point at 0x1214c8898>,
#  <shapely.geometry.point.Point at 0x121821da0>,
#  <shapely.geometry.point.Point at 0x1214e1f60>,
#  <shapely.geometry.point.Point at 0x12169b390>,
#  <shapely.geometry.point.Point at 0x1218b0b38>,
#  <shapely.geometry.point.Point at 0x1218b0c50>,
#  <shapely.geometry.point.Point at 0x1218b07f0>,
#  <shapely.geometry.point.Point at 0x1218b0d30>,
#  <shapely.geometry.point.Point at 0x1218b02b0>,
#  <shapely.geometry.point.Point at 0x1218b0f98>,
#  <shapely.geometry.point.Point at 0x1218b0860>,
#  <shapely.geometry.point.Point at 0x1218b00f0>,
#  <shapely.geometry.point.Point at 0x1218b0cf8>,
#  <shapely.geometry.point.Point at 0x1218b06d8>,
#  <shapely.geometry.point.Point at 0x1218b0518>,
#  <shapely.geometry.point.Point at 0x1218b08d0>,
#  <shapely.geometry.point.Point at 0x1218b0c18>,
#  <shapely.geometry.point.Point at 0x121826d30>,
#  <shapely.geometry.point.Point at 0x1218bd358>,
#  <shapely.geometry.point.Point at 0x121773cf8>,
#  <shapely.geometry.point.Point at 0x1214de9e8>,
#  <shapely.geometry.point.Point at 0x1216c9668>,
#  <shapely.geometry.point.Point at 0x121950a90>,
#  <shapely.geometry.point.Point at 0x1219500f0>,
#  <shapely.geometry.point.Point at 0x1219507b8>,
#  <shapely.geometry.point.Point at 0x121950438>,
#  <shapely.geometry.point.Point at 0x1219506d8>,
#  <shapely.geometry.point.Point at 0x1219508d0>,
#  <shapely.geometry.point.Point at 0x121950828>,
#  <shapely.geometry.point.Point at 0x121950358>,
#  <shapely.geometry.point.Point at 0x12156d6a0>,
#  <shapely.geometry.point.Point at 0x1218e6a58>,
#  <shapely.geometry.point.Point at 0x12659c860>,
#  <shapely.geometry.point.Point at 0x12659cba8>,
#  <shapely.geometry.point.Point at 0x12659c908>,
#  <shapely.geometry.point.Point at 0x12659cd68>,
#  <shapely.geometry.point.Point at 0x12659cda0>,
#  <shapely.geometry.point.Point at 0x12659c160>,
#  <shapely.geometry.point.Point at 0x12659c9e8>,
#  <shapely.geometry.point.Point at 0x12659c278>,
#  <shapely.geometry.point.Point at 0x12659c208>,
#  <shapely.geometry.point.Point at 0x12659ccc0>,
#  <shapely.geometry.point.Point at 0x12659cdd8>,
#  <shapely.geometry.point.Point at 0x12659c7f0>,
#  <shapely.geometry.point.Point at 0x12659cac8>,
#  <shapely.geometry.point.Point at 0x12659c0f0>,
#  <shapely.geometry.point.Point at 0x12659c0b8>,
#  <shapely.geometry.point.Point at 0x12659c358>,
#  <shapely.geometry.point.Point at 0x12659c240>,
#  <shapely.geometry.point.Point at 0x12659c9b0>,
#  <shapely.geometry.point.Point at 0x12659c400>,
#  <shapely.geometry.point.Point at 0x12659c198>,
#  <shapely.geometry.point.Point at 0x12659c1d0>,
#  <shapely.geometry.point.Point at 0x12659c2b0>,
#  <shapely.geometry.point.Point at 0x12659c470>,
#  <shapely.geometry.point.Point at 0x12659c320>,
#  <shapely.geometry.point.Point at 0x12659c2e8>,
#  <shapely.geometry.point.Point at 0x12659c080>,
#  <shapely.geometry.point.Point at 0x12659c4e0>,
#  <shapely.geometry.point.Point at 0x12659c048>,
#  <shapely.geometry.point.Point at 0x12659c518>,
#  <shapely.geometry.point.Point at 0x12659c588>,
#  <shapely.geometry.point.Point at 0x12659c5f8>,
#  <shapely.geometry.point.Point at 0x12659c748>,
#  <shapely.geometry.point.Point at 0x12659c5c0>,
#  <shapely.geometry.point.Point at 0x12659c668>,
#  <shapely.geometry.point.Point at 0x12659c550>,
#  <shapely.geometry.point.Point at 0x1214dc4a8>,
#  <shapely.geometry.point.Point at 0x1213a0400>,
#  <shapely.geometry.point.Point at 0x121709cc0>,
#  <shapely.geometry.point.Point at 0x121709828>,
#  <shapely.geometry.point.Point at 0x129857dd8>,
#  <shapely.geometry.point.Point at 0x129857b70>,
#  <shapely.geometry.point.Point at 0x129857c88>,
#  <shapely.geometry.point.Point at 0x129857ac8>,
#  <shapely.geometry.point.Point at 0x129857a90>,
#  <shapely.geometry.point.Point at 0x129857a58>,
#  <shapely.geometry.point.Point at 0x129857a20>,
#  <shapely.geometry.point.Point at 0x1298579e8>,
#  <shapely.geometry.point.Point at 0x1298579b0>,
#  <shapely.geometry.point.Point at 0x129857978>,
#  <shapely.geometry.point.Point at 0x129857940>,
#  <shapely.geometry.point.Point at 0x129857908>,
#  <shapely.geometry.point.Point at 0x1298578d0>,
#  <shapely.geometry.point.Point at 0x129857898>,
#  <shapely.geometry.point.Point at 0x129857860>,
#  <shapely.geometry.point.Point at 0x129857828>,
#  <shapely.geometry.point.Point at 0x1298577f0>,
#  <shapely.geometry.point.Point at 0x1298577b8>,
#  <shapely.geometry.point.Point at 0x129857780>,
#  <shapely.geometry.point.Point at 0x129857748>,
#  <shapely.geometry.point.Point at 0x129857710>,
#  <shapely.geometry.point.Point at 0x1298576d8>,
#  <shapely.geometry.point.Point at 0x1298576a0>,
#  <shapely.geometry.point.Point at 0x129857668>,
#  <shapely.geometry.point.Point at 0x129857630>,
#  <shapely.geometry.point.Point at 0x1298575f8>,
#  <shapely.geometry.point.Point at 0x1298575c0>,
#  <shapely.geometry.point.Point at 0x129857588>,
#  <shapely.geometry.point.Point at 0x129857550>,
#  <shapely.geometry.point.Point at 0x129857518>,
#  <shapely.geometry.point.Point at 0x1298574e0>,
#  <shapely.geometry.point.Point at 0x1298574a8>,
#  <shapely.geometry.point.Point at 0x129857470>,
#  <shapely.geometry.point.Point at 0x129857438>,
#  <shapely.geometry.point.Point at 0x129857400>,
#  <shapely.geometry.point.Point at 0x1298573c8>,
#  <shapely.geometry.point.Point at 0x129857390>,
#  <shapely.geometry.point.Point at 0x129857358>,
#  <shapely.geometry.point.Point at 0x129857320>,
#  <shapely.geometry.point.Point at 0x1298572e8>,
#  <shapely.geometry.point.Point at 0x1298572b0>,
#  <shapely.geometry.point.Point at 0x129857278>,
#  <shapely.geometry.point.Point at 0x129857240>,
#  <shapely.geometry.point.Point at 0x129857208>,
#  <shapely.geometry.point.Point at 0x1298571d0>,
#  <shapely.geometry.point.Point at 0x129857198>,
#  <shapely.geometry.point.Point at 0x129857160>,
#  <shapely.geometry.point.Point at 0x129857128>,
#  <shapely.geometry.point.Point at 0x1298570f0>,
#  <shapely.geometry.point.Point at 0x1298570b8>,
#  <shapely.geometry.point.Point at 0x129857080>,
#  <shapely.geometry.point.Point at 0x129857048>,
#  <shapely.geometry.point.Point at 0x129857c50>,
#  <shapely.geometry.point.Point at 0x12991bc18>,
#  <shapely.geometry.point.Point at 0x12991be80>,
#  <shapely.geometry.point.Point at 0x12991bd68>,
#  <shapely.geometry.point.Point at 0x12991bdd8>,
#  <shapely.geometry.point.Point at 0x12991bf60>,
#  <shapely.geometry.point.Point at 0x12991bda0>,
#  <shapely.geometry.point.Point at 0x12991be48>,
#  <shapely.geometry.point.Point at 0x12991bf98>,
#  <shapely.geometry.point.Point at 0x12991bc50>,
#  <shapely.geometry.point.Point at 0x12991bb38>,
#  <shapely.geometry.point.Point at 0x12991b780>,
#  <shapely.geometry.point.Point at 0x1217b39b0>,
#  <shapely.geometry.point.Point at 0x1217b34e0>,
#  <shapely.geometry.point.Point at 0x121889d68>,
#  <shapely.geometry.point.Point at 0x1216e9630>,
#  <shapely.geometry.point.Point at 0x129921c88>,
#  <shapely.geometry.point.Point at 0x129921e48>,
#  <shapely.geometry.point.Point at 0x129921cf8>,
#  <shapely.geometry.point.Point at 0x129921048>,
#  <shapely.geometry.point.Point at 0x129921b38>,
#  <shapely.geometry.point.Point at 0x129921f60>,
#  <shapely.geometry.point.Point at 0x129921550>,
#  <shapely.geometry.point.Point at 0x129921160>,
#  <shapely.geometry.point.Point at 0x129921400>,
#  <shapely.geometry.point.Point at 0x129921eb8>,
#  <shapely.geometry.point.Point at 0x129921668>,
#  <shapely.geometry.point.Point at 0x129921390>,
#  <shapely.geometry.point.Point at 0x129921128>,
#  <shapely.geometry.point.Point at 0x129921f28>,
#  <shapely.geometry.point.Point at 0x129921630>,
#  <shapely.geometry.point.Point at 0x129921588>,
#  <shapely.geometry.point.Point at 0x129921cc0>,
#  <shapely.geometry.point.Point at 0x129921e80>,
#  <shapely.geometry.point.Point at 0x129921b00>,
#  <shapely.geometry.point.Point at 0x129921da0>,
#  <shapely.geometry.point.Point at 0x129921c50>,
#  <shapely.geometry.point.Point at 0x129921a90>,
#  <shapely.geometry.point.Point at 0x129921c18>,
#  <shapely.geometry.point.Point at 0x1217832e8>,
#  <shapely.geometry.point.Point at 0x12173de80>,
#  <shapely.geometry.point.Point at 0x1219dda58>,
#  <shapely.geometry.point.Point at 0x12985b3c8>,
#  <shapely.geometry.point.Point at 0x12985b390>,
#  <shapely.geometry.point.Point at 0x1219961d0>,
#  <shapely.geometry.point.Point at 0x1214f0080>,
#  <shapely.geometry.point.Point at 0x129908160>,
#  <shapely.geometry.point.Point at 0x12991e390>,
#  <shapely.geometry.point.Point at 0x12991e278>,
#  <shapely.geometry.point.Point at 0x12991e240>,
#  <shapely.geometry.point.Point at 0x12991e470>,
#  <shapely.geometry.point.Point at 0x12991e550>,
#  <shapely.geometry.point.Point at 0x12991e400>,
#  <shapely.geometry.point.Point at 0x12659f9e8>,
#  <shapely.geometry.point.Point at 0x12659c780>,
#  <shapely.geometry.point.Point at 0x12659ce10>,
#  <shapely.geometry.point.Point at 0x12659cc18>,
#  <shapely.geometry.point.Point at 0x12659c7b8>,
#  <shapely.geometry.point.Point at 0x12659ca58>,
#  <shapely.geometry.point.Point at 0x121709588>,
#  <shapely.geometry.point.Point at 0x121553048>,
#  <shapely.geometry.point.Point at 0x121783400>,
#  <shapely.geometry.point.Point at 0x1299277b8>,
#  <shapely.geometry.point.Point at 0x129927550>,
#  <shapely.geometry.point.Point at 0x129927710>,
#  <shapely.geometry.point.Point at 0x1299270f0>,
#  <shapely.geometry.point.Point at 0x1299278d0>,
#  <shapely.geometry.point.Point at 0x129927128>,
#  <shapely.geometry.point.Point at 0x129927240>,
#  <shapely.geometry.point.Point at 0x129927278>,
#  <shapely.geometry.point.Point at 0x129927748>,
#  <shapely.geometry.point.Point at 0x1299276d8>,
#  <shapely.geometry.point.Point at 0x1299270b8>,
#  <shapely.geometry.point.Point at 0x129927160>,
#  <shapely.geometry.point.Point at 0x129927390>,
#  <shapely.geometry.point.Point at 0x1299272b0>,
#  <shapely.geometry.point.Point at 0x129927518>,
#  <shapely.geometry.point.Point at 0x129927320>,
#  <shapely.geometry.point.Point at 0x129927438>,
#  <shapely.geometry.point.Point at 0x129927470>,
#  <shapely.geometry.point.Point at 0x1299272e8>,
#  <shapely.geometry.point.Point at 0x129927358>,
#  <shapely.geometry.point.Point at 0x129927198>,
#  <shapely.geometry.point.Point at 0x129927208>,
#  <shapely.geometry.point.Point at 0x129927a90>,
#  <shapely.geometry.point.Point at 0x129927b38>,
#  <shapely.geometry.point.Point at 0x129927b00>,
#  <shapely.geometry.point.Point at 0x129927ac8>,
#  <shapely.geometry.point.Point at 0x129927a58>,
#  <shapely.geometry.point.Point at 0x129927a20>,
#  <shapely.geometry.point.Point at 0x1299279e8>,
#  <shapely.geometry.point.Point at 0x1299279b0>,
#  <shapely.geometry.point.Point at 0x1299274e0>,
#  <shapely.geometry.point.Point at 0x129927978>,
#  <shapely.geometry.point.Point at 0x129927780>,
#  <shapely.geometry.point.Point at 0x1299271d0>,
#  <shapely.geometry.point.Point at 0x1299276a0>,
#  <shapely.geometry.point.Point at 0x129927898>,
#  <shapely.geometry.point.Point at 0x1299273c8>,
#  <shapely.geometry.point.Point at 0x129927400>,
#  <shapely.geometry.point.Point at 0x1299274a8>,
#  <shapely.geometry.point.Point at 0x129927908>,
#  <shapely.geometry.point.Point at 0x129927940>,
#  <shapely.geometry.point.Point at 0x129927b70>,
#  <shapely.geometry.point.Point at 0x129927ba8>,
#  <shapely.geometry.point.Point at 0x129927be0>,
#  <shapely.geometry.point.Point at 0x129927c18>,
#  <shapely.geometry.point.Point at 0x129927c50>,
#  <shapely.geometry.point.Point at 0x129927c88>,
#  <shapely.geometry.point.Point at 0x129927cc0>,
#  <shapely.geometry.point.Point at 0x129927cf8>,
#  <shapely.geometry.point.Point at 0x129927d30>,
#  <shapely.geometry.point.Point at 0x129927d68>,
#  <shapely.geometry.point.Point at 0x129927da0>,
#  <shapely.geometry.point.Point at 0x129927dd8>,
#  <shapely.geometry.point.Point at 0x129927e10>,
#  <shapely.geometry.point.Point at 0x129927e48>,
#  <shapely.geometry.point.Point at 0x129927e80>,
#  <shapely.geometry.point.Point at 0x129927eb8>,
#  <shapely.geometry.point.Point at 0x129927ef0>,
#  <shapely.geometry.point.Point at 0x129927f28>,
#  <shapely.geometry.point.Point at 0x129927f60>,
#  <shapely.geometry.point.Point at 0x129927f98>,
#  <shapely.geometry.point.Point at 0x129927fd0>,
#  <shapely.geometry.point.Point at 0x12f005048>,
#  <shapely.geometry.point.Point at 0x12f005080>,
#  <shapely.geometry.point.Point at 0x12f0050b8>,
#  <shapely.geometry.point.Point at 0x12f0050f0>,
#  <shapely.geometry.point.Point at 0x12f005128>,
#  <shapely.geometry.point.Point at 0x12f005160>,
#  <shapely.geometry.point.Point at 0x12f005198>,
#  <shapely.geometry.point.Point at 0x12f0051d0>,
#  <shapely.geometry.point.Point at 0x12f005208>,
#  <shapely.geometry.point.Point at 0x12f005240>,
#  <shapely.geometry.point.Point at 0x12f005278>,
#  <shapely.geometry.point.Point at 0x12f0052b0>,
#  <shapely.geometry.point.Point at 0x12f0052e8>,
#  <shapely.geometry.point.Point at 0x12f005320>,
#  <shapely.geometry.point.Point at 0x12f005358>,
#  <shapely.geometry.point.Point at 0x12f005390>,
#  <shapely.geometry.point.Point at 0x12f0053c8>,
#  <shapely.geometry.point.Point at 0x12f005400>,
#  <shapely.geometry.point.Point at 0x12f005438>,
#  <shapely.geometry.point.Point at 0x12f005470>,
#  <shapely.geometry.point.Point at 0x12f0054a8>,
#  <shapely.geometry.point.Point at 0x12f0054e0>,
#  <shapely.geometry.point.Point at 0x12f005518>,
#  <shapely.geometry.point.Point at 0x12f005550>,
#  <shapely.geometry.point.Point at 0x12f005588>,
#  <shapely.geometry.point.Point at 0x12f0055c0>,
#  <shapely.geometry.point.Point at 0x12f0055f8>,
#  <shapely.geometry.point.Point at 0x12f005630>,
#  <shapely.geometry.point.Point at 0x12f005668>,
#  <shapely.geometry.point.Point at 0x12f0056a0>,
#  <shapely.geometry.point.Point at 0x12f0056d8>,
#  <shapely.geometry.point.Point at 0x12f005710>,
#  <shapely.geometry.point.Point at 0x12f005748>,
#  <shapely.geometry.point.Point at 0x12f005780>,
#  <shapely.geometry.point.Point at 0x12f0057b8>,
#  <shapely.geometry.point.Point at 0x12f0057f0>,
#  <shapely.geometry.point.Point at 0x12f005828>,
#  <shapely.geometry.point.Point at 0x12f005860>,
#  <shapely.geometry.point.Point at 0x12f005898>,
#  <shapely.geometry.point.Point at 0x12f0058d0>,
#  <shapely.geometry.point.Point at 0x12f005908>,
#  <shapely.geometry.point.Point at 0x12f005940>,
#  <shapely.geometry.point.Point at 0x12f005978>,
#  <shapely.geometry.point.Point at 0x12f0059b0>,
#  <shapely.geometry.point.Point at 0x12f0059e8>,
#  <shapely.geometry.point.Point at 0x12f005a20>,
#  <shapely.geometry.point.Point at 0x12f005a58>,
#  <shapely.geometry.point.Point at 0x12f005a90>,
#  <shapely.geometry.point.Point at 0x12f005ac8>,
#  <shapely.geometry.point.Point at 0x12f005b00>,
#  <shapely.geometry.point.Point at 0x12f005b38>,
#  <shapely.geometry.point.Point at 0x12f005b70>,
#  <shapely.geometry.point.Point at 0x12f005ba8>,
#  <shapely.geometry.point.Point at 0x12f005be0>,
#  <shapely.geometry.point.Point at 0x12f005c18>,
#  <shapely.geometry.point.Point at 0x12f005c50>,
#  <shapely.geometry.point.Point at 0x12f005c88>,
#  <shapely.geometry.point.Point at 0x12f005cc0>,
#  <shapely.geometry.point.Point at 0x12f005cf8>,
#  <shapely.geometry.point.Point at 0x12f005d30>,
#  <shapely.geometry.point.Point at 0x12f005d68>,
#  <shapely.geometry.point.Point at 0x12f005da0>,
#  <shapely.geometry.point.Point at 0x12f005dd8>,
#  <shapely.geometry.point.Point at 0x12f005e10>,
#  <shapely.geometry.point.Point at 0x12f005e48>,
#  <shapely.geometry.point.Point at 0x12f005e80>,
#  <shapely.geometry.point.Point at 0x12f005eb8>,
#  <shapely.geometry.point.Point at 0x12f005ef0>,
#  <shapely.geometry.point.Point at 0x12f005f28>,
#  <shapely.geometry.point.Point at 0x12f005f60>,
#  <shapely.geometry.point.Point at 0x12f005f98>,
#  <shapely.geometry.point.Point at 0x12f005fd0>,
#  <shapely.geometry.point.Point at 0x1265ad048>,
#  <shapely.geometry.point.Point at 0x1265ad080>,
#  <shapely.geometry.point.Point at 0x1265ad0b8>,
#  <shapely.geometry.point.Point at 0x1265ad0f0>,
#  <shapely.geometry.point.Point at 0x1265ad128>,
#  <shapely.geometry.point.Point at 0x1265ad160>,
#  <shapely.geometry.point.Point at 0x1265ad198>,
#  <shapely.geometry.point.Point at 0x1265ad1d0>,
#  <shapely.geometry.point.Point at 0x1265ad208>,
#  <shapely.geometry.point.Point at 0x1265ad240>,
#  <shapely.geometry.point.Point at 0x1265ad278>,
#  <shapely.geometry.point.Point at 0x1265ad2b0>,
#  <shapely.geometry.point.Point at 0x1265ad2e8>,
#  <shapely.geometry.point.Point at 0x1265ad320>,
#  <shapely.geometry.point.Point at 0x1265ad358>,
#  <shapely.geometry.point.Point at 0x1265ad390>,
#  <shapely.geometry.point.Point at 0x1265ad3c8>,
#  <shapely.geometry.point.Point at 0x1265ad400>,
#  <shapely.geometry.point.Point at 0x1265ad438>,
#  <shapely.geometry.point.Point at 0x1265ad470>,
#  <shapely.geometry.point.Point at 0x1265ad4a8>,
#  <shapely.geometry.point.Point at 0x1265ad4e0>,
#  <shapely.geometry.point.Point at 0x1265ad518>,
#  <shapely.geometry.point.Point at 0x1265ad550>,
#  <shapely.geometry.point.Point at 0x1265ad588>,
#  <shapely.geometry.point.Point at 0x1265ad5c0>,
#  <shapely.geometry.point.Point at 0x1265ad5f8>,
#  <shapely.geometry.point.Point at 0x1265ad630>,
#  <shapely.geometry.point.Point at 0x1265ad668>,
#  <shapely.geometry.point.Point at 0x1265ad6a0>,
#  <shapely.geometry.point.Point at 0x1265ad6d8>,
#  <shapely.geometry.point.Point at 0x1265ad710>,
#  <shapely.geometry.point.Point at 0x1265ad748>,
#  <shapely.geometry.point.Point at 0x1265ad780>,
#  <shapely.geometry.point.Point at 0x1265ad7b8>,
#  <shapely.geometry.point.Point at 0x1265ad7f0>,
#  <shapely.geometry.point.Point at 0x1265ad828>,
#  <shapely.geometry.point.Point at 0x1265ad860>,
#  <shapely.geometry.point.Point at 0x1265ad898>,
#  <shapely.geometry.point.Point at 0x1265ad8d0>,
#  <shapely.geometry.point.Point at 0x1265ad908>,
#  <shapely.geometry.point.Point at 0x1265ad940>,
#  <shapely.geometry.point.Point at 0x1265ad978>,
#  <shapely.geometry.point.Point at 0x1265ad9b0>,
#  <shapely.geometry.point.Point at 0x1265ad9e8>,
#  <shapely.geometry.point.Point at 0x1265ada20>,
#  <shapely.geometry.point.Point at 0x1265ada58>,
#  <shapely.geometry.point.Point at 0x1265ada90>,
#  <shapely.geometry.point.Point at 0x1265adac8>,
#  <shapely.geometry.point.Point at 0x1265adb00>,
#  <shapely.geometry.point.Point at 0x1265adb38>,
#  <shapely.geometry.point.Point at 0x1265adb70>,
#  <shapely.geometry.point.Point at 0x1265adba8>,
#  <shapely.geometry.point.Point at 0x1265adbe0>,
#  <shapely.geometry.point.Point at 0x1265adc18>,
#  <shapely.geometry.point.Point at 0x1265adc50>,
#  <shapely.geometry.point.Point at 0x1265adc88>,
#  <shapely.geometry.point.Point at 0x1265adcc0>,
#  <shapely.geometry.point.Point at 0x1265adcf8>,
#  <shapely.geometry.point.Point at 0x1265add30>,
#  <shapely.geometry.point.Point at 0x1265add68>,
#  <shapely.geometry.point.Point at 0x1265adda0>,
#  <shapely.geometry.point.Point at 0x1265addd8>,
#  <shapely.geometry.point.Point at 0x1265ade10>,
#  <shapely.geometry.point.Point at 0x1265ade48>,
#  <shapely.geometry.point.Point at 0x1265ade80>,
#  <shapely.geometry.point.Point at 0x1265adeb8>,
#  <shapely.geometry.point.Point at 0x1265adef0>,
#  <shapely.geometry.point.Point at 0x1265adf28>,
#  <shapely.geometry.point.Point at 0x1265adf60>,
#  <shapely.geometry.point.Point at 0x1265adf98>,
#  <shapely.geometry.point.Point at 0x1265adfd0>,
#  <shapely.geometry.point.Point at 0x1265acfd0>,
#  <shapely.geometry.point.Point at 0x1265acf98>,
#  <shapely.geometry.point.Point at 0x1265acf60>,
#  <shapely.geometry.point.Point at 0x1265acf28>,
#  <shapely.geometry.point.Point at 0x1265acef0>,
#  <shapely.geometry.point.Point at 0x1265aceb8>,
#  <shapely.geometry.point.Point at 0x1265ace80>,
#  <shapely.geometry.point.Point at 0x1265ace48>,
#  <shapely.geometry.point.Point at 0x1265ace10>,
#  <shapely.geometry.point.Point at 0x1265acdd8>,
#  <shapely.geometry.point.Point at 0x1265acda0>,
#  <shapely.geometry.point.Point at 0x1265acd68>,
#  <shapely.geometry.point.Point at 0x1265acd30>,
#  <shapely.geometry.point.Point at 0x1265accf8>,
#  <shapely.geometry.point.Point at 0x1265accc0>,
#  <shapely.geometry.point.Point at 0x1265acc88>,
#  <shapely.geometry.point.Point at 0x1265acc50>,
#  <shapely.geometry.point.Point at 0x1265acc18>,
#  <shapely.geometry.point.Point at 0x1265acbe0>,
#  <shapely.geometry.point.Point at 0x1265acba8>,
#  <shapely.geometry.point.Point at 0x1265acb70>,
#  <shapely.geometry.point.Point at 0x1265acb38>,
#  <shapely.geometry.point.Point at 0x1265acb00>,
#  <shapely.geometry.point.Point at 0x1265acac8>,
#  <shapely.geometry.point.Point at 0x1265aca90>,
#  <shapely.geometry.point.Point at 0x1265aca58>,
#  <shapely.geometry.point.Point at 0x1265aca20>,
#  <shapely.geometry.point.Point at 0x1265ac9e8>,
#  <shapely.geometry.point.Point at 0x1265ac9b0>,
#  <shapely.geometry.point.Point at 0x1265ac978>,
#  <shapely.geometry.point.Point at 0x1265ac940>,
#  <shapely.geometry.point.Point at 0x1265ac908>,
#  <shapely.geometry.point.Point at 0x1265ac8d0>,
#  <shapely.geometry.point.Point at 0x1265ac898>,
#  <shapely.geometry.point.Point at 0x1265ac860>,
#  <shapely.geometry.point.Point at 0x1265ac828>,
#  <shapely.geometry.point.Point at 0x1265ac7f0>,
#  <shapely.geometry.point.Point at 0x1265ac7b8>,
#  <shapely.geometry.point.Point at 0x1265ac780>,
#  <shapely.geometry.point.Point at 0x1265ac748>,
#  <shapely.geometry.point.Point at 0x1265ac710>,
#  <shapely.geometry.point.Point at 0x1265ac6d8>,
#  <shapely.geometry.point.Point at 0x1265ac6a0>,
#  <shapely.geometry.point.Point at 0x1265ac668>,
#  <shapely.geometry.point.Point at 0x1265ac630>,
#  <shapely.geometry.point.Point at 0x1265ac5f8>,
#  <shapely.geometry.point.Point at 0x1265ac5c0>,
#  <shapely.geometry.point.Point at 0x1265ac588>,
#  <shapely.geometry.point.Point at 0x1265ac550>,
#  <shapely.geometry.point.Point at 0x1265ac518>,
#  <shapely.geometry.point.Point at 0x1265ac4e0>,
#  <shapely.geometry.point.Point at 0x1265ac4a8>,
#  <shapely.geometry.point.Point at 0x1265ac470>,
#  <shapely.geometry.point.Point at 0x1265ac438>,
#  <shapely.geometry.point.Point at 0x1265ac400>,
#  <shapely.geometry.point.Point at 0x1265ac3c8>,
#  <shapely.geometry.point.Point at 0x1265ac390>,
#  <shapely.geometry.point.Point at 0x1265ac358>,
#  <shapely.geometry.point.Point at 0x1265ac320>,
#  <shapely.geometry.point.Point at 0x1265ac2e8>,
#  <shapely.geometry.point.Point at 0x1265ac2b0>,
#  <shapely.geometry.point.Point at 0x1265ac278>,
#  <shapely.geometry.point.Point at 0x1265ac240>,
#  <shapely.geometry.point.Point at 0x1265ac208>,
#  <shapely.geometry.point.Point at 0x1265ac1d0>,
#  <shapely.geometry.point.Point at 0x1265ac198>,
#  <shapely.geometry.point.Point at 0x1265ac160>,
#  <shapely.geometry.point.Point at 0x1265ac128>,
#  <shapely.geometry.point.Point at 0x1265ac0f0>,
#  <shapely.geometry.point.Point at 0x1265ac0b8>,
#  <shapely.geometry.point.Point at 0x1265ac080>,
#  <shapely.geometry.point.Point at 0x1265ac048>,
#  <shapely.geometry.point.Point at 0x1265a8048>,
#  <shapely.geometry.point.Point at 0x1265a8080>,
#  <shapely.geometry.point.Point at 0x1265a80b8>,
#  <shapely.geometry.point.Point at 0x1265a80f0>,
#  <shapely.geometry.point.Point at 0x1265a8128>,
#  <shapely.geometry.point.Point at 0x1265a8160>,
#  <shapely.geometry.point.Point at 0x1265a8198>,
#  <shapely.geometry.point.Point at 0x1265a81d0>,
#  <shapely.geometry.point.Point at 0x1265a8208>,
#  <shapely.geometry.point.Point at 0x1265a8240>,
#  <shapely.geometry.point.Point at 0x1265a8278>,
#  <shapely.geometry.point.Point at 0x1265a82b0>,
#  <shapely.geometry.point.Point at 0x1265a82e8>,
#  <shapely.geometry.point.Point at 0x1265a8320>,
#  <shapely.geometry.point.Point at 0x1265a8358>,
#  <shapely.geometry.point.Point at 0x1265a8390>,
#  <shapely.geometry.point.Point at 0x1265a83c8>,
#  <shapely.geometry.point.Point at 0x1265a8400>,
#  <shapely.geometry.point.Point at 0x1265a8438>,
#  <shapely.geometry.point.Point at 0x1265a8470>,
#  <shapely.geometry.point.Point at 0x1265a84a8>,
#  <shapely.geometry.point.Point at 0x1265a84e0>,
#  <shapely.geometry.point.Point at 0x1265a8518>,
#  <shapely.geometry.point.Point at 0x1265a8550>,
#  <shapely.geometry.point.Point at 0x1265a8588>,
#  <shapely.geometry.point.Point at 0x1265a85c0>,
#  <shapely.geometry.point.Point at 0x1265a85f8>,
#  <shapely.geometry.point.Point at 0x1265a8630>,
#  <shapely.geometry.point.Point at 0x1265a8668>,
#  <shapely.geometry.point.Point at 0x1265a86a0>,
#  <shapely.geometry.point.Point at 0x1265a86d8>,
#  <shapely.geometry.point.Point at 0x1265a8710>,
#  <shapely.geometry.point.Point at 0x1265a8748>,
#  <shapely.geometry.point.Point at 0x1265a8780>,
#  <shapely.geometry.point.Point at 0x1265a87b8>,
#  <shapely.geometry.point.Point at 0x1265a87f0>,
#  <shapely.geometry.point.Point at 0x1265a8828>,
#  <shapely.geometry.point.Point at 0x1265a8860>,
#  <shapely.geometry.point.Point at 0x1265a8898>,
#  <shapely.geometry.point.Point at 0x1265a88d0>,
#  <shapely.geometry.point.Point at 0x1265a8908>,
#  <shapely.geometry.point.Point at 0x1265a8940>,
#  <shapely.geometry.point.Point at 0x1265a8978>,
#  <shapely.geometry.point.Point at 0x1265a89b0>,
#  <shapely.geometry.point.Point at 0x1265a89e8>,
#  <shapely.geometry.point.Point at 0x1265a8a20>,
#  <shapely.geometry.point.Point at 0x1265a8a58>,
#  <shapely.geometry.point.Point at 0x1265a8a90>,
#  <shapely.geometry.point.Point at 0x1265a8ac8>,
#  <shapely.geometry.point.Point at 0x1265a8b00>,
#  <shapely.geometry.point.Point at 0x1265a8b38>,
#  <shapely.geometry.point.Point at 0x1265a8b70>,
#  <shapely.geometry.point.Point at 0x1265a8ba8>,
#  <shapely.geometry.point.Point at 0x1265a8be0>,
#  <shapely.geometry.point.Point at 0x1265a8c18>,
#  <shapely.geometry.point.Point at 0x1265a8c50>,
#  <shapely.geometry.point.Point at 0x1265a8c88>,
#  <shapely.geometry.point.Point at 0x1265a8cc0>,
#  <shapely.geometry.point.Point at 0x1265a8cf8>,
#  <shapely.geometry.point.Point at 0x1265a8d30>,
#  <shapely.geometry.point.Point at 0x1265a8d68>,
#  <shapely.geometry.point.Point at 0x1265a8da0>,
#  <shapely.geometry.point.Point at 0x1265a8dd8>,
#  <shapely.geometry.point.Point at 0x1265a8e10>,
#  <shapely.geometry.point.Point at 0x1265a8e48>,
#  <shapely.geometry.point.Point at 0x1265a8e80>,
#  <shapely.geometry.point.Point at 0x1265a8eb8>,
#  <shapely.geometry.point.Point at 0x1265a8ef0>,
#  <shapely.geometry.point.Point at 0x1265a8f28>,
#  <shapely.geometry.point.Point at 0x1265a8f60>,
#  <shapely.geometry.point.Point at 0x1265a8f98>,
#  <shapely.geometry.point.Point at 0x1265a8fd0>,
#  <shapely.geometry.point.Point at 0x1265a2048>,
#  <shapely.geometry.point.Point at 0x1265a2080>,
#  <shapely.geometry.point.Point at 0x1265a20b8>,
#  <shapely.geometry.point.Point at 0x1265a20f0>,
#  <shapely.geometry.point.Point at 0x1265a2128>,
#  <shapely.geometry.point.Point at 0x1265a2160>,
#  <shapely.geometry.point.Point at 0x1265a2198>,
#  <shapely.geometry.point.Point at 0x1265a21d0>,
#  <shapely.geometry.point.Point at 0x1265a2208>,
#  <shapely.geometry.point.Point at 0x1265a2240>,
#  <shapely.geometry.point.Point at 0x1265a2278>,
#  <shapely.geometry.point.Point at 0x1265a22b0>,
#  <shapely.geometry.point.Point at 0x1265a22e8>,
#  <shapely.geometry.point.Point at 0x1265a2320>,
#  <shapely.geometry.point.Point at 0x1265a2358>,
#  <shapely.geometry.point.Point at 0x1265a2390>,
#  <shapely.geometry.point.Point at 0x1265a23c8>,
#  <shapely.geometry.point.Point at 0x1265a2400>,
#  <shapely.geometry.point.Point at 0x1265a2438>,
#  <shapely.geometry.point.Point at 0x1265a2470>,
#  <shapely.geometry.point.Point at 0x1265a24a8>,
#  <shapely.geometry.point.Point at 0x1265a24e0>,
#  <shapely.geometry.point.Point at 0x1265a2518>,
#  <shapely.geometry.point.Point at 0x1265a2550>,
#  <shapely.geometry.point.Point at 0x1265a2588>,
#  <shapely.geometry.point.Point at 0x1265a25c0>,
#  <shapely.geometry.point.Point at 0x1265a25f8>,
#  <shapely.geometry.point.Point at 0x1265a2630>,
#  <shapely.geometry.point.Point at 0x1265a2668>,
#  <shapely.geometry.point.Point at 0x1265a26a0>,
#  <shapely.geometry.point.Point at 0x1265a26d8>,
#  <shapely.geometry.point.Point at 0x1265a2710>,
#  <shapely.geometry.point.Point at 0x1265a2748>,
#  <shapely.geometry.point.Point at 0x1265a2780>,
#  <shapely.geometry.point.Point at 0x1265a27b8>,
#  <shapely.geometry.point.Point at 0x1265a27f0>,
#  <shapely.geometry.point.Point at 0x1265a2828>,
#  <shapely.geometry.point.Point at 0x1265a2860>,
#  <shapely.geometry.point.Point at 0x1265a2898>,
#  <shapely.geometry.point.Point at 0x1265a28d0>,
#  <shapely.geometry.point.Point at 0x1265a2908>,
#  <shapely.geometry.point.Point at 0x1265a2940>,
#  <shapely.geometry.point.Point at 0x1265a2978>,
#  <shapely.geometry.point.Point at 0x1265a29b0>,
#  <shapely.geometry.point.Point at 0x1265a29e8>,
#  <shapely.geometry.point.Point at 0x1265a2a20>,
#  <shapely.geometry.point.Point at 0x1265a2a58>,
#  <shapely.geometry.point.Point at 0x1265a2a90>,
#  <shapely.geometry.point.Point at 0x1265a2ac8>,
#  <shapely.geometry.point.Point at 0x1265a2b00>,
#  <shapely.geometry.point.Point at 0x1265a2b38>,
#  <shapely.geometry.point.Point at 0x1265a2b70>,
#  <shapely.geometry.point.Point at 0x1265a2ba8>,
#  <shapely.geometry.point.Point at 0x1265a2be0>,
#  <shapely.geometry.point.Point at 0x1265a2c18>,
#  <shapely.geometry.point.Point at 0x1265a2c50>,
#  <shapely.geometry.point.Point at 0x1265a2c88>,
#  <shapely.geometry.point.Point at 0x1265a2cc0>,
#  <shapely.geometry.point.Point at 0x1265a2cf8>,
#  <shapely.geometry.point.Point at 0x1265a2d30>,
#  <shapely.geometry.point.Point at 0x1265a2d68>,
#  <shapely.geometry.point.Point at 0x1265a2da0>,
#  <shapely.geometry.point.Point at 0x1265a2dd8>,
#  <shapely.geometry.point.Point at 0x1265a2e10>,
#  <shapely.geometry.point.Point at 0x1265a2e48>,
#  <shapely.geometry.point.Point at 0x1265a2e80>,
#  <shapely.geometry.point.Point at 0x1265a2eb8>,
#  <shapely.geometry.point.Point at 0x1265a2ef0>,
#  <shapely.geometry.point.Point at 0x1265a2f28>,
#  <shapely.geometry.point.Point at 0x1265a2f60>,
#  <shapely.geometry.point.Point at 0x1265a2f98>,
#  <shapely.geometry.point.Point at 0x1265a2fd0>,
#  <shapely.geometry.point.Point at 0x129856048>,
#  <shapely.geometry.point.Point at 0x129856080>,
#  <shapely.geometry.point.Point at 0x1298560b8>,
#  <shapely.geometry.point.Point at 0x1298560f0>,
#  <shapely.geometry.point.Point at 0x129856128>,
#  <shapely.geometry.point.Point at 0x129856160>,
#  <shapely.geometry.point.Point at 0x129856198>,
#  <shapely.geometry.point.Point at 0x1298561d0>,
#  <shapely.geometry.point.Point at 0x129856208>,
#  <shapely.geometry.point.Point at 0x129856240>,
#  <shapely.geometry.point.Point at 0x129856278>,
#  <shapely.geometry.point.Point at 0x1298562b0>,
#  <shapely.geometry.point.Point at 0x1298562e8>,
#  <shapely.geometry.point.Point at 0x129856320>,
#  <shapely.geometry.point.Point at 0x129856358>,
#  <shapely.geometry.point.Point at 0x129856390>,
#  <shapely.geometry.point.Point at 0x1298563c8>,
#  <shapely.geometry.point.Point at 0x129856400>,
#  <shapely.geometry.point.Point at 0x129856438>,
#  <shapely.geometry.point.Point at 0x129856470>,
#  <shapely.geometry.point.Point at 0x1298564a8>,
#  <shapely.geometry.point.Point at 0x1298564e0>,
#  <shapely.geometry.point.Point at 0x129856518>,
#  <shapely.geometry.point.Point at 0x129856550>,
#  <shapely.geometry.point.Point at 0x129856588>,
#  <shapely.geometry.point.Point at 0x1298565c0>,
#  <shapely.geometry.point.Point at 0x1298565f8>,
#  <shapely.geometry.point.Point at 0x129856630>,
#  <shapely.geometry.point.Point at 0x129856668>,
#  <shapely.geometry.point.Point at 0x1298566a0>,
#  <shapely.geometry.point.Point at 0x1298566d8>,
#  <shapely.geometry.point.Point at 0x129856710>,
#  <shapely.geometry.point.Point at 0x129856748>,
#  <shapely.geometry.point.Point at 0x129856780>,
#  <shapely.geometry.point.Point at 0x1298567b8>,
#  <shapely.geometry.point.Point at 0x1298567f0>,
#  <shapely.geometry.point.Point at 0x129856828>,
#  <shapely.geometry.point.Point at 0x129856860>,
#  <shapely.geometry.point.Point at 0x129856898>,
#  <shapely.geometry.point.Point at 0x1298568d0>,
#  <shapely.geometry.point.Point at 0x129856908>,
#  <shapely.geometry.point.Point at 0x129856940>,
#  <shapely.geometry.point.Point at 0x129856978>,
#  <shapely.geometry.point.Point at 0x1298569b0>,
#  <shapely.geometry.point.Point at 0x1298569e8>,
#  <shapely.geometry.point.Point at 0x129856a20>,
#  <shapely.geometry.point.Point at 0x129856a58>,
#  <shapely.geometry.point.Point at 0x129856a90>,
#  <shapely.geometry.point.Point at 0x129856ac8>,
#  <shapely.geometry.point.Point at 0x129856b00>,
#  <shapely.geometry.point.Point at 0x129856b38>,
#  <shapely.geometry.point.Point at 0x129856b70>,
#  <shapely.geometry.point.Point at 0x129856ba8>,
#  <shapely.geometry.point.Point at 0x129856be0>,
#  <shapely.geometry.point.Point at 0x129856c18>,
#  <shapely.geometry.point.Point at 0x129856c50>,
#  <shapely.geometry.point.Point at 0x129856c88>,
#  <shapely.geometry.point.Point at 0x129856cc0>,
#  <shapely.geometry.point.Point at 0x129856cf8>,
#  <shapely.geometry.point.Point at 0x129856d30>,
#  <shapely.geometry.point.Point at 0x129856d68>,
#  <shapely.geometry.point.Point at 0x129856da0>,
#  <shapely.geometry.point.Point at 0x129856dd8>,
#  <shapely.geometry.point.Point at 0x129856e10>,
#  <shapely.geometry.point.Point at 0x129856e48>,
#  <shapely.geometry.point.Point at 0x129856e80>,
#  <shapely.geometry.point.Point at 0x129856eb8>,
#  <shapely.geometry.point.Point at 0x129856ef0>,
#  <shapely.geometry.point.Point at 0x129856f28>,
#  <shapely.geometry.point.Point at 0x129856f60>,
#  <shapely.geometry.point.Point at 0x129856f98>,
#  <shapely.geometry.point.Point at 0x129856fd0>,
#  <shapely.geometry.point.Point at 0x129850048>,
#  <shapely.geometry.point.Point at 0x129850080>,
#  <shapely.geometry.point.Point at 0x1298500b8>,
#  <shapely.geometry.point.Point at 0x1298500f0>,
#  <shapely.geometry.point.Point at 0x129850128>,
#  <shapely.geometry.point.Point at 0x129850160>,
#  <shapely.geometry.point.Point at 0x129850198>,
#  <shapely.geometry.point.Point at 0x1298501d0>,
#  <shapely.geometry.point.Point at 0x129850208>,
#  <shapely.geometry.point.Point at 0x129850240>,
#  <shapely.geometry.point.Point at 0x129850278>,
#  <shapely.geometry.point.Point at 0x1298502b0>,
#  <shapely.geometry.point.Point at 0x1298502e8>,
#  <shapely.geometry.point.Point at 0x129850320>,
#  <shapely.geometry.point.Point at 0x129850358>,
#  <shapely.geometry.point.Point at 0x129850390>,
#  <shapely.geometry.point.Point at 0x1298503c8>,
#  <shapely.geometry.point.Point at 0x129850400>,
#  <shapely.geometry.point.Point at 0x129850438>,
#  <shapely.geometry.point.Point at 0x129850470>,
#  <shapely.geometry.point.Point at 0x1298504a8>,
#  <shapely.geometry.point.Point at 0x1298504e0>,
#  <shapely.geometry.point.Point at 0x129850518>,
#  <shapely.geometry.point.Point at 0x129850550>,
#  <shapely.geometry.point.Point at 0x129850588>,
#  <shapely.geometry.point.Point at 0x1298505c0>,
#  <shapely.geometry.point.Point at 0x1298505f8>,
#  <shapely.geometry.point.Point at 0x129850630>,
#  <shapely.geometry.point.Point at 0x129850668>,
#  <shapely.geometry.point.Point at 0x1298506a0>,
#  <shapely.geometry.point.Point at 0x1298506d8>,
#  <shapely.geometry.point.Point at 0x129850710>,
#  <shapely.geometry.point.Point at 0x129850748>,
#  <shapely.geometry.point.Point at 0x129850780>,
#  <shapely.geometry.point.Point at 0x1298507b8>,
#  <shapely.geometry.point.Point at 0x1298507f0>,
#  <shapely.geometry.point.Point at 0x129850828>,
#  <shapely.geometry.point.Point at 0x129850860>,
#  <shapely.geometry.point.Point at 0x129850898>,
#  <shapely.geometry.point.Point at 0x1298508d0>,
#  <shapely.geometry.point.Point at 0x129850908>,
#  <shapely.geometry.point.Point at 0x129850940>,
#  <shapely.geometry.point.Point at 0x129850978>,
#  <shapely.geometry.point.Point at 0x1298509b0>,
#  <shapely.geometry.point.Point at 0x1298509e8>,
#  <shapely.geometry.point.Point at 0x129850a20>,
#  <shapely.geometry.point.Point at 0x129850a58>,
#  <shapely.geometry.point.Point at 0x129850a90>,
#  <shapely.geometry.point.Point at 0x129850ac8>,
#  <shapely.geometry.point.Point at 0x129850b00>,
#  <shapely.geometry.point.Point at 0x129850b38>,
#  <shapely.geometry.point.Point at 0x129850b70>,
#  <shapely.geometry.point.Point at 0x129850ba8>,
#  <shapely.geometry.point.Point at 0x129850be0>,
#  <shapely.geometry.point.Point at 0x129850c18>,
#  <shapely.geometry.point.Point at 0x129850c50>,
#  <shapely.geometry.point.Point at 0x129850c88>,
#  <shapely.geometry.point.Point at 0x129850cc0>,
#  <shapely.geometry.point.Point at 0x129850cf8>,
#  <shapely.geometry.point.Point at 0x129850d30>,
#  <shapely.geometry.point.Point at 0x129850d68>,
#  <shapely.geometry.point.Point at 0x129850da0>,
#  <shapely.geometry.point.Point at 0x129850dd8>,
#  <shapely.geometry.point.Point at 0x129850e10>,
#  <shapely.geometry.point.Point at 0x129850e48>,
#  <shapely.geometry.point.Point at 0x129850e80>,
#  <shapely.geometry.point.Point at 0x129850eb8>,
#  <shapely.geometry.point.Point at 0x129850ef0>,
#  <shapely.geometry.point.Point at 0x129850f28>,
#  <shapely.geometry.point.Point at 0x129850f60>,
#  <shapely.geometry.point.Point at 0x129850f98>,
#  <shapely.geometry.point.Point at 0x129850fd0>,
#  <shapely.geometry.point.Point at 0x12984b048>,
#  <shapely.geometry.point.Point at 0x12984b080>,
#  <shapely.geometry.point.Point at 0x12984b0b8>,
#  <shapely.geometry.point.Point at 0x12984b0f0>,
#  <shapely.geometry.point.Point at 0x12984b128>,
#  <shapely.geometry.point.Point at 0x12984b160>,
#  <shapely.geometry.point.Point at 0x12984b198>,
#  <shapely.geometry.point.Point at 0x12984b1d0>,
#  <shapely.geometry.point.Point at 0x12984b208>,
#  <shapely.geometry.point.Point at 0x12984b240>,
#  <shapely.geometry.point.Point at 0x12984b278>,
#  <shapely.geometry.point.Point at 0x12984b2b0>,
#  <shapely.geometry.point.Point at 0x12984b2e8>,
#  <shapely.geometry.point.Point at 0x12984b320>,
#  <shapely.geometry.point.Point at 0x12984b358>,
#  <shapely.geometry.point.Point at 0x12984b390>,
#  <shapely.geometry.point.Point at 0x12984b3c8>,
#  <shapely.geometry.point.Point at 0x12984b400>,
#  <shapely.geometry.point.Point at 0x12984b438>,
#  <shapely.geometry.point.Point at 0x12984b470>,
#  <shapely.geometry.point.Point at 0x12984b4a8>,
#  <shapely.geometry.point.Point at 0x12984b4e0>,
#  <shapely.geometry.point.Point at 0x12984b518>,
#  <shapely.geometry.point.Point at 0x12984b550>,
#  <shapely.geometry.point.Point at 0x12984b588>,
#  <shapely.geometry.point.Point at 0x12984b5c0>,
#  <shapely.geometry.point.Point at 0x12984b5f8>,
#  <shapely.geometry.point.Point at 0x12984b630>,
#  <shapely.geometry.point.Point at 0x12984b668>,
#  <shapely.geometry.point.Point at 0x12984b6a0>,
#  <shapely.geometry.point.Point at 0x12984b6d8>,
#  <shapely.geometry.point.Point at 0x12984b710>,
#  <shapely.geometry.point.Point at 0x12984b748>,
#  <shapely.geometry.point.Point at 0x12984b780>,
#  <shapely.geometry.point.Point at 0x12984b7b8>,
#  <shapely.geometry.point.Point at 0x12984b7f0>,
#  <shapely.geometry.point.Point at 0x12984b828>,
#  <shapely.geometry.point.Point at 0x12984b860>,
#  <shapely.geometry.point.Point at 0x12984b898>,
#  <shapely.geometry.point.Point at 0x12984b8d0>,
#  <shapely.geometry.point.Point at 0x12984b908>,
#  <shapely.geometry.point.Point at 0x12984b940>,
#  <shapely.geometry.point.Point at 0x12984b978>,
#  <shapely.geometry.point.Point at 0x12984b9b0>,
#  <shapely.geometry.point.Point at 0x12984b9e8>,
#  <shapely.geometry.point.Point at 0x12984ba20>,
#  <shapely.geometry.point.Point at 0x12984ba58>,
#  <shapely.geometry.point.Point at 0x12984ba90>,
#  <shapely.geometry.point.Point at 0x12984bac8>,
#  <shapely.geometry.point.Point at 0x12984bb00>,
#  <shapely.geometry.point.Point at 0x12984bb38>,
#  <shapely.geometry.point.Point at 0x12984bb70>,
#  <shapely.geometry.point.Point at 0x12984bba8>,
#  <shapely.geometry.point.Point at 0x12984bbe0>,
#  <shapely.geometry.point.Point at 0x12984bc18>,
#  <shapely.geometry.point.Point at 0x12984bc50>,
#  <shapely.geometry.point.Point at 0x12984bc88>,
#  <shapely.geometry.point.Point at 0x12984bcc0>,
#  <shapely.geometry.point.Point at 0x12984bcf8>,
#  <shapely.geometry.point.Point at 0x12984bd30>,
#  <shapely.geometry.point.Point at 0x12984bd68>,
#  <shapely.geometry.point.Point at 0x12984bda0>,
#  <shapely.geometry.point.Point at 0x12984bdd8>,
#  <shapely.geometry.point.Point at 0x12984be10>,
#  <shapely.geometry.point.Point at 0x12984be48>,
#  <shapely.geometry.point.Point at 0x12984be80>,
#  <shapely.geometry.point.Point at 0x12984beb8>,
#  <shapely.geometry.point.Point at 0x12984bef0>,
#  <shapely.geometry.point.Point at 0x12984bf28>,
#  <shapely.geometry.point.Point at 0x12984bf60>,
#  <shapely.geometry.point.Point at 0x12984bf98>,
#  <shapely.geometry.point.Point at 0x12984bfd0>,
#  <shapely.geometry.point.Point at 0x129847048>,
#  <shapely.geometry.point.Point at 0x129847080>,
#  <shapely.geometry.point.Point at 0x1298470b8>,
#  <shapely.geometry.point.Point at 0x1298470f0>,
#  <shapely.geometry.point.Point at 0x129847128>,
#  <shapely.geometry.point.Point at 0x129847160>,
#  <shapely.geometry.point.Point at 0x129847198>,
#  <shapely.geometry.point.Point at 0x1298471d0>,
#  <shapely.geometry.point.Point at 0x129847208>,
#  <shapely.geometry.point.Point at 0x129847240>,
#  <shapely.geometry.point.Point at 0x129847278>,
#  <shapely.geometry.point.Point at 0x1298472b0>,
#  <shapely.geometry.point.Point at 0x1298472e8>,
#  <shapely.geometry.point.Point at 0x129847320>,
#  <shapely.geometry.point.Point at 0x129847358>,
#  <shapely.geometry.point.Point at 0x129847390>,
#  <shapely.geometry.point.Point at 0x1298473c8>,
#  <shapely.geometry.point.Point at 0x129847400>,
#  <shapely.geometry.point.Point at 0x129847438>,
#  <shapely.geometry.point.Point at 0x129847470>,
#  <shapely.geometry.point.Point at 0x1298474a8>,
#  <shapely.geometry.point.Point at 0x1298474e0>,
#  <shapely.geometry.point.Point at 0x129847518>,
#  <shapely.geometry.point.Point at 0x129847550>,
#  <shapely.geometry.point.Point at 0x129847588>,
#  <shapely.geometry.point.Point at 0x1298475c0>,
#  <shapely.geometry.point.Point at 0x1298475f8>,
#  <shapely.geometry.point.Point at 0x129847630>,
#  <shapely.geometry.point.Point at 0x129847668>,
#  <shapely.geometry.point.Point at 0x1298476a0>,
#  <shapely.geometry.point.Point at 0x1298476d8>,
#  <shapely.geometry.point.Point at 0x129847710>,
#  <shapely.geometry.point.Point at 0x129847748>,
#  <shapely.geometry.point.Point at 0x129847780>,
#  <shapely.geometry.point.Point at 0x1298477b8>,
#  <shapely.geometry.point.Point at 0x1298477f0>,
#  <shapely.geometry.point.Point at 0x129847828>,
#  <shapely.geometry.point.Point at 0x129847860>,
#  <shapely.geometry.point.Point at 0x129847898>,
#  <shapely.geometry.point.Point at 0x1298478d0>,
#  <shapely.geometry.point.Point at 0x129847908>,
#  <shapely.geometry.point.Point at 0x129847940>,
#  <shapely.geometry.point.Point at 0x129847978>,
#  <shapely.geometry.point.Point at 0x1298479b0>,
#  <shapely.geometry.point.Point at 0x1298479e8>,
#  <shapely.geometry.point.Point at 0x129847a20>,
#  <shapely.geometry.point.Point at 0x129847a58>,
#  <shapely.geometry.point.Point at 0x129847a90>,
#  <shapely.geometry.point.Point at 0x129847ac8>,
#  <shapely.geometry.point.Point at 0x129847b00>,
#  <shapely.geometry.point.Point at 0x129847b38>,
#  <shapely.geometry.point.Point at 0x129847b70>,
#  <shapely.geometry.point.Point at 0x129847ba8>,
#  <shapely.geometry.point.Point at 0x129847be0>,
#  <shapely.geometry.point.Point at 0x129847c18>,
#  <shapely.geometry.point.Point at 0x129847c50>,
#  <shapely.geometry.point.Point at 0x129847c88>,
#  ...]

# %%
crs = {'init': 'epsg:4326'}
taxiSample = gpd.GeoDataFrame(taxiSample, crs=crs, geometry=geometry)

# %%
taxiSample.head()
# Out:
#    Unnamed: 0 vendor_id      pickup_datetime     dropoff_datetime  \
# 0     6463382       VTS  2013-10-01 07:10:00  2013-10-01 07:23:00
# 1     3959086       CMT  2013-10-22 12:39:33  2013-10-22 12:53:47
# 2     4318338       CMT  2013-10-25 13:55:45  2013-10-25 13:59:04
# 3    13891146       CMT  2013-10-02 18:41:38  2013-10-02 18:45:18
# 4     4464588       CMT  2013-10-24 14:40:05  2013-10-24 14:46:13
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1           2.81        -73.986260        40.734592
# 1                1           1.00        -73.981446        40.765865
# 2                2           0.00        -73.947737        40.772811
# 3                1           1.00        -73.949122        40.781575
# 4                1           0.70        -73.972321        40.765193
#
#    rate_code store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0          1                NaN         -74.013570         40.714595
# 1          1                  N         -73.982812         40.753442
# 2          1                  N         -73.947136         40.772706
# 3          1                  N         -73.955284         40.769184
# 4          1                  N         -73.981999         40.770587
#
#   payment_type  fare_amount  surcharge  mta_tax  tip_amount  tolls_amount  \
# 0          CRD         13.0        0.0      0.5         2.6           0.0
# 1          CSH          9.5        0.0      0.5         0.0           0.0
# 2          CSH          3.5        0.0      0.5         0.0           0.0
# 3          CRD          5.0        1.0      0.5         2.5           0.0
# 4          CSH          5.5        0.0      0.5         0.0           0.0
#
#    total_amount                              geometry
# 0          16.1           POINT (-74.01357 40.714595)
# 1          10.0  POINT (-73.98281199999998 40.753442)
# 2           4.0          POINT (-73.947136 40.772706)
# 3           9.0  POINT (-73.95528399999999 40.769184)
# 4           6.0          POINT (-73.981999 40.770587)

# %%
taxiSample['dropoff_latitude'].min()
# Out:
# 0.0

# %%
taxiSample['dropoff_longitude'].min()
# Out:
# -79.414876

# %%
cleanTaxiSample = taxiSample[taxiSample['dropoff_latitude'] > 40.4]
cleanTaxiSample = cleanTaxiSample[cleanTaxiSample['dropoff_latitude'] < 40.95]
cleanTaxiSample = cleanTaxiSample[cleanTaxiSample['dropoff_longitude'] > -74.3]
cleanTaxiSample = cleanTaxiSample[cleanTaxiSample['dropoff_longitude'] < -73.65]

# %%
cleanTaxiSample['dropoff_longitude'].max()
# Out:
# -73.65201299999998

# %%
len(cleanTaxiSample)
# Out:
# 98824

# %%
cleanTaxiSample['geometry'] = cleanTaxiSample['geometry'].to_crs(epsg=2263)

# %%
cleanTaxiSample.plot(color='red', markersize=0.2)

# %%
fig, ax = plt.subplots()
nycClean.plot(column='MHHI', ax=ax, cmap='cool')
cleanTaxiSample.plot(color='red',ax=ax, markersize=0.2)
plt.show()

# %%
nycCensusTaxis = gpd.sjoin(nycClean, cleanTaxiSample, how='left', op='intersects')
# Out:
# /usr/local/lib/python3.7/site-packages/geopandas/tools/sjoin.py:44: UserWarning: CRS of frames being joined does not match!
#   warn('CRS of frames being joined does not match!')

# %%
nycCensusTaxis.shape
# Out:
# (92896, 39)

# %%
nycCensusTaxis.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID NAME         NAMELSAD  MTFCC FUNCSTAT  \
# 0      36      081  003400  36081003400   34  Census Tract 34  G5020        S
# 1      36      081  003900  36081003900   39  Census Tract 39  G5020        S
# 1      36      081  003900  36081003900   39  Census Tract 39  G5020        S
# 1      36      081  003900  36081003900   39  Census Tract 39  G5020        S
# 1      36      081  003900  36081003900   39  Census Tract 39  G5020        S
#
#     ALAND  AWATER  ... store_and_fwd_flag dropoff_longitude dropoff_latitude  \
# 0  213987       0  ...                NaN               NaN              NaN
# 1  146970       0  ...                NaN        -73.942118        40.761825
# 1  146970       0  ...                NaN        -73.941955        40.761852
# 1  146970       0  ...                NaN        -73.940365        40.762235
# 1  146970       0  ...                  N        -73.940812        40.763547
#
#   payment_type  fare_amount surcharge  mta_tax  tip_amount  tolls_amount  \
# 0          NaN          NaN       NaN      NaN         NaN           NaN
# 1          CRD         11.0       0.5      0.5         2.3           0.0
# 1          CSH         14.0       0.5      0.5         0.0           0.0
# 1          CSH          8.0       0.0      0.5         0.0           0.0
# 1          CSH          7.0       0.0      0.5         0.0           0.0
#
#    total_amount
# 0           NaN
# 1          14.3
# 1          15.0
# 1           8.5
# 1           7.5
#
# [5 rows x 39 columns]

# %%
nycCensusTaxis['tip_perc'] = nycCensusTaxis['tip_amount'] / nycCensusTaxis['fare_amount']

# %%
nycCensusTaxis['tip_perc'].sort_values(ascending=False)
# Out:
# 1854    13.466667
# 1114     9.600000
# 519      9.400000
# 1863     9.101818
# 1858     6.000000
# 1867     4.800000
# 1854     4.800000
# 524      4.562857
# 384      3.333333
# 1888     3.285455
# 883      2.800000
# 597      2.693333
# 934      2.600000
# 662      2.113333
# 1523     2.000000
# 1867     2.000000
# 1849     2.000000
# 639      2.000000
# 519      1.847692
# 654      1.818182
# 1905     1.704516
# 1836     1.666667
# 576      1.666667
# 1806     1.600000
# 633      1.538462
# 1868     1.538462
# 1827     1.538462
# 601      1.538462
# 1802     1.500000
# 629      1.500000
#           ...
# 2075          NaN
# 2078          NaN
# 2080          NaN
# 2081          NaN
# 2082          NaN
# 2083          NaN
# 2086          NaN
# 2087          NaN
# 2088          NaN
# 2090          NaN
# 2092          NaN
# 2093          NaN
# 2094          NaN
# 2095          NaN
# 2097          NaN
# 2098          NaN
# 2102          NaN
# 2104          NaN
# 2106          NaN
# 2107          NaN
# 2110          NaN
# 2112          NaN
# 2131          NaN
# 2140          NaN
# 2142          NaN
# 2154          NaN
# 2159          NaN
# 2160          NaN
# 2162          NaN
# 2163          NaN
# Name: tip_perc, Length: 92896, dtype: float64

# %%
pivotTable = nycCensusTaxis.pivot_table(index='GEOID',
values=['MHHI', 'tip_perc', 'vendor_id'],
aggfunc={'vendor_id':'count', 'tip_perc':'mean', 'MHHI':'mean'})

# %%
pivotTable.head()
# Out:
#               MHHI  tip_perc  vendor_id
# GEOID
# 36005000200  62773       NaN          0
# 36005000400  82697  0.202198          1
# 36005001600  33118  0.000000          1
# 36005001900  40117  0.074850          8
# 36005002000  18370       NaN          0

# %%
pivotTable.sort_values('MHHI', ascending=False)
# Out:
#                MHHI  tip_perc  vendor_id
# GEOID
# 36061011401  233646  0.093622        540
# 36047002100  212159  0.129339        154
# 36061014200  208024  0.098462        583
# 36061015002  205145  0.089195        495
# 36061003100  202404  0.118018        224
# 36061006900  198636  0.147260        236
# 36061003300  193750  0.110213        593
# 36061013000  190208  0.093777        609
# 36061014700  190167  0.110480        113
# 36061012000  187292  0.102557        619
# 36061005800  183988  0.127913        824
# 36061000900  180547  0.101342        450
# 36061008603  167607  0.109989        210
# 36061010200  167500  0.097691       1143
# 36061016700  165753  0.104040        364
# 36061012800  165049  0.100192        650
# 36061011202  163750  0.119909        612
# 36061031704  162030  0.107878        426
# 36081074900  161750  0.187760          3
# 36047000900  161144  0.125080         86
# 36061010900  160511  0.094969        731
# 36081056100  160250       NaN          0
# 36061005501  160121  0.118210        231
# 36061005200  159821  0.129754        760
# 36061014500  159222  0.112300        714
# 36047006700  158194  0.136792         33
# 36061003900  157652  0.132848        528
# 36047000700  157534  0.161422         55
# 36061005700  157176  0.117353        311
# 36061012200  156827  0.092464        522
# ...             ...       ...        ...
# 36047111000   17854  0.081081          1
# 36047048900   17518  0.208696          1
# 36061002500   17500  0.106708          9
# 36005005200   17454  0.000000          1
# 36005002300   17426  0.000000          2
# 36047110600   17405       NaN          0
# 36005002701   17383  0.000000          1
# 36061019200   17304  0.018972         11
# 36005015300   17154  0.142857          2
# 36061019600   17070  0.094778        119
# 36047092000   17016       NaN          0
# 36047025902   16448  0.207970          2
# 36047115600   16404  0.203390          1
# 36061011900   16394  0.092471        964
# 36005014300   15060       NaN          0
# 36005020502   14821  0.000000          1
# 36061002000   14745  0.064664         33
# 36005016100   14667       NaN          0
# 36047091200   14347       NaN          0
# 36061002400   14300  0.069619         17
# 36005005300   13519       NaN          0
# 36085013301   13485       NaN          0
# 36005002702   13216  0.011364          4
# 36047008500   13207  0.149213          5
# 36047035200   12302       NaN          0
# 36047091000   11560  0.000000          1
# 36047090800   10767       NaN          0
# 36047080800   10729       NaN          0
# 36047090600   10693       NaN          0
# 36085031901    9053       NaN          0
#
# [2101 rows x 3 columns]

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.scatter(pivotTable['MHHI'], pivotTable['tip_perc'])
plt.show()
